# %% [markdown]
# # Snomed2Vec-01 - Use Model - Methods & Class. V.01.
# ** Basado en el Notebook original 17 - Snomed2Vec - Use Model - Uso de la clase y sus métodos.**
# ### A new Approach Snomed-CT with word embedding - Snomed2Vec - Model.
# ### Introducción:
# **Autor:** Ignacio Martinez Soriano.<br>
# **Director Tesis:** Juan Luis Castro Peña.<br>
# **Fecha:** 12/10/2018.<br>
#
# ## 1. Introducción:
# Creación de un nuevo enfoque **Snomed2Vec**<br>
# Diseño de una herramienta para obtener los conceptos clínicos dentro del texto libre de cualquier informe médico. Asociándole el código mas aproximado, del concepto Snomed-CT. Devolviendo la lista de conceptos Snomed-CT, que aparecen en una frase y sus relaciones con otras entidadades clínicas.<br>
# Nos basamos en dos artículos:<br>
# 1. [DNER Clinical (named entity recognition) from free clinical text to Snomed-CT concept](http://www.wseas.org/multimedia/journals/computers/2017/a205805-078.pdf). Ignacio Martinez Soriano. Juan Luis castro Peña. WSEAS Transactions on Computers, ISSN / E-ISSN: 1109-2750 / 2224-2872, Volume 16, 2017, Art. 10, pp. 83-91.
# 1. [STMC: Semantic Tag Medical Concept Using Word2Vec Representation](https://ieeexplore.ieee.org/document/8417270) Ignacio Martinez Soriano, Juan Luis Castro Peña. 2018 IEEE 31st International Symposium on Computer-Based Medical Systems (CBMS). Karsltad (Sweden).
#
#
# Desarrollo de un **Clinical Semantic TAG** (Clinical Named Entity Recognition - NER).<br>
# Generamos un espacio vectorial de palabras embebidas, "Word Embedding", utilizamos un enfoque híbrido con dos versiones, creando distintos enfoques:
# * los Informes de Alta del Servicio de Urgencias del Hospital "Rafael Méndez", desde el año 2009-2016, mas las descripciones de los conceptos de Snomed-CT.
# * Un modelo genarado con la descarga normalizada de Wikipedia en español (Fecha 01 de Octubre 2018) + las descripciones de los conceptos de Snomed.CT.
#
# Para generar el espacio vectorial final de palabras embebidas, utilizamos nuestro modelo entrenado con las palabras de un gran corpus (Informes de Alta o Wikipedia) y lo volvemos a entrenar añadiendole las descripciones de Snomed-CT, generando de esta forma los vectores finales de nuestro Modelo.
#
# **Generación Modelo final Snomed2Vec:**
#
# Basándonos en los vectores de ese Modelo, aplicamos los vectores de las palabras para generar el Vector de la Descripción de Snomed-CT:<br>
# Utilizamos el Modelo generado con Word2Vec, y lo aplicamos a la descripción de Snomed-CT, generando el siguiente vector asociado a la descripción **[d]**<br>
# Siendo $ V(w_i) $ el Vector asociado a la palabra $ w_i $, según el modelo Word2Vec $ M $.<br>
# * $ Descripcion-Snomed-CT(d) = (w_1,w_2,...,w_n),=> V[d] = \sum_{i=1}^{n}v[w_{i}]=v[w_{1}]+v[w_{2}]+...+v[w_{n}] $
#
# El Modelo **Snomed2Vec** final: quedaria así:
#
# * Un registro para cada concepto con la siguiente estructura:<br>
# **| Id-Concept | Jerarquia | Descripcion | [Vector de la Descripción] |**
#
# ### Métodos implementados:
#
# Implementamos una version de **Most_Similar()** para obtener los Conceptos similares de  **Snomed-CT**<br>
#
# * **Mas_Similar('frase','clase mas proxima')**
# *  Entrada: **frase**, **clase mas proxima**, se refiere a si se quiere buscar, los conceptos mas cercanos, según la jerarquía de Snomed-CT.
# *  Salida: (Lista de conceptos, nombrados en la **frase**, proporcionando los mas cercanos según clase buscada)
#
# ## 2. Snomed-CT:
# Utilizamos la Ontología **Snomed-CT**, como Terminología clínica,para identificar los conceptos y codificarlos.<br>
#
# ### Estructura Lógica:
# ![Estructura Lógica Snomed-CT](./imagesNB/Modelo_logico_Snomed_1.png "Estructura Lógica")
# *Imagen de https://confluence.ihtsdotools.org/*
#
# **Conceptos:**<br>
# Cada concepto representa un significado clínico único, al que se referencia con un identificador numérico único de SNOMED CT.
#
# **Descripciones:**<br>
# A cada concepto se asigna un conjunto de descripciones textuales. Éstas constituyen la forma legible de un concepto. Se utilizan dos tipos de descripciones para representar cada concepto - Descripción completa (FSN, por Fully specified name en inglés) y Sinónimo.
#
# **Relaciones:**<br>
# Una relación representa una asociación entre dos conceptos. Las relaciones se utilizan para definir lógicamente el significado de un concepto de manera que pueda procesarlo un ordenador. Un tercer concepto, denominado el tipo de relación (o atributo), se utiliza para representar el significado de la asociación entre el concepto de origen y el de destino. En SNOMED CT existen diferentes tipos de relaciones.
#
# **Jerarquías:**<br>
# Nivel superior con una breve descripción del contenido representado en su rama de la jerarquía.
#
# >**|Hallazgo clínico|** representa el resultado de una observación, una evaluación o un juicio clínico e incluye a los conceptos utilizados para representar diagnósticos.<br>
# **|Procedimiento|** representa actividades que se llevan a cabo durante la atención de la salud.<br>
# **|Situación con contexto explícito|** representa hallazgos clínicos y procedimientos que aún no han ocurrido, (por ejemplo,|antecedente de infarto de miocardio|).<br>
# **|Entidad observable|** representa una pregunta o una evaluación de las que se puede obtener una respuesta o un resultado (por ejemplo, |presión arterial sistólica|, |color del iris|, |género|). <br>
# **|Estructura corporal|** representa estructuras anatómicas normales y anormales.<br>
# **|Organismo|** representa organismos relevantes para la medicina humana y veterinaria.<br>
# **|Sustancia|** representa sustancias en general, los constituyentes químicos de los productos farmacéuticos/biológicos, sustancias corporales, sustancias alimenticias y diagnósticas. <br>
# **|Producto farmacéutico / biológico|** representa los productos farmacológicos (por ejemplo, |amoxicilina 250 mg, cápsula|, |paracetamol + codeína comprimido|). <br>
# **|Espécimen|** representa entidades que se obtienen (por lo general del paciente) para realizar exámenes o análisis.<br>
# **|Concepto especial|** representa conceptos que no desempeñan ningún papel en la lógica formal del modelo conceptual de la terminología, pero que pueden ser útiles para casos de uso específicos. <br>
# **|Objeto físico|** representa objetos físicos naturales y fabricados por el hombre.<br>
# **|Fuerza física|** representa fuerzas físicas que pueden desempeñar un papel como mecanismos de lesión (por ejemplo |fricción|, |radiación|, |corriente alterna|).<br>
# **|Evento|** representa acontecimientos, con exclusión de procedimientos e intervenciones, (por ejemplo, |terremoto|). <br>
# **|Ambiente o localización geográfica|** representa tipos de ambientes, así como lugares con nombres propios, como países, estados y regiones.<br>
# **|Contexto social|** representa condiciones sociales y circunstancias significativas para la atención de la salud.<br>
# **|Estadificaciones y escalas|** representa escalas de evaluación y sistemas de estadificación tumoral. <br>
# **|Calificador|** representa los valores para algunos de los atributos de SNOMED CT, cuando esos valores no son subtipos de otros conceptos de nivel superior (por ejemplo, |izquierdo|, |resultado anormal|, |severo|).<br>
# **|Elemento de registro|** representa contenido creado para brindar información a otras personas sobre eventos de registro o estado de asuntos (por ejemplo, |registro llevado por el paciente|, entrada de registro|, |sección correspondiente a antecedentes familiares|).<br>
# **|Componente del modelo de SNOMED CT|** contiene los metadatos que se utilizan para la publicación de SNOMED CT. <br>
#
#
# ### Estructura General:
# ![Estructura General Modelo Snomed-CT](./imagesNB/Diseno.png "Modelo conceptual")
# *Imagen de https://confluence.ihtsdotools.org/*
#
# ## 3. Generación de los Modelos de Espacio Vectorial, para palabras:
#
# Para generar el modelo vectorial de palabras embebidas utilizamos Word2Vec, generado por Mikolov et al.<br>
# >Tomas Mikolov, Kai Chen, Greg Corrado, and Jeffrey Dean. 2013a. [Efficient estimation of word representations in vector space.](https://arxiv.org/abs/1301.3781) In Proceedings of ICLR Workshop
#
#
# **Word2Vec**, es un framework semántico que utiliza una red neuronal superficial de una sola capa oculta, para aprender la representación de la palabra según su contexto.<br>
# La idea es que el significado de las palabras viene definido, por el contexto. Esta idea fue desarrollada por Mikolov et al. generando una representacion distribuida de palabras en un espacio vectorial. Permitiendo la agrupación de palabras similares.
# Para generar los Modelos del espacio vectorial de palabras, utilizamos la libreria Python **gensim:**<br>
# >[*REHUREK, R., AND SOJKA, P. Software framework for topic modelling with large corpora. New Challenges For NLP Frameworks Programme (May 2010), 45–50.*](https://github.com/RaRe-Technologies/gensim)
#
# Los parámetros utilizados para entrenar la red neuronal, han sido:
# * El modelo elegido ha sido Skip-Gram.
# * Tamaño del vector. size=300.
# * Tamaño del a ventana de contexto. Window=5
# * Mínimas palabras de estudio. min_count=2
#
# **Se ha generado los siguientes Modelos:**
#
# 1. Modelo Dominio local, Word2Vec: Snomed2Vec-IA<br>
# Se genera un modelo de espacio vectorial, con **Word2Vec**, basado en los **Informes de Alta de urgencias**. Con los siguientes parámetros:<br>
# ***(SkipGram, vector size 300, windows= 5, Negative=0, min=2)***
#
# 1. Modelo Dominio General, Word2Vec: Snomed2Vec-Wiki<br>
# Se genera un modelo de espacio vectorial, con **Word2Vec**, basado en **Wikipedia Español**. Con los siguientes parámetros:<br>
# ***(SkipGram, vector size 300, windows= 5, Negative=0, min=2)***
#
# 1. Modelo Dominio General, Word2Vec: Snomed2Vec-CT<br>
# Se genera un modelo de espacio vectorial, con **Word2Vec**, basado en **Descripciones del Snomed-CT**. Con los siguientes parámetros:<br>
# ***(SkipGram, vector size 300, windows= 5, Negative=0, min=2)***
#
# 1. Modelo Dominio local, ampliado con las descripciones de Snomed-CT:<br>
# Se genera un modelo de espacio vectorial, con **Word2Vec**, basado en los Informes de Alta de urgencias y se vuelve a entrenar con las descripciones de Snomed-CT.
#
# 1. Modelo Dominio general, Wikipedia, ampliado con descripciones Snomed-CT:<br>
# Se genera un modelo de espacio vectorial, con **Word2Vec**, basado en los datos de la wikipedia en español, ampliada con las descripciones de Snomed-CT.
#
# **Modelo Final:**
# ![Snomed2Vec-Model02](./imagesNB/Snomed2Vec-Model02.png "Modelo Snomed2Vec")
#
# ## 4. Generación Vector para las frases:
#
# Una vez generado el modelo elegido, se aplica a las descripciones de Snomed-CT, utilizando un DataSet construido específicamente para este framework.
#
# El DataSet construido está compuesto por los siguientes campos **(id-Concepto, Jerarquia, descripción Concepto)**
# Para identificar que tipo de concepto estamos seleccionando, se ha utilizado la jerarquia superior del concepto de Snomed-CT, al que pertenece.
#
# **Generación Modelo final:**<br>
# Utillizando los modelos anteriores, se aplica a la descripción del concepto, para generar el vector de la descripción:
#
# Siendo $ V(w_i) $ el Vector asociado a la palabra $ w_i $, según el modelo Word2Vec $ M $.<br>
# * $ Descripcion-Snomed-CT(d) = (w_1,w_2,...,w_n),=> V[d] = \sum_{i=1}^{n}v[w_{i}]=v[w_{1}]+v[w_{2}]+...+v[w_{n}] $
#
# Obteniendo un modelo final **Snomed2Vec**, compuesto por:
# **(id-Concept | Jerarquia | Descripción | vecSnom(d) )**:
# ![Estructura Snomed2Vec](./imagesNB/SnomedWork.png "Modelo Snomed2Vec")
#
#
# ## 5. Métodos,  cálculo similaridad y mas_similar():<br>
# Para calcular los conceptos similares, se aplica la distancia del coseno, entre los vectores de cada palabra o frase:<br>
# ![Distancia Coseno Similaridad](./imagesNB/cosine-similarity.png "Modelo Snomed2Vec")
#
# ### Snomed2Vec.Similar(texto1, texto2):<br>
# **Entrada:** texto1=frase secuencia palabras<br>
# **Sallida:** grado de similaridad = distancia del coseno, entre los vectores de V[texto1] y v[texto2]<br>
#
# ### Snomed2Vec.mas_similar(texto,clase):<br>
# **Entrada:**<br>
# *texto*=frase secuencia palabras<br>
# *clase*= Tipo de concepto, para sacar los más proximos, respecto a la entrad de texto.<br>
# **Sallida:** grado de similaridad = distancia del coseno, entre los vectores de V[texto] y v[Todas Desc Snomed-CT]<br>
#
#
# ## 6. Resultados de la investigación:
# * DataSet de Snomed-CT, compuesto por los conceptos con su jerarquia superior, y sus sinónimos.
# * Modelo Wikipedia en Español, entrenado con word2vec y normalizado. (palabras en minúsculas). Tamañao 300 y con Skip-Gram.
# * Modelos Snomed2Vec, entrenados, según lso modelos de espacios vectorial, elegidos.
# * framework, para obtner los conceptos y relaciones, según una frase de entrada. (Por ejemplo un diagnóstico principal).
#
#
#
# ### Representation Learning
# I create some jupyter notebook to test the framewotk
# Prueba
#   ```
#   python Snomed2Vec.py *"sentence test"*
#   ```
#   This script get the SNomed-CT Clinical concept from a free text sentence.
#
# ## 7. Data sources, Space vector Models:
# ** Corpus Gold:**
#
# ## Final notes:
# This documentation is part of my PH.D.Thesis and share to improve this new approach.
# For any comments or help needed with how to test *Snomed2Vec* tool, you can write to: ignacio.martinez@carm.es

# %% [markdown]
# ### Carga de librerias necesarias:

# %%
# Carga de librerias. Versiones en Portatil
# numpy 1.13.3
# pandas 0.20.3
# gensim 2.30
import sys
#p= r'D:\Doctorado\codigo'
p='/media/nacho/DatosHD/Doctorado/codigo'
sys.path.append(p)

#import unicodedata
import pandas as pd
import numpy as np
from numpy import exp, log, dot, zeros, outer, random, dtype, float32 as REAL,\
    double, uint32, seterr, array, uint8, vstack, fromstring, sqrt, newaxis,\
    ndarray, empty, sum as np_sum, prod, ones, ascontiguousarray, vstack

from six import iteritems, itervalues, string_types
from six.moves import xrange
from gensim import utils, matutils

from gensim.models import Word2Vec
from gensim.models.keyedvectors import KeyedVectors

import logging
import IPython.display as disp

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
pd.set_option('max_colwidth', 100) #para que se impriman las columnas con mayor anchura en el notebook
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 1. Función Snomed2vec_Model, seleccion del Modelo inicial:
# **Snomed2Vec.load(typeModel)**

# %% [markdown]
# ### 1.1 Modelo de Espacio de vectores aplicado a las descripciones de Snomed:
#
# Dependiendo del Modelo elegido, se utilizará,para generer los vectores de cada descripción de Snomed.
#
# El vector generado para la descripción **[d]** está formado  por:
# * $ Descripcion (d) = (w_1,w_2,...,w_n), V[d] = \sum_{i=1}^{n}v[w_{i}]=v[w_{1}]+v[w_{2}]+...+v[w_{n}] $

# %% [markdown]
# ### 1.2. Carga Datos DataFrame de Snomed-CT. Snomed2Vec.load(typeModel).
# Carga del Modelo Snomed2Vec, Entrenado según el modelo elegido.
#
# Obtenemos el modelo final:<br>
# ** Carga de Datos Snomed IdConcepto, Jerarquias, TokenTerm, Vector(Segun Modelo):**<br>
# Modelo generado en el Notebook 20-02.Snomed-CT<br>
# ** Cargar el modelo previamente generado en formato numpy.**<br>
# fichero *Snomed2Vec-SK300-IA-Op2.npy*<br>

# %%
# Carga del Modelo elegido, según de la funcion snomed2vec.load.
# Utilzia el modelo entrenado Word2Vec, (Word vectors)y el modelo generado final Snomed2Vec.(Sentence vectors)

def snomed2vec_load(typeModel=0):
    """ 
    Dependiendo del parámetro typeModel, se carga los siguientes modelos preentrenados (Word2Vec):
    1. typeModel=0 -> Modelo entrenado con los (Informes de ALta de urgencia + Descripcion Snomed-CT)
    2. typeModel=1 -> Modelo entrenado con wikipedia en español + Descripción Terminos Snomed-CT.

    """
    if typeModel==0: #Modelo Informes de Alta + Descripciones Snomed-CT
        print('Modelo entrenado con los Informes de Alta de Urgencias + Descripciones de Snomed-CT')
        fich = '/Models/w2v-SK-s300-w5-m2-Total-Key.txt'
        fSnomed = '/Snomed-CT/Diccionario/Snomed2Vec-SK300-InfAlt-Snomed-Op4.npy'
        
    elif typeModel==1: #Modelo Wikipedia
        print('Modelo entrenado con la Wikipedia en Español')
        fich = '/Models/Snomed2Vec-Wiki-SK-s300-w5-m1-Total-Key.txt'
        fSnomed = '/Snomed-CT/Diccionario/Snomed2Vec-COBW300-Wiki-Op3.npy'
    
    f = p+fich
    fSno = p+fSnomed
    cols=['idConcept','jerarquia','corpusTerm','vecSnom']
    print('Carga del Modelo Snomed2Vec tipo:(%s)' % str(typeModel))
    with open(fSno,'rb') as np_file:
        data = np.load(np_file)
    
    return KeyedVectors.load_word2vec_format(f, binary=False), pd.DataFrame(data, columns=cols)

# %%
w2vModel, SnomedWork = snomed2vec_load(0)
# Out:
# Modelo entrenado con los Informes de Alta de Urgencias + Descripciones de Snomed-CT
# Carga del Modelo Snomed2Vec tipo:(0)
# 2018-10-30 11:57:03,521 : INFO : loading projection weights from /media/nacho/DatosHD/Doctorado/codigo/Models/w2v-SK-s300-w5-m2-Total-Key.txt
# 2018-10-30 11:57:53,895 : INFO : loaded (294700, 300) matrix from /media/nacho/DatosHD/Doctorado/codigo/Models/w2v-SK-s300-w5-m2-Total-Key.txt

# %%
# Comprobacion del dataframe:

SnomedWork.head()
# Out:
#   idConcept      jerarquia                                    corpusTerm  \
# 0    102002      Sustancia                       [hemoglobina, okaloosa]
# 1    102002      Sustancia                       [hb, 48, cd7, leu, arg]
# 2    103007      Organismo                    [virus, fibroma, ardillas]
# 3    104001  Procedimiento                    [escision, lesion, rotula]
# 4    104001  Procedimiento  [escision, local, lesion, o, tejido, rotula]
#
#                                                                                                vecSnom
# 0  [-0.660218, 0.112245, 0.067039, 0.441094, -0.50456, -0.724666, -0.107986, 0.313558, 0.198024, 1....
# 1  [-0.317944, 1.87942, 1.76004, 1.72051, 0.75724, -1.13105, -0.499457, -1.84984, -0.570444, -0.630...
# 2  [-0.14364, -0.006139, 0.080456, 0.936581, -1.16385, -0.552844, 0.081489, -0.584596, -0.185695, 0...
# 3  [-1.0588, -0.371483, -1.84789, 1.65618, -0.235278, 0.101576, -1.08105, 0.863104, -0.374193, 1.04...
# 4  [-0.178396, -0.865999, -2.62099, 3.59125, -1.68036, -0.115811, -1.95361, 0.583631, -1.50294, 1.5...

# %%
# Comprobación del Modelo
w2vModel.vocab
# Out:
# {'no': <gensim.models.keyedvectors.Vocab at 0x7f5854ddcbe0>,
#  '0': <gensim.models.keyedvectors.Vocab at 0x7f586b241da0>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x7f586b32e710>,
#  'dolor': <gensim.models.keyedvectors.Vocab at 0x7f586830db00>,
#  'horas': <gensim.models.keyedvectors.Vocab at 0x7f5893455ba8>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x7f5854dc8048>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x7f5854dc81d0>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x7f5854dc80b8>,
#  'ni': <gensim.models.keyedvectors.Vocab at 0x7f5854dc8d30>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x7f5854d120b8>,
#  'dias': <gensim.models.keyedvectors.Vocab at 0x7f5854d121d0>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x7f5854d12240>,
#  'cada': <gensim.models.keyedvectors.Vocab at 0x7f5854d12390>,
#  'años': <gensim.models.keyedvectors.Vocab at 0x7f5854d123c8>,
#  'si': <gensim.models.keyedvectors.Vocab at 0x7f5854d124a8>,
#  'mg': <gensim.models.keyedvectors.Vocab at 0x7f5854d12588>,
#  'c': <gensim.models.keyedvectors.Vocab at 0x7f5854d125f8>,
#  'paciente': <gensim.models.keyedvectors.Vocab at 0x7f5854d12630>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x7f5854d126d8>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x7f5854d12780>,
#  'refiere': <gensim.models.keyedvectors.Vocab at 0x7f5854d12828>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x7f5854d12860>,
#  'hace': <gensim.models.keyedvectors.Vocab at 0x7f5854d129b0>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x7f5854d129e8>,
#  't': <gensim.models.keyedvectors.Vocab at 0x7f5854d12b00>,
#  'fiebre': <gensim.models.keyedvectors.Vocab at 0x7f5854d12ba8>,
#  'beg': <gensim.models.keyedvectors.Vocab at 0x7f5854d12c18>,
#  'negativo': <gensim.models.keyedvectors.Vocab at 0x7f5854d12c50>,
#  'hta': <gensim.models.keyedvectors.Vocab at 0x7f5854d12da0>,
#  'rx': <gensim.models.keyedvectors.Vocab at 0x7f5854d12e80>,
#  'signos': <gensim.models.keyedvectors.Vocab at 0x7f5854d12f28>,
#  'derecho': <gensim.models.keyedvectors.Vocab at 0x7f5854d12fd0>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x7f5854d15240>,
#  'evolucion': <gensim.models.keyedvectors.Vocab at 0x7f5854d15390>,
#  'derecha': <gensim.models.keyedvectors.Vocab at 0x7f5854d15550>,
#  'raf': <gensim.models.keyedvectors.Vocab at 0x7f5854d15710>,
#  'acude': <gensim.models.keyedvectors.Vocab at 0x7f5854d158d0>,
#  'ap': <gensim.models.keyedvectors.Vocab at 0x7f5854d15a90>,
#  '12': <gensim.models.keyedvectors.Vocab at 0x7f5854d15be0>,
#  'tras': <gensim.models.keyedvectors.Vocab at 0x7f5854d15d30>,
#  'dm': <gensim.models.keyedvectors.Vocab at 0x7f5854d15e48>,
#  'soplos': <gensim.models.keyedvectors.Vocab at 0x7f5854d15f60>,
#  'consulta': <gensim.models.keyedvectors.Vocab at 0x7f5854d15f98>,
#  'ta': <gensim.models.keyedvectors.Vocab at 0x7f5854d170f0>,
#  'tratamiento': <gensim.models.keyedvectors.Vocab at 0x7f5854d17160>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x7f5854d17198>,
#  'medico': <gensim.models.keyedvectors.Vocab at 0x7f5854d172b0>,
#  'palpacion': <gensim.models.keyedvectors.Vocab at 0x7f5854d17358>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x7f5854d17400>,
#  'urgencias': <gensim.models.keyedvectors.Vocab at 0x7f5854d17438>,
#  'izquierdo': <gensim.models.keyedvectors.Vocab at 0x7f5854d174e0>,
#  'interes': <gensim.models.keyedvectors.Vocab at 0x7f5854d17550>,
#  'reposo': <gensim.models.keyedvectors.Vocab at 0x7f5854d17710>,
#  '24': <gensim.models.keyedvectors.Vocab at 0x7f5854d177f0>,
#  'izquierda': <gensim.models.keyedvectors.Vocab at 0x7f5854d17828>,
#  'vomitos': <gensim.models.keyedvectors.Vocab at 0x7f5854d17978>,
#  'blando': <gensim.models.keyedvectors.Vocab at 0x7f5854d17a90>,
#  'depresible': <gensim.models.keyedvectors.Vocab at 0x7f5854d17b70>,
#  'nbsp': <gensim.models.keyedvectors.Vocab at 0x7f5854d17cf8>,
#  'abdomen': <gensim.models.keyedvectors.Vocab at 0x7f5854d17e10>,
#  'ritmico': <gensim.models.keyedvectors.Vocab at 0x7f5854d17eb8>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x7f5854d17fd0>,
#  '36': <gensim.models.keyedvectors.Vocab at 0x7f5854d1b198>,
#  'abdominal': <gensim.models.keyedvectors.Vocab at 0x7f5854d1b1d0>,
#  'cyo': <gensim.models.keyedvectors.Vocab at 0x7f5854d1b2b0>,
#  'torax': <gensim.models.keyedvectors.Vocab at 0x7f5854d1b400>,
#  'dlp': <gensim.models.keyedvectors.Vocab at 0x7f5854d1b4a8>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x7f5854d1b588>,
#  'buen': <gensim.models.keyedvectors.Vocab at 0x7f5854d1b668>,
#  'ac': <gensim.models.keyedvectors.Vocab at 0x7f5854d1b710>,
#  'mg/dl': <gensim.models.keyedvectors.Vocab at 0x7f5854d1b828>,
#  '40': <gensim.models.keyedvectors.Vocab at 0x7f5854d1b9b0>,
#  'acp': <gensim.models.keyedvectors.Vocab at 0x7f5854d1bb00>,
#  'abd': <gensim.models.keyedvectors.Vocab at 0x7f5854d1bba8>,
#  'dia': <gensim.models.keyedvectors.Vocab at 0x7f5854d1bc88>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x7f5854d1bdd8>,
#  'masas': <gensim.models.keyedvectors.Vocab at 0x7f5854d1bef0>,
#  'afebril': <gensim.models.keyedvectors.Vocab at 0x7f5854d1bfd0>,
#  'resto': <gensim.models.keyedvectors.Vocab at 0x7f5854d1f160>,
#  '+': <gensim.models.keyedvectors.Vocab at 0x7f5854d1f240>,
#  'lpm': <gensim.models.keyedvectors.Vocab at 0x7f5854d1f358>,
#  'ingreso': <gensim.models.keyedvectors.Vocab at 0x7f5854d1f4a8>,
#  'nivel': <gensim.models.keyedvectors.Vocab at 0x7f5854d1f6a0>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x7f5854d1f828>,
#  'urea': <gensim.models.keyedvectors.Vocab at 0x7f5854d1f8d0>,
#  'leucocitos': <gensim.models.keyedvectors.Vocab at 0x7f5854d1f908>,
#  'map': <gensim.models.keyedvectors.Vocab at 0x7f5854d1f978>,
#  'bilateral': <gensim.models.keyedvectors.Vocab at 0x7f5854d1f9b0>,
#  'doloroso': <gensim.models.keyedvectors.Vocab at 0x7f5854d1f9e8>,
#  'x10': <gensim.models.keyedvectors.Vocab at 0x7f5854d1fa58>,
#  '00': <gensim.models.keyedvectors.Vocab at 0x7f5854d1fac8>,
#  'mvc': <gensim.models.keyedvectors.Vocab at 0x7f5854d1fc50>,
#  'seguimiento': <gensim.models.keyedvectors.Vocab at 0x7f5854d1fd30>,
#  'volver': <gensim.models.keyedvectors.Vocab at 0x7f5854d1fdd8>,
#  'revision': <gensim.models.keyedvectors.Vocab at 0x7f5854d1fe10>,
#  'glucosa': <gensim.models.keyedvectors.Vocab at 0x7f5854d1fe80>,
#  'presenta': <gensim.models.keyedvectors.Vocab at 0x7f5854d1fef0>,
#  'leve': <gensim.models.keyedvectors.Vocab at 0x7f5854d1ff28>,
#  'fc': <gensim.models.keyedvectors.Vocab at 0x7f588d17f5f8>,
#  'megalias': <gensim.models.keyedvectors.Vocab at 0x7f588d17fef0>,
#  'paracetamol': <gensim.models.keyedvectors.Vocab at 0x7f588d17f6d8>,
#  'nc': <gensim.models.keyedvectors.Vocab at 0x7f588d17ff60>,
#  'ruidos': <gensim.models.keyedvectors.Vocab at 0x7f5854d200b8>,
#  'peritoneal': <gensim.models.keyedvectors.Vocab at 0x7f5854d20198>,
#  'mejoria': <gensim.models.keyedvectors.Vocab at 0x7f5854d202b0>,
#  'orl': <gensim.models.keyedvectors.Vocab at 0x7f5854d203c8>,
#  'cuadro': <gensim.models.keyedvectors.Vocab at 0x7f5854d204e0>,
#  '37': <gensim.models.keyedvectors.Vocab at 0x7f5854d20630>,
#  'alta': <gensim.models.keyedvectors.Vocab at 0x7f5854d20710>,
#  '9/l': <gensim.models.keyedvectors.Vocab at 0x7f5854d20860>,
#  'piel': <gensim.models.keyedvectors.Vocab at 0x7f5854d20940>,
#  'nolotil': <gensim.models.keyedvectors.Vocab at 0x7f5854d20ac8>,
#  'alteraciones': <gensim.models.keyedvectors.Vocab at 0x7f5854d20ba8>,
#  'tipo': <gensim.models.keyedvectors.Vocab at 0x7f5854d20c88>,
#  'tto': <gensim.models.keyedvectors.Vocab at 0x7f5854d20d68>,
#  'enantyum': <gensim.models.keyedvectors.Vocab at 0x7f5854d20da0>,
#  'lesiones': <gensim.models.keyedvectors.Vocab at 0x7f5854d20e48>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x7f5854d20fd0>,
#  'irritacion': <gensim.models.keyedvectors.Vocab at 0x7f5854d20e80>,
#  'normales': <gensim.models.keyedvectors.Vocab at 0x7f5854d23198>,
#  'consciente': <gensim.models.keyedvectors.Vocab at 0x7f5854d231d0>,
#  'aguda': <gensim.models.keyedvectors.Vocab at 0x7f5854d232b0>,
#  'meses': <gensim.models.keyedvectors.Vocab at 0x7f5854d23358>,
#  'orina': <gensim.models.keyedvectors.Vocab at 0x7f5854d23470>,
#  'tos': <gensim.models.keyedvectors.Vocab at 0x7f5854d23550>,
#  'antecedentes': <gensim.models.keyedvectors.Vocab at 0x7f5854d235f8>,
#  'omeprazol': <gensim.models.keyedvectors.Vocab at 0x7f5854d23630>,
#  'pie': <gensim.models.keyedvectors.Vocab at 0x7f5854d236a0>,
#  'pcr': <gensim.models.keyedvectors.Vocab at 0x7f5854d23780>,
#  'buena': <gensim.models.keyedvectors.Vocab at 0x7f5854d23828>,
#  'fractura': <gensim.models.keyedvectors.Vocab at 0x7f5854d23898>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x7f5854d23908>,
#  'rodilla': <gensim.models.keyedvectors.Vocab at 0x7f5854d23978>,
#  'mano': <gensim.models.keyedvectors.Vocab at 0x7f5854d23a20>,
#  'edemas': <gensim.models.keyedvectors.Vocab at 0x7f5854d23ac8>,
#  'mañana': <gensim.models.keyedvectors.Vocab at 0x7f5854d23b00>,
#  '38': <gensim.models.keyedvectors.Vocab at 0x7f5854d23b70>,
#  'dedo': <gensim.models.keyedvectors.Vocab at 0x7f5854d23c88>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x7f5854d23d68>,
#  'hb': <gensim.models.keyedvectors.Vocab at 0x7f5854d23e10>,
#  'observacion': <gensim.models.keyedvectors.Vocab at 0x7f5854d23e48>,
#  'peso': <gensim.models.keyedvectors.Vocab at 0x7f5854d23f60>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x7f5854d23fd0>,
#  'nauseas': <gensim.models.keyedvectors.Vocab at 0x7f5854d27160>,
#  'servicio': <gensim.models.keyedvectors.Vocab at 0x7f5854d27358>,
#  'ibuprofeno': <gensim.models.keyedvectors.Vocab at 0x7f5854d27390>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x7f5854d27588>,
#  'sintomatologia': <gensim.models.keyedvectors.Vocab at 0x7f5854d27710>,
#  'consultar': <gensim.models.keyedvectors.Vocab at 0x7f5854d27748>,
#  '35': <gensim.models.keyedvectors.Vocab at 0x7f5854d27908>,
#  'comp': <gensim.models.keyedvectors.Vocab at 0x7f5854d27b38>,
#  'sd': <gensim.models.keyedvectors.Vocab at 0x7f5854d27c50>,
#  'comprimido': <gensim.models.keyedvectors.Vocab at 0x7f5854d27cc0>,
#  'dieta': <gensim.models.keyedvectors.Vocab at 0x7f5854d27dd8>,
#  'nh': <gensim.models.keyedvectors.Vocab at 0x7f5854d27e80>,
#  'eupneico': <gensim.models.keyedvectors.Vocab at 0x7f5854d27eb8>,
#  'toracico': <gensim.models.keyedvectors.Vocab at 0x7f5854d27f60>,
#  'renal': <gensim.models.keyedvectors.Vocab at 0x7f5854d27fd0>,
#  'cronica': <gensim.models.keyedvectors.Vocab at 0x7f5854d29080>,
#  'sindrome': <gensim.models.keyedvectors.Vocab at 0x7f5854d290b8>,
#  '1/2': <gensim.models.keyedvectors.Vocab at 0x7f5854d29240>,
#  'oral': <gensim.models.keyedvectors.Vocab at 0x7f5854d29320>,
#  'mmii': <gensim.models.keyedvectors.Vocab at 0x7f5854d29438>,
#  'eupneica': <gensim.models.keyedvectors.Vocab at 0x7f5854d294a8>,
#  'adjunta': <gensim.models.keyedvectors.Vocab at 0x7f5854d29550>,
#  'cervical': <gensim.models.keyedvectors.Vocab at 0x7f5854d29588>,
#  'creatinina': <gensim.models.keyedvectors.Vocab at 0x7f5854d295f8>,
#  'conservado': <gensim.models.keyedvectors.Vocab at 0x7f5854d29630>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7f5854d296a0>,
#  'zona': <gensim.models.keyedvectors.Vocab at 0x7f5854d29748>,
#  'ph': <gensim.models.keyedvectors.Vocab at 0x7f5854d297f0>,
#  '13': <gensim.models.keyedvectors.Vocab at 0x7f5854d29898>,
#  '80': <gensim.models.keyedvectors.Vocab at 0x7f5854d29908>,
#  'ayer': <gensim.models.keyedvectors.Vocab at 0x7f5854d299b0>,
#  'patologicos': <gensim.models.keyedvectors.Vocab at 0x7f5854d299e8>,
#  'meq/l': <gensim.models.keyedvectors.Vocab at 0x7f5854d29b00>,
#  'tobillo': <gensim.models.keyedvectors.Vocab at 0x7f5854d29c18>,
#  'mas': <gensim.models.keyedvectors.Vocab at 0x7f5854d29d30>,
#  'mujer': <gensim.models.keyedvectors.Vocab at 0x7f5854d29e80>,
#  'inr': <gensim.models.keyedvectors.Vocab at 0x7f5854d29f60>,
#  'lumbar': <gensim.models.keyedvectors.Vocab at 0x7f5854d2b080>,
#  'liquidos': <gensim.models.keyedvectors.Vocab at 0x7f5854d2b0f0>,
#  'sodio': <gensim.models.keyedvectors.Vocab at 0x7f5854d2b198>,
#  'respiratoria': <gensim.models.keyedvectors.Vocab at 0x7f5854d2b1d0>,
#  'empeoramiento': <gensim.models.keyedvectors.Vocab at 0x7f5854d2b2b0>,
#  'presentar': <gensim.models.keyedvectors.Vocab at 0x7f5854d2b2e8>,
#  'estudio': <gensim.models.keyedvectors.Vocab at 0x7f5854d2b390>,
#  '14': <gensim.models.keyedvectors.Vocab at 0x7f5854d2b470>,
#  'primaria': <gensim.models.keyedvectors.Vocab at 0x7f5854d2b550>,
#  'p': <gensim.models.keyedvectors.Vocab at 0x7f5854d2b588>,
#  'iv': <gensim.models.keyedvectors.Vocab at 0x7f5854d2b668>,
#  'semanas': <gensim.models.keyedvectors.Vocab at 0x7f5854d2b780>,
#  'contusion': <gensim.models.keyedvectors.Vocab at 0x7f5854d2b860>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x7f5854d2b898>,
#  'sat': <gensim.models.keyedvectors.Vocab at 0x7f5854d2b940>,
#  'pediatra': <gensim.models.keyedvectors.Vocab at 0x7f5854d2b978>,
#  'semana': <gensim.models.keyedvectors.Vocab at 0x7f5854d2ba20>,
#  'alergias': <gensim.models.keyedvectors.Vocab at 0x7f5854d2ba58>,
#  'potasio': <gensim.models.keyedvectors.Vocab at 0x7f5854d2bb00>,
#  'abundantes': <gensim.models.keyedvectors.Vocab at 0x7f5854d2bb38>,
#  'atencion': <gensim.models.keyedvectors.Vocab at 0x7f5854d2bb70>,
#  'vesicular': <gensim.models.keyedvectors.Vocab at 0x7f5854d2bbe0>,
#  'plaquetas': <gensim.models.keyedvectors.Vocab at 0x7f5854d2bc18>,
#  'hemograma': <gensim.models.keyedvectors.Vocab at 0x7f5854d2bcf8>,
#  'hoy': <gensim.models.keyedvectors.Vocab at 0x7f5854d2be48>,
#  'exploracion': <gensim.models.keyedvectors.Vocab at 0x7f5854d2be80>,
#  'murmullo': <gensim.models.keyedvectors.Vocab at 0x7f5854d2bf98>,
#  'diarrea': <gensim.models.keyedvectors.Vocab at 0x7f5854d2bfd0>,
#  'disnea': <gensim.models.keyedvectors.Vocab at 0x7f5854d2f278>,
#  'madre': <gensim.models.keyedvectors.Vocab at 0x7f5854d2f390>,
#  'traumatismo': <gensim.models.keyedvectors.Vocab at 0x7f5854d2f3c8>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x7f5854d2f4e0>,
#  'perdida': <gensim.models.keyedvectors.Vocab at 0x7f5854d2f588>,
#  's': <gensim.models.keyedvectors.Vocab at 0x7f5854d2f5f8>,
#  '75': <gensim.models.keyedvectors.Vocab at 0x7f5854d2f6d8>,
#  'informe': <gensim.models.keyedvectors.Vocab at 0x7f5854d2f780>,
#  'sangre': <gensim.models.keyedvectors.Vocab at 0x7f5854d2f7f0>,
#  'cefalea': <gensim.models.keyedvectors.Vocab at 0x7f5854d2f860>,
#  'administra': <gensim.models.keyedvectors.Vocab at 0x7f5854d2f898>,
#  'aumento': <gensim.models.keyedvectors.Vocab at 0x7f5854d2f978>,
#  'sensacion': <gensim.models.keyedvectors.Vocab at 0x7f5854d2f9e8>,
#  'o2': <gensim.models.keyedvectors.Vocab at 0x7f5854d2fa90>,
#  'fuerza': <gensim.models.keyedvectors.Vocab at 0x7f5854d2fb00>,
#  'focalidad': <gensim.models.keyedvectors.Vocab at 0x7f5854d2fb38>,
#  'segun': <gensim.models.keyedvectors.Vocab at 0x7f5854d2fbe0>,
#  'niega': <gensim.models.keyedvectors.Vocab at 0x7f5854d2fd30>,
#  'probable': <gensim.models.keyedvectors.Vocab at 0x7f5854d2fe10>,
#  'conservada': <gensim.models.keyedvectors.Vocab at 0x7f5854d2fe48>,
#  '16': <gensim.models.keyedvectors.Vocab at 0x7f5854d2ff60>,
#  'ambos': <gensim.models.keyedvectors.Vocab at 0x7f5854cb30b8>,
#  'precisa': <gensim.models.keyedvectors.Vocab at 0x7f5854cb31d0>,
#  'insuficiencia': <gensim.models.keyedvectors.Vocab at 0x7f5854cb32b0>,
#  '60': <gensim.models.keyedvectors.Vocab at 0x7f5854cb3390>,
#  'dos': <gensim.models.keyedvectors.Vocab at 0x7f5854cb3470>,
#  'clinica': <gensim.models.keyedvectors.Vocab at 0x7f5854cb3550>,
#  'coagulacion': <gensim.models.keyedvectors.Vocab at 0x7f5854cb3588>,
#  'izq': <gensim.models.keyedvectors.Vocab at 0x7f5854cb3710>,
#  'varon': <gensim.models.keyedvectors.Vocab at 0x7f5854cb3828>,
#  'centro': <gensim.models.keyedvectors.Vocab at 0x7f5854cb38d0>,
#  'protrombina': <gensim.models.keyedvectors.Vocab at 0x7f5854cb39b0>,
#  'k': <gensim.models.keyedvectors.Vocab at 0x7f5854cb39e8>,
#  'pendiente': <gensim.models.keyedvectors.Vocab at 0x7f5854cb3a90>,
#  '70': <gensim.models.keyedvectors.Vocab at 0x7f5854cb3b70>,
#  'hallazgos': <gensim.models.keyedvectors.Vocab at 0x7f5854cb3ba8>,
#  'bioquimica': <gensim.models.keyedvectors.Vocab at 0x7f5854cb3c88>,
#  'na': <gensim.models.keyedvectors.Vocab at 0x7f5854cb3d30>,
#  'mareo': <gensim.models.keyedvectors.Vocab at 0x7f5854cb3e10>,
#  'izda': <gensim.models.keyedvectors.Vocab at 0x7f5854cb3eb8>,
#  'meningeos': <gensim.models.keyedvectors.Vocab at 0x7f5854cb3ef0>,
#  'simetricos': <gensim.models.keyedvectors.Vocab at 0x7f5854cb3f28>,
#  'hernia': <gensim.models.keyedvectors.Vocab at 0x7f5854cb3f60>,
#  'orientado': <gensim.models.keyedvectors.Vocab at 0x7f5854cb50f0>,
#  'seg': <gensim.models.keyedvectors.Vocab at 0x7f5854cb51d0>,
#  'pulsos': <gensim.models.keyedvectors.Vocab at 0x7f5854cb5278>,
#  '600': <gensim.models.keyedvectors.Vocab at 0x7f5854cb5390>,
#  'mucosas': <gensim.models.keyedvectors.Vocab at 0x7f5854cb5438>,
#  'domiciliaria': <gensim.models.keyedvectors.Vocab at 0x7f5854cb54a8>,
#  '48': <gensim.models.keyedvectors.Vocab at 0x7f5854cb5588>,
#  'izdo': <gensim.models.keyedvectors.Vocab at 0x7f5854cb55f8>,
#  'infeccion': <gensim.models.keyedvectors.Vocab at 0x7f5854cb5630>,
#  'continuar': <gensim.models.keyedvectors.Vocab at 0x7f5854cb56d8>,
#  'herida': <gensim.models.keyedvectors.Vocab at 0x7f5854cb57f0>,
#  'hidratacion': <gensim.models.keyedvectors.Vocab at 0x7f5854cb5828>,
#  'coloracion': <gensim.models.keyedvectors.Vocab at 0x7f5854cb58d0>,
#  'orientada': <gensim.models.keyedvectors.Vocab at 0x7f5854cb5908>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x7f5854cb59e8>,
#  '500': <gensim.models.keyedvectors.Vocab at 0x7f5854cb5ac8>,
#  'leucos': <gensim.models.keyedvectors.Vocab at 0x7f5854cb5b70>,
#  'colico': <gensim.models.keyedvectors.Vocab at 0x7f5854cb5cc0>,
#  'sintomas': <gensim.models.keyedvectors.Vocab at 0x7f5854cb5d68>,
#  'crisis': <gensim.models.keyedvectors.Vocab at 0x7f5854cb5e10>,
#  'murphy': <gensim.models.keyedvectors.Vocab at 0x7f5854cb5e80>,
#  'previos': <gensim.models.keyedvectors.Vocab at 0x7f5854cb5fd0>,
#  'cita': <gensim.models.keyedvectors.Vocab at 0x7f5854cb90f0>,
#  'abundante': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9128>,
#  'embarazo': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9208>,
#  'relativo': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9240>,
#  'valoracion': <gensim.models.keyedvectors.Vocab at 0x7f5854cb92e8>,
#  'edema': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9390>,
#  '39': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9470>,
#  'ml': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9550>,
#  'calor': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9630>,
#  'repolarizacion': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9668>,
#  'alteracion': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9748>,
#  'conocidas': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9780>,
#  'neutrofilos': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9898>,
#  'blumberg': <gensim.models.keyedvectors.Vocab at 0x7f5854cb98d0>,
#  'muñeca': <gensim.models.keyedvectors.Vocab at 0x7f5854cb99b0>,
#  'amc': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9ac8>,
#  'bien': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9be0>,
#  'edad': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9cf8>,
#  'alergia': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9dd8>,
#  'presentes': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9e10>,
#  'augmentine': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9f28>,
#  '/': <gensim.models.keyedvectors.Vocab at 0x7f5854cb9f60>,
#  'noche': <gensim.models.keyedvectors.Vocab at 0x7f5854cbb080>,
#  'salud': <gensim.models.keyedvectors.Vocab at 0x7f5854cbb128>,
#  'cuello': <gensim.models.keyedvectors.Vocab at 0x7f5854cbb278>,
#  'hematies': <gensim.models.keyedvectors.Vocab at 0x7f5854cbb320>,
#  'ojo': <gensim.models.keyedvectors.Vocab at 0x7f5854cbb438>,
#  'adecuada': <gensim.models.keyedvectors.Vocab at 0x7f5854cbb470>,
#  'itu': <gensim.models.keyedvectors.Vocab at 0x7f5854cbb588>,
#  'neurologica': <gensim.models.keyedvectors.Vocab at 0x7f5854cbb668>,
#  'sinusal': <gensim.models.keyedvectors.Vocab at 0x7f5854cbb780>,
#  '32': <gensim.models.keyedvectors.Vocab at 0x7f5854cbb860>,
#  'sedimento': <gensim.models.keyedvectors.Vocab at 0x7f5854cbb898>,
#  'empeora': <gensim.models.keyedvectors.Vocab at 0x7f5854cbb978>,
#  'grado': <gensim.models.keyedvectors.Vocab at 0x7f5854cbba90>,
#  'ritmo': <gensim.models.keyedvectors.Vocab at 0x7f5854cbbba8>,
#  'hombro': <gensim.models.keyedvectors.Vocab at 0x7f5854cbbc88>,
#  'campo': <gensim.models.keyedvectors.Vocab at 0x7f5854cbbd68>,
#  'posterior': <gensim.models.keyedvectors.Vocab at 0x7f5854cbbdd8>,
#  'venosa': <gensim.models.keyedvectors.Vocab at 0x7f5854cbbeb8>,
#  'sensibilidad': <gensim.models.keyedvectors.Vocab at 0x7f5854cbbef0>,
#  'hematoma': <gensim.models.keyedvectors.Vocab at 0x7f5854cbbf98>,
#  'padre': <gensim.models.keyedvectors.Vocab at 0x7f5854cbbfd0>,
#  'actividad': <gensim.models.keyedvectors.Vocab at 0x7f5854cbd128>,
#  'fumador': <gensim.models.keyedvectors.Vocab at 0x7f5854cbd208>,
#  'im': <gensim.models.keyedvectors.Vocab at 0x7f5854cbd2b0>,
#  'medicamentosas': <gensim.models.keyedvectors.Vocab at 0x7f5854cbd320>,
#  '400': <gensim.models.keyedvectors.Vocab at 0x7f5854cbd390>,
#  'episodio': <gensim.models.keyedvectors.Vocab at 0x7f5854cbd3c8>,
#  'patologia': <gensim.models.keyedvectors.Vocab at 0x7f5854cbd438>,
#  'cardiopatia': <gensim.models.keyedvectors.Vocab at 0x7f5854cbd470>,
#  'lesion': <gensim.models.keyedvectors.Vocab at 0x7f5854cbd550>,
#  'negativos': <gensim.models.keyedvectors.Vocab at 0x7f5854cbd5f8>,
#  'buscapina': <gensim.models.keyedvectors.Vocab at 0x7f5854cbd630>,
#  'enfermedades': <gensim.models.keyedvectors.Vocab at 0x7f5854cbd748>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x7f5854cbd860>,
#  'tamaño': <gensim.models.keyedvectors.Vocab at 0x7f5854cbd898>,
#  '5mg': <gensim.models.keyedvectors.Vocab at 0x7f5854cbd940>,
#  'ingesta': <gensim.models.keyedvectors.Vocab at 0x7f5854cbda20>,
#  'ingresos': <gensim.models.keyedvectors.Vocab at 0x7f5854cbda58>,
#  'habitual': <gensim.models.keyedvectors.Vocab at 0x7f5854cbda90>,
#  'costal': <gensim.models.keyedvectors.Vocab at 0x7f5854cbdc50>,
#  'ritmica': <gensim.models.keyedvectors.Vocab at 0x7f5854cbddd8>,
#  'inflamacion': <gensim.models.keyedvectors.Vocab at 0x7f5854cbdef0>,
#  'sangrado': <gensim.models.keyedvectors.Vocab at 0x7f5854cbdf28>,
#  'molestias': <gensim.models.keyedvectors.Vocab at 0x7f5854cbdda0>,
#  'farmacos': <gensim.models.keyedvectors.Vocab at 0x7f5854cc30b8>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x7f5854cc3208>,
#  'tonos': <gensim.models.keyedvectors.Vocab at 0x7f5854cc3400>,
#  'miccional': <gensim.models.keyedvectors.Vocab at 0x7f5854cc3588>,
#  'ttpa': <gensim.models.keyedvectors.Vocab at 0x7f5854cc36d8>,
#  'glasgow': <gensim.models.keyedvectors.Vocab at 0x7f5854cc3780>,
#  'caida': <gensim.models.keyedvectors.Vocab at 0x7f5854cc3828>,
#  'kg': <gensim.models.keyedvectors.Vocab at 0x7f5854cc3908>,
#  'dificultad': <gensim.models.keyedvectors.Vocab at 0x7f5854cc3940>,
#  'cabecera': <gensim.models.keyedvectors.Vocab at 0x7f5854cc3a20>,
#  'gea': <gensim.models.keyedvectors.Vocab at 0x7f5854cc3b38>,
#  '20mg': <gensim.models.keyedvectors.Vocab at 0x7f5854cc3c18>,
#  'nitritos': <gensim.models.keyedvectors.Vocab at 0x7f5854cc3c50>,
#  '90': <gensim.models.keyedvectors.Vocab at 0x7f5854cc3d68>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x7f5854cc3e48>,
#  '136': <gensim.models.keyedvectors.Vocab at 0x7f5854cc3eb8>,
#  'parto': <gensim.models.keyedvectors.Vocab at 0x7f5854cc3f60>,
#  'tomar': <gensim.models.keyedvectors.Vocab at 0x7f5854cc3fd0>,
#  'ii': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5080>,
#  'febril': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5128>,
#  'reacciones': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5160>,
#  'mes': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5208>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5278>,
#  'lumbalgia': <gensim.models.keyedvectors.Vocab at 0x7f5854cc52b0>,
#  'nasal': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5320>,
#  'blanda': <gensim.models.keyedvectors.Vocab at 0x7f5854cc53c8>,
#  'inferior': <gensim.models.keyedvectors.Vocab at 0x7f5854cc54a8>,
#  '28': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5588>,
#  'cara': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5710>,
#  'anterior': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5748>,
#  'observa': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5898>,
#  'inguinal': <gensim.models.keyedvectors.Vocab at 0x7f5854cc59b0>,
#  'negativa': <gensim.models.keyedvectors.Vocab at 0x7f5854cc59e8>,
#  'mfyc': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5a90>,
#  'distal': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5b70>,
#  'calculada': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5be0>,
#  '74': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5cc0>,
#  'creat': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5dd8>,
#  '43': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5e80>,
#  'mmhg': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5f98>,
#  'ritmicos': <gensim.models.keyedvectors.Vocab at 0x7f5854cc5fd0>,
#  'familia': <gensim.models.keyedvectors.Vocab at 0x7f5854cc8160>,
#  'apiretal': <gensim.models.keyedvectors.Vocab at 0x7f5854cc81d0>,
#  'cabeza': <gensim.models.keyedvectors.Vocab at 0x7f5854cc8278>,
#  'cirugia': <gensim.models.keyedvectors.Vocab at 0x7f5854cc82e8>,
#  'bronquitis': <gensim.models.keyedvectors.Vocab at 0x7f5854cc8320>,
#  'pa': <gensim.models.keyedvectors.Vocab at 0x7f5854cc83c8>,
#  'dalsy': <gensim.models.keyedvectors.Vocab at 0x7f5854cc84a8>,
#  'acudir': <gensim.models.keyedvectors.Vocab at 0x7f5854cc8550>,
#  'reactiva': <gensim.models.keyedvectors.Vocab at 0x7f5854cc8588>,
#  'ninguno': <gensim.models.keyedvectors.Vocab at 0x7f5854cc8668>,
#  'normocoloreada': <gensim.models.keyedvectors.Vocab at 0x7f5854cc86a0>,
#  'heces': <gensim.models.keyedvectors.Vocab at 0x7f5854cc8748>,
#  'h': <gensim.models.keyedvectors.Vocab at 0x7f5854cc87f0>,
#  'pares': <gensim.models.keyedvectors.Vocab at 0x7f5854cc88d0>,
#  'posible': <gensim.models.keyedvectors.Vocab at 0x7f5854cc8978>,
#  'analitica': <gensim.models.keyedvectors.Vocab at 0x7f5854cc89b0>,
#  '22': <gensim.models.keyedvectors.Vocab at 0x7f5854cc8a58>,
#  'via': <gensim.models.keyedvectors.Vocab at 0x7f5854cc8b00>,
#  'cm': <gensim.models.keyedvectors.Vocab at 0x7f5854cc8be0>,
#  'trauma': <gensim.models.keyedvectors.Vocab at 0x7f5854cc8da0>,
#  'conservados': <gensim.models.keyedvectors.Vocab at 0x7f5854cc8eb8>,
#  'pulmonar': <gensim.models.keyedvectors.Vocab at 0x7f5854cc8ef0>,
#  'hipogastrio': <gensim.models.keyedvectors.Vocab at 0x7f5854cc8d68>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x7f5854ccc080>,
#  'bilirrubina': <gensim.models.keyedvectors.Vocab at 0x7f5854ccc128>,
#  'hemoglobina': <gensim.models.keyedvectors.Vocab at 0x7f5854ccc160>,
#  'gr': <gensim.models.keyedvectors.Vocab at 0x7f5854ccc2b0>,
#  'deposiciones': <gensim.models.keyedvectors.Vocab at 0x7f5854ccc390>,
#  'ecg': <gensim.models.keyedvectors.Vocab at 0x7f5854ccc518>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x7f5854ccc668>,
#  'bq': <gensim.models.keyedvectors.Vocab at 0x7f5854ccc780>,
#  'osmolalidad': <gensim.models.keyedvectors.Vocab at 0x7f5854ccc7b8>,
#  'arterial': <gensim.models.keyedvectors.Vocab at 0x7f5854ccc828>,
#  'movilidad': <gensim.models.keyedvectors.Vocab at 0x7f5854ccc860>,
#  'enfermedad': <gensim.models.keyedvectors.Vocab at 0x7f5854ccc940>,
#  'simple': <gensim.models.keyedvectors.Vocab at 0x7f5854ccca20>,
#  '200': <gensim.models.keyedvectors.Vocab at 0x7f5854cccac8>,
#  'media': <gensim.models.keyedvectors.Vocab at 0x7f5854cccba8>,
#  'rs': <gensim.models.keyedvectors.Vocab at 0x7f5854cccc50>,
#  '26': <gensim.models.keyedvectors.Vocab at 0x7f5854ccccc0>,
#  'intestinal': <gensim.models.keyedvectors.Vocab at 0x7f5854ccccf8>,
#  'anemia': <gensim.models.keyedvectors.Vocab at 0x7f5854ccce10>,
#  'liquido': <gensim.models.keyedvectors.Vocab at 0x7f5854ccceb8>,
#  'activo': <gensim.models.keyedvectors.Vocab at 0x7f5854cccf28>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7f5854cccfd0>,
#  'normocoloreado': <gensim.models.keyedvectors.Vocab at 0x7f5854ccd128>,
#  'tce': <gensim.models.keyedvectors.Vocab at 0x7f5854ccd240>,
#  'cuerpo': <gensim.models.keyedvectors.Vocab at 0x7f5854ccd2e8>,
#  'neonatal': <gensim.models.keyedvectors.Vocab at 0x7f5854ccd320>,
#  'hiperemia': <gensim.models.keyedvectors.Vocab at 0x7f5854ccd3c8>,
#  'eeii': <gensim.models.keyedvectors.Vocab at 0x7f5854ccd4a8>,
#  'seco': <gensim.models.keyedvectors.Vocab at 0x7f5854ccd588>,
#  'proteinas': <gensim.models.keyedvectors.Vocab at 0x7f5854ccd5c0>,
#  'forma': <gensim.models.keyedvectors.Vocab at 0x7f5854ccd6a0>,
#  'episodios': <gensim.models.keyedvectors.Vocab at 0x7f5854ccd748>,
#  'defensa': <gensim.models.keyedvectors.Vocab at 0x7f5854ccd860>,
#  'fur': <gensim.models.keyedvectors.Vocab at 0x7f5854ccd940>,
#  'byd': <gensim.models.keyedvectors.Vocab at 0x7f5854ccd9b0>,
#  'consultas': <gensim.models.keyedvectors.Vocab at 0x7f5854ccd9e8>,
#  'cadera': <gensim.models.keyedvectors.Vocab at 0x7f5854ccdac8>,
#  'sn': <gensim.models.keyedvectors.Vocab at 0x7f5854ccdb38>,
#  'pasa': <gensim.models.keyedvectors.Vocab at 0x7f5854ccdc18>,
#  'actualmente': <gensim.models.keyedvectors.Vocab at 0x7f5854ccdc88>,
#  'depresivo': <gensim.models.keyedvectors.Vocab at 0x7f5854ccdcc0>,
#  'frcv': <gensim.models.keyedvectors.Vocab at 0x7f5854ccdd68>,
#  'adiro': <gensim.models.keyedvectors.Vocab at 0x7f5854ccde10>,
#  'inespecifico': <gensim.models.keyedvectors.Vocab at 0x7f5854ccdeb8>,
#  'lateral': <gensim.models.keyedvectors.Vocab at 0x7f5854ccdfd0>,
#  'previo': <gensim.models.keyedvectors.Vocab at 0x7f5854cd10b8>,
#  'extremidades': <gensim.models.keyedvectors.Vocab at 0x7f5854cd10f0>,
#  'toma': <gensim.models.keyedvectors.Vocab at 0x7f5854cd11d0>,
#  'oseas': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1240>,
#  'epoc': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1320>,
#  'alternar': <gensim.models.keyedvectors.Vocab at 0x7f5854cd13c8>,
#  'petequias': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1400>,
#  'observan': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1470>,
#  'calendario': <gensim.models.keyedvectors.Vocab at 0x7f5854cd14a8>,
#  'densidad': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1518>,
#  'moderada': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1550>,
#  'sintrom': <gensim.models.keyedvectors.Vocab at 0x7f5854cd15f8>,
#  'hto': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1710>,
#  'movimientos': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1780>,
#  'pco2': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1860>,
#  'vaginal': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1908>,
#  'condensaciones': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1940>,
#  'fa': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1a20>,
#  'materna': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1ac8>,
#  'vacunal': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1be0>,
#  'dislipemia': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1cc0>,
#  'funcional': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1cf8>,
#  'contractura': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1e10>,
#  'alimentacion': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1e48>,
#  'fibrinogeno': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1eb8>,
#  'ventolin': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1ef0>,
#  'medio': <gensim.models.keyedvectors.Vocab at 0x7f5854cd1fd0>,
#  '34': <gensim.models.keyedvectors.Vocab at 0x7f5854cd4160>,
#  'infiltrados': <gensim.models.keyedvectors.Vocab at 0x7f5854cd4208>,
#  'g/dl': <gensim.models.keyedvectors.Vocab at 0x7f5854cd42e8>,
#  'ventilacion': <gensim.models.keyedvectors.Vocab at 0x7f5854cd4320>,
#  'medicacion': <gensim.models.keyedvectors.Vocab at 0x7f5854cd43c8>,
#  'mecanica': <gensim.models.keyedvectors.Vocab at 0x7f5854cd4400>,
#  'controlado': <gensim.models.keyedvectors.Vocab at 0x7f5854cd4470>,
#  'normohidratada': <gensim.models.keyedvectors.Vocab at 0x7f5854cd44a8>,
#  '95': <gensim.models.keyedvectors.Vocab at 0x7f5854cd4550>,
#  'cesarea': <gensim.models.keyedvectors.Vocab at 0x7f5854cd45f8>,
#  'tres': <gensim.models.keyedvectors.Vocab at 0x7f5854cd46a0>,
#  'agua': <gensim.models.keyedvectors.Vocab at 0x7f5854cd4828>,
#  '98': <gensim.models.keyedvectors.Vocab at 0x7f5854cd4908>,
#  'imagenes': <gensim.models.keyedvectors.Vocab at 0x7f5854cd4a20>,
#  'tac': <gensim.models.keyedvectors.Vocab at 0x7f5854cd4b70>,
#  '33': <gensim.models.keyedvectors.Vocab at 0x7f5854cd4c50>,
#  'habito': <gensim.models.keyedvectors.Vocab at 0x7f5854cd4cf8>,
#  'asma': <gensim.models.keyedvectors.Vocab at 0x7f5854cd4dd8>,
#  'vacunacion': <gensim.models.keyedvectors.Vocab at 0x7f5854cd4e10>,
#  'mucosidad': <gensim.models.keyedvectors.Vocab at 0x7f5854cd4ef0>,
#  'cardiaca': <gensim.models.keyedvectors.Vocab at 0x7f5854cd4f28>,
#  '23': <gensim.models.keyedvectors.Vocab at 0x7f5854cd6080>,
#  'varios': <gensim.models.keyedvectors.Vocab at 0x7f5854cd6198>,
#  'nueva': <gensim.models.keyedvectors.Vocab at 0x7f5854cd6278>,
#  'alergica': <gensim.models.keyedvectors.Vocab at 0x7f5854cd6358>,
#  'valorar': <gensim.models.keyedvectors.Vocab at 0x7f5854cd6438>,
#  '27': <gensim.models.keyedvectors.Vocab at 0x7f5854cd6550>,
#  'aprecia': <gensim.models.keyedvectors.Vocab at 0x7f5854cd65f8>,
#  'ppr': <gensim.models.keyedvectors.Vocab at 0x7f5854cd66d8>,
#  'sato2': <gensim.models.keyedvectors.Vocab at 0x7f5854cd67f0>,
#  'codo': <gensim.models.keyedvectors.Vocab at 0x7f5854cd6908>,
#  'sb': <gensim.models.keyedvectors.Vocab at 0x7f5854cd69e8>,
#  'repeticion': <gensim.models.keyedvectors.Vocab at 0x7f5854cd6a20>,
#  'ng/ml': <gensim.models.keyedvectors.Vocab at 0x7f5854cd6ac8>,
#  '21': <gensim.models.keyedvectors.Vocab at 0x7f5854cd6b70>,
#  'superior': <gensim.models.keyedvectors.Vocab at 0x7f5854cd6be0>,
#  'biliar': <gensim.models.keyedvectors.Vocab at 0x7f5854cd6c88>,
#  '8h': <gensim.models.keyedvectors.Vocab at 0x7f5854cd6d30>,
#  'inicio': <gensim.models.keyedvectors.Vocab at 0x7f5854cd6ef0>,
#  'vesical': <gensim.models.keyedvectors.Vocab at 0x7f5854cd6f28>,
#  'previas': <gensim.models.keyedvectors.Vocab at 0x7f5854cdb0f0>,
#  '01': <gensim.models.keyedvectors.Vocab at 0x7f5854cdb208>,
#  'vida': <gensim.models.keyedvectors.Vocab at 0x7f5854cdb2e8>,
#  'pierna': <gensim.models.keyedvectors.Vocab at 0x7f5854cdb390>,
#  'ultima': <gensim.models.keyedvectors.Vocab at 0x7f5854cdb470>,
#  '45': <gensim.models.keyedvectors.Vocab at 0x7f5854cdb550>,
#  'cambios': <gensim.models.keyedvectors.Vocab at 0x7f5854cdb5f8>,
#  'intenso': <gensim.models.keyedvectors.Vocab at 0x7f5854cdb6a0>,
#  'muscular': <gensim.models.keyedvectors.Vocab at 0x7f5854cdb6d8>,
#  'profunda': <gensim.models.keyedvectors.Vocab at 0x7f5854cdb710>,
#  'ansiedad': <gensim.models.keyedvectors.Vocab at 0x7f5854cdb748>,
#  'realiza': <gensim.models.keyedvectors.Vocab at 0x7f5854cdb828>,
#  'fracturas': <gensim.models.keyedvectors.Vocab at 0x7f5854cdb860>,
#  'hco3': <gensim.models.keyedvectors.Vocab at 0x7f5854cdb940>,
#  'glu': <gensim.models.keyedvectors.Vocab at 0x7f5854cdba20>,
#  'craneales': <gensim.models.keyedvectors.Vocab at 0x7f5854cdba58>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x7f5854cdba90>,
#  'severa': <gensim.models.keyedvectors.Vocab at 0x7f5854cdbb38>,
#  'sistema': <gensim.models.keyedvectors.Vocab at 0x7f5854cdbbe0>,
#  'cardiologia': <gensim.models.keyedvectors.Vocab at 0x7f5854cdbc18>,
#  'nuevo': <gensim.models.keyedvectors.Vocab at 0x7f5854cdbc88>,
#  'craneo': <gensim.models.keyedvectors.Vocab at 0x7f5854cdbd30>,
#  'epigastrio': <gensim.models.keyedvectors.Vocab at 0x7f5854cdbd68>,
#  'marcha': <gensim.models.keyedvectors.Vocab at 0x7f5854cdbe10>,
#  '31': <gensim.models.keyedvectors.Vocab at 0x7f5854cdbf28>,
#  'veces': <gensim.models.keyedvectors.Vocab at 0x7f5854cdbf60>,
#  'estreñimiento': <gensim.models.keyedvectors.Vocab at 0x7f5854cdd0b8>,
#  'l': <gensim.models.keyedvectors.Vocab at 0x7f5854cdd128>,
#  '1g': <gensim.models.keyedvectors.Vocab at 0x7f5854cdd1d0>,
#  'pulso': <gensim.models.keyedvectors.Vocab at 0x7f5854cdd2e8>,
#  'distres': <gensim.models.keyedvectors.Vocab at 0x7f5854cdd400>,
#  'tt': <gensim.models.keyedvectors.Vocab at 0x7f5854cdd518>,
#  'orales': <gensim.models.keyedvectors.Vocab at 0x7f5854cdd630>,
#  'extraño': <gensim.models.keyedvectors.Vocab at 0x7f5854cdd668>,
#  'escolar': <gensim.models.keyedvectors.Vocab at 0x7f5854cdd710>,
#  'ver': <gensim.models.keyedvectors.Vocab at 0x7f5854cdd7b8>,
#  'lactancia': <gensim.models.keyedvectors.Vocab at 0x7f5854cdd828>,
#  'adversas': <gensim.models.keyedvectors.Vocab at 0x7f5854cdd860>,
#  'soplo': <gensim.models.keyedvectors.Vocab at 0x7f5854cdd940>,
#  'orfidal': <gensim.models.keyedvectors.Vocab at 0x7f5854cdd9b0>,
#  'preciso': <gensim.models.keyedvectors.Vocab at 0x7f5854cdda58>,
#  'reglada': <gensim.models.keyedvectors.Vocab at 0x7f5854cddba8>,
#  'cr': <gensim.models.keyedvectors.Vocab at 0x7f5854cddd30>,
#  'litiasis': <gensim.models.keyedvectors.Vocab at 0x7f5854cdddd8>,
#  'despues': <gensim.models.keyedvectors.Vocab at 0x7f5854cddf28>,
#  'normohidratado': <gensim.models.keyedvectors.Vocab at 0x7f5854cddf60>,
#  'urologia': <gensim.models.keyedvectors.Vocab at 0x7f5854cdde10>,
#  'hematocrito': <gensim.models.keyedvectors.Vocab at 0x7f5854ce1080>,
#  'externas': <gensim.models.keyedvectors.Vocab at 0x7f5854ce1128>,
#  'mosm/l': <gensim.models.keyedvectors.Vocab at 0x7f5854ce11d0>,
#  'intolerancia': <gensim.models.keyedvectors.Vocab at 0x7f5854ce1208>,
#  'suero': <gensim.models.keyedvectors.Vocab at 0x7f5854ce12b0>,
#  'guardia': <gensim.models.keyedvectors.Vocab at 0x7f5854ce14a8>,
#  'seguril': <gensim.models.keyedvectors.Vocab at 0x7f5854ce1588>,
#  'derrame': <gensim.models.keyedvectors.Vocab at 0x7f5854ce1668>,
#  '25mg': <gensim.models.keyedvectors.Vocab at 0x7f5854ce1748>,
#  'fosa': <gensim.models.keyedvectors.Vocab at 0x7f5854ce1828>,
#  'igual': <gensim.models.keyedvectors.Vocab at 0x7f5854ce1978>,
#  '29': <gensim.models.keyedvectors.Vocab at 0x7f5854ce1a90>,
#  'cetonicos': <gensim.models.keyedvectors.Vocab at 0x7f5854ce1b38>,
#  'cede': <gensim.models.keyedvectors.Vocab at 0x7f5854ce1be0>,
#  'basal': <gensim.models.keyedvectors.Vocab at 0x7f5854ce1cf8>,
#  'mioglobina': <gensim.models.keyedvectors.Vocab at 0x7f5854ce1d30>,
#  'ratio': <gensim.models.keyedvectors.Vocab at 0x7f5854ce1e10>,
#  'externa': <gensim.models.keyedvectors.Vocab at 0x7f5854ce1ef0>,
#  'po2': <gensim.models.keyedvectors.Vocab at 0x7f5854ce1f98>,
#  'vomito': <gensim.models.keyedvectors.Vocab at 0x7f5854ce4080>,
#  'reglado': <gensim.models.keyedvectors.Vocab at 0x7f5854ce4160>,
#  'acompañado': <gensim.models.keyedvectors.Vocab at 0x7f5854ce4198>,
#  'eje': <gensim.models.keyedvectors.Vocab at 0x7f5854ce42b0>,
#  'faringe': <gensim.models.keyedvectors.Vocab at 0x7f5854ce4400>,
#  'interna': <gensim.models.keyedvectors.Vocab at 0x7f5854ce4470>,
#  'irradiado': <gensim.models.keyedvectors.Vocab at 0x7f5854ce44a8>,
#  'pupilas': <gensim.models.keyedvectors.Vocab at 0x7f5854ce4518>,
#  '295': <gensim.models.keyedvectors.Vocab at 0x7f5854ce45c0>,
#  'origen': <gensim.models.keyedvectors.Vocab at 0x7f5854ce46a0>,
#  'adenopatias': <gensim.models.keyedvectors.Vocab at 0x7f5854ce4710>,
#  'tono': <gensim.models.keyedvectors.Vocab at 0x7f5854ce47b8>,
#  '150': <gensim.models.keyedvectors.Vocab at 0x7f5854ce48d0>,
#  'cama': <gensim.models.keyedvectors.Vocab at 0x7f5854ce4978>,
#  'aporta': <gensim.models.keyedvectors.Vocab at 0x7f5854ce49e8>,
#  'c/': <gensim.models.keyedvectors.Vocab at 0x7f5854ce4a58>,
#  'mejora': <gensim.models.keyedvectors.Vocab at 0x7f5854ce4b00>,
#  'tvp': <gensim.models.keyedvectors.Vocab at 0x7f5854ce4ba8>,
#  'isquemica': <gensim.models.keyedvectors.Vocab at 0x7f5854ce4be0>,
#  'vias': <gensim.models.keyedvectors.Vocab at 0x7f5854ce4c88>,
#  'dorsal': <gensim.models.keyedvectors.Vocab at 0x7f5854ce4dd8>,
#  'ambas': <gensim.models.keyedvectors.Vocab at 0x7f5854ce4e80>,
#  'esguince': <gensim.models.keyedvectors.Vocab at 0x7f5854ce4f28>,
#  'ex': <gensim.models.keyedvectors.Vocab at 0x7f5854ce4f60>,
#  '300': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6160>,
#  'linfocitos': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6198>,
#  'trastorno': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6240>,
#  '40mg': <gensim.models.keyedvectors.Vocab at 0x7f5854ce63c8>,
#  'momento': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6518>,
#  'mama': <gensim.models.keyedvectors.Vocab at 0x7f5854ce65f8>,
#  'activa': <gensim.models.keyedvectors.Vocab at 0x7f5854ce67b8>,
#  '41': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6898>,
#  'oi': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6908>,
#  'dcha': <gensim.models.keyedvectors.Vocab at 0x7f5854ce69e8>,
#  'mientras': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6a20>,
#  'presente': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6ac8>,
#  'lactante': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6b00>,
#  'masa': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6ba8>,
#  '42': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6cc0>,
#  'diazepam': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6d30>,
#  'urobilinogeno': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6d68>,
#  'evitar': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6e10>,
#  'traumatologia': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6e48>,
#  'rectal': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6ef0>,
#  'dcho': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6f60>,
#  'cervicalgia': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6f98>,
#  'protesis': <gensim.models.keyedvectors.Vocab at 0x7f5854ce6f28>,
#  'roncus': <gensim.models.keyedvectors.Vocab at 0x7f5854cea128>,
#  'mg/l': <gensim.models.keyedvectors.Vocab at 0x7f5854cea198>,
#  'columna': <gensim.models.keyedvectors.Vocab at 0x7f5854cea278>,
#  'ocular': <gensim.models.keyedvectors.Vocab at 0x7f5854cea358>,
#  '140': <gensim.models.keyedvectors.Vocab at 0x7f5854cea470>,
#  'administracion': <gensim.models.keyedvectors.Vocab at 0x7f5854cea4a8>,
#  'ecografia': <gensim.models.keyedvectors.Vocab at 0x7f5854cea588>,
#  'ca': <gensim.models.keyedvectors.Vocab at 0x7f5854cea630>,
#  'pauta': <gensim.models.keyedvectors.Vocab at 0x7f5854cea710>,
#  '19': <gensim.models.keyedvectors.Vocab at 0x7f5854cea860>,
#  'positivo': <gensim.models.keyedvectors.Vocab at 0x7f5854cea898>,
#  'apendicectomia': <gensim.models.keyedvectors.Vocab at 0x7f5854cea940>,
#  'neurologico': <gensim.models.keyedvectors.Vocab at 0x7f5854cea978>,
#  'shp': <gensim.models.keyedvectors.Vocab at 0x7f5854ceaa58>,
#  'gotas': <gensim.models.keyedvectors.Vocab at 0x7f5854ceac18>,
#  '+++': <gensim.models.keyedvectors.Vocab at 0x7f5854ceacc0>,
#  'fumadora': <gensim.models.keyedvectors.Vocab at 0x7f5854cead68>,
#  '97': <gensim.models.keyedvectors.Vocab at 0x7f5854ceadd8>,
#  'secundaria': <gensim.models.keyedvectors.Vocab at 0x7f5854ceae10>,
#  'esfuerzos': <gensim.models.keyedvectors.Vocab at 0x7f5854ceae80>,
#  'huva': <gensim.models.keyedvectors.Vocab at 0x7f5854ceaf28>,
#  'procede': <gensim.models.keyedvectors.Vocab at 0x7f5854ceaf60>,
#  'hidratado': <gensim.models.keyedvectors.Vocab at 0x7f5854ced128>,
#  'ventricular': <gensim.models.keyedvectors.Vocab at 0x7f5854ced208>,
#  'anormal': <gensim.models.keyedvectors.Vocab at 0x7f5854ced320>,
#  'crepitantes': <gensim.models.keyedvectors.Vocab at 0x7f5854ced358>,
#  'cataratas': <gensim.models.keyedvectors.Vocab at 0x7f5854ced3c8>,
#  'minutos': <gensim.models.keyedvectors.Vocab at 0x7f5854ced438>,
#  'od': <gensim.models.keyedvectors.Vocab at 0x7f5854ced4e0>,
#  'hospital': <gensim.models.keyedvectors.Vocab at 0x7f5854ced518>,
#  'reactivo': <gensim.models.keyedvectors.Vocab at 0x7f5854ced588>,
#  'ferula': <gensim.models.keyedvectors.Vocab at 0x7f5854ced668>,
#  'ultimo': <gensim.models.keyedvectors.Vocab at 0x7f5854ced748>,
#  'epigastralgia': <gensim.models.keyedvectors.Vocab at 0x7f5854ced780>,
#  'domicilio': <gensim.models.keyedvectors.Vocab at 0x7f5854ced7b8>,
#  '99': <gensim.models.keyedvectors.Vocab at 0x7f5854ced828>,
#  'año': <gensim.models.keyedvectors.Vocab at 0x7f5854ced860>,
#  'intervenido': <gensim.models.keyedvectors.Vocab at 0x7f5854ced978>,
#  'sano': <gensim.models.keyedvectors.Vocab at 0x7f5854ceda58>,
#  'obesidad': <gensim.models.keyedvectors.Vocab at 0x7f5854ceda90>,
#  'proteina': <gensim.models.keyedvectors.Vocab at 0x7f5854cedb38>,
#  'resolucion': <gensim.models.keyedvectors.Vocab at 0x7f5854cedb70>,
#  'suap': <gensim.models.keyedvectors.Vocab at 0x7f5854cedc88>,
#  'quiste': <gensim.models.keyedvectors.Vocab at 0x7f5854cedd68>,
#  'persiste': <gensim.models.keyedvectors.Vocab at 0x7f5854cede10>,
#  'neumonia': <gensim.models.keyedvectors.Vocab at 0x7f5854cede48>,
#  'hora': <gensim.models.keyedvectors.Vocab at 0x7f5854cedf60>,
#  'caso': <gensim.models.keyedvectors.Vocab at 0x7f5854c700b8>,
#  'gonalgia': <gensim.models.keyedvectors.Vocab at 0x7f5854c70160>,
#  'imagen': <gensim.models.keyedvectors.Vocab at 0x7f5854c70240>,
#  'ocasiones': <gensim.models.keyedvectors.Vocab at 0x7f5854c70278>,
#  '44': <gensim.models.keyedvectors.Vocab at 0x7f5854c70320>,
#  'movilizacion': <gensim.models.keyedvectors.Vocab at 0x7f5854c70358>,
#  'suspender': <gensim.models.keyedvectors.Vocab at 0x7f5854c70390>,
#  'aproximadamente': <gensim.models.keyedvectors.Vocab at 0x7f5854c70470>,
#  'hematuria': <gensim.models.keyedvectors.Vocab at 0x7f5854c704a8>,
#  '275': <gensim.models.keyedvectors.Vocab at 0x7f5854c70550>,
#  'mal': <gensim.models.keyedvectors.Vocab at 0x7f5854c705c0>,
#  'gluc': <gensim.models.keyedvectors.Vocab at 0x7f5854c70668>,
#  'puntos': <gensim.models.keyedvectors.Vocab at 0x7f5854c707b8>,
#  'ranitidina': <gensim.models.keyedvectors.Vocab at 0x7f5854c70898>,
#  'centrados': <gensim.models.keyedvectors.Vocab at 0x7f5854c708d0>,
#  'flanco': <gensim.models.keyedvectors.Vocab at 0x7f5854c70978>,
#  'x': <gensim.models.keyedvectors.Vocab at 0x7f5854c70a58>,
#  'neurologia': <gensim.models.keyedvectors.Vocab at 0x7f5854c70a90>,
#  'troponina': <gensim.models.keyedvectors.Vocab at 0x7f5854c70c50>,
#  'temperatura': <gensim.models.keyedvectors.Vocab at 0x7f5854c70c88>,
#  '2013': <gensim.models.keyedvectors.Vocab at 0x7f5854c70e48>,
#  'dilatacion': <gensim.models.keyedvectors.Vocab at 0x7f5854c70fd0>,
#  'tarde': <gensim.models.keyedvectors.Vocab at 0x7f5854c75198>,
#  'vo': <gensim.models.keyedvectors.Vocab at 0x7f5854c75320>,
#  'toxicos': <gensim.models.keyedvectors.Vocab at 0x7f5854c754a8>,
#  'hipotiroidismo': <gensim.models.keyedvectors.Vocab at 0x7f5854c754e0>,
#  'nasales': <gensim.models.keyedvectors.Vocab at 0x7f5854c75630>,
#  'antineumococica': <gensim.models.keyedvectors.Vocab at 0x7f5854c756a0>,
#  'monocitos': <gensim.models.keyedvectors.Vocab at 0x7f5854c756d8>,
#  'vascular': <gensim.models.keyedvectors.Vocab at 0x7f5854c75780>,
#  'namc': <gensim.models.keyedvectors.Vocab at 0x7f5854c75828>,
#  'dolorosa': <gensim.models.keyedvectors.Vocab at 0x7f5854c75860>,
#  'mismo': <gensim.models.keyedvectors.Vocab at 0x7f5854c75908>,
#  'sibilantes': <gensim.models.keyedvectors.Vocab at 0x7f5854c759b0>,
#  'acxfa': <gensim.models.keyedvectors.Vocab at 0x7f5854c75a90>,
#  'accidental': <gensim.models.keyedvectors.Vocab at 0x7f5854c75ac8>,
#  'dosis': <gensim.models.keyedvectors.Vocab at 0x7f5854c75be0>,
#  'germenes': <gensim.models.keyedvectors.Vocab at 0x7f5854c75c50>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7f5854c75c88>,
#  '000': <gensim.models.keyedvectors.Vocab at 0x7f5854c75da0>,
#  'reaccion': <gensim.models.keyedvectors.Vocab at 0x7f5854c75e10>,
#  'miembros': <gensim.models.keyedvectors.Vocab at 0x7f5854c75e48>,
#  'refiriendo': <gensim.models.keyedvectors.Vocab at 0x7f5854c75eb8>,
#  'hoja': <gensim.models.keyedvectors.Vocab at 0x7f5854c75f28>,
#  'eco': <gensim.models.keyedvectors.Vocab at 0x7f5854c75f60>,
#  '96': <gensim.models.keyedvectors.Vocab at 0x7f5854c76160>,
#  '106': <gensim.models.keyedvectors.Vocab at 0x7f5854c761d0>,
#  'y': <gensim.models.keyedvectors.Vocab at 0x7f5854c76208>,
#  'deformidad': <gensim.models.keyedvectors.Vocab at 0x7f5854c762b0>,
#  'fl': <gensim.models.keyedvectors.Vocab at 0x7f5854c76358>,
#  'sospecha': <gensim.models.keyedvectors.Vocab at 0x7f5854c76390>,
#  'caracteristicas': <gensim.models.keyedvectors.Vocab at 0x7f5854c76438>,
#  'beber': <gensim.models.keyedvectors.Vocab at 0x7f5854c76518>,
#  '2012': <gensim.models.keyedvectors.Vocab at 0x7f5854c765f8>,
#  '2010': <gensim.models.keyedvectors.Vocab at 0x7f5854c766a0>,
#  'varias': <gensim.models.keyedvectors.Vocab at 0x7f5854c76748>,
#  'gav': <gensim.models.keyedvectors.Vocab at 0x7f5854c767f0>,
#  'colon': <gensim.models.keyedvectors.Vocab at 0x7f5854c76908>,
#  'intervenida': <gensim.models.keyedvectors.Vocab at 0x7f5854c76940>,
#  'oea': <gensim.models.keyedvectors.Vocab at 0x7f5854c76a58>,
#  'luego': <gensim.models.keyedvectors.Vocab at 0x7f5854c76be0>,
# ...
#  'fisura': <gensim.models.keyedvectors.Vocab at 0x7f5854c7ac18>,
#  'iii': <gensim.models.keyedvectors.Vocab at 0x7f5854c7ad30>,
#  'artrosis': <gensim.models.keyedvectors.Vocab at 0x7f5854c7ae10>,
#  'aprecian': <gensim.models.keyedvectors.Vocab at 0x7f5854c7ae48>,
#  'bronquial': <gensim.models.keyedvectors.Vocab at 0x7f5854c7aef0>,
#  'gestacion': <gensim.models.keyedvectors.Vocab at 0x7f5854c7af28>,
#  'metabolico': <gensim.models.keyedvectors.Vocab at 0x7f5854c7afd0>,
#  'tolerancia': <gensim.models.keyedvectors.Vocab at 0x7f5854c7acf8>,
#  'pr': <gensim.models.keyedvectors.Vocab at 0x7f5854c7e0b8>,
#  '++': <gensim.models.keyedvectors.Vocab at 0x7f5854c7e208>,
#  'expectoracion': <gensim.models.keyedvectors.Vocab at 0x7f5854c7e2b0>,
#  'comenta': <gensim.models.keyedvectors.Vocab at 0x7f5854c7e390>,
#  'previa': <gensim.models.keyedvectors.Vocab at 0x7f5854c7e438>,
#  'brazo': <gensim.models.keyedvectors.Vocab at 0x7f5854c7e518>,
#  'hemitorax': <gensim.models.keyedvectors.Vocab at 0x7f5854c7e550>,
#  'posteriormente': <gensim.models.keyedvectors.Vocab at 0x7f5854c7e5f8>,
#  '10mg': <gensim.models.keyedvectors.Vocab at 0x7f5854c7e6d8>,
#  'ansioso': <gensim.models.keyedvectors.Vocab at 0x7f5854c7e780>,
#  'estable': <gensim.models.keyedvectors.Vocab at 0x7f5854c7e908>,
#  '005': <gensim.models.keyedvectors.Vocab at 0x7f5854c7ea58>,
#  '2011': <gensim.models.keyedvectors.Vocab at 0x7f5854c7eb70>,
#  'hidratada': <gensim.models.keyedvectors.Vocab at 0x7f5854c7eba8>,
#  'frontal': <gensim.models.keyedvectors.Vocab at 0x7f5854c7ec88>,
#  '67': <gensim.models.keyedvectors.Vocab at 0x7f5854c7ed68>,
#  '51': <gensim.models.keyedvectors.Vocab at 0x7f5854c7eef0>,
#  'analgesia': <gensim.models.keyedvectors.Vocab at 0x7f5854c7efd0>,
#  'seguir': <gensim.models.keyedvectors.Vocab at 0x7f5854c800b8>,
#  'plaq': <gensim.models.keyedvectors.Vocab at 0x7f5854c80278>,
#  'estancia': <gensim.models.keyedvectors.Vocab at 0x7f5854c802b0>,
#  'glucemia': <gensim.models.keyedvectors.Vocab at 0x7f5854c80358>,
#  'hipertensiva': <gensim.models.keyedvectors.Vocab at 0x7f5854c80390>,
#  'exantema': <gensim.models.keyedvectors.Vocab at 0x7f5854c80438>,
#  'algun': <gensim.models.keyedvectors.Vocab at 0x7f5854c80550>,
#  'zaldiar': <gensim.models.keyedvectors.Vocab at 0x7f5854c80668>,
#  'haber': <gensim.models.keyedvectors.Vocab at 0x7f5854c80748>,
#  'fid': <gensim.models.keyedvectors.Vocab at 0x7f5854c807f0>,
#  'vision': <gensim.models.keyedvectors.Vocab at 0x7f5854c80860>,
#  'conciente': <gensim.models.keyedvectors.Vocab at 0x7f5854c80898>,
#  '03': <gensim.models.keyedvectors.Vocab at 0x7f5854c80940>,
#  'osea': <gensim.models.keyedvectors.Vocab at 0x7f5854c80a58>,
#  'hipoventilacion': <gensim.models.keyedvectors.Vocab at 0x7f5854c80b70>,
#  'cc': <gensim.models.keyedvectors.Vocab at 0x7f5854c80c18>,
#  'estenosis': <gensim.models.keyedvectors.Vocab at 0x7f5854c80c50>,
#  'gasometria': <gensim.models.keyedvectors.Vocab at 0x7f5854c80cc0>,
#  'generalizada': <gensim.models.keyedvectors.Vocab at 0x7f5854c80cf8>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x7f5854c80da0>,
#  '146': <gensim.models.keyedvectors.Vocab at 0x7f5854c80e10>,
#  'zamene': <gensim.models.keyedvectors.Vocab at 0x7f5854c80e80>,
#  '1gr': <gensim.models.keyedvectors.Vocab at 0x7f5854c80ef0>,
#  'refieren': <gensim.models.keyedvectors.Vocab at 0x7f5854c80f98>,
#  'v': <gensim.models.keyedvectors.Vocab at 0x7f5854c80fd0>,
#  'pared': <gensim.models.keyedvectors.Vocab at 0x7f5854c860b8>,
#  'dentro': <gensim.models.keyedvectors.Vocab at 0x7f5854c86198>,
#  'altas': <gensim.models.keyedvectors.Vocab at 0x7f5854c86240>,
#  'mmol/l': <gensim.models.keyedvectors.Vocab at 0x7f5854c862b0>,
#  'placas': <gensim.models.keyedvectors.Vocab at 0x7f5854c86400>,
#  'lenguaje': <gensim.models.keyedvectors.Vocab at 0x7f5854c864a8>,
#  'cronico': <gensim.models.keyedvectors.Vocab at 0x7f5854c86518>,
#  'colecistectomia': <gensim.models.keyedvectors.Vocab at 0x7f5854c86550>,
#  'penicilina': <gensim.models.keyedvectors.Vocab at 0x7f5854c86588>,
#  'estertores': <gensim.models.keyedvectors.Vocab at 0x7f5854c865c0>,
#  'unas': <gensim.models.keyedvectors.Vocab at 0x7f5854c86668>,
#  'tiempo': <gensim.models.keyedvectors.Vocab at 0x7f5854c86748>,
#  'globuloso': <gensim.models.keyedvectors.Vocab at 0x7f5854c867b8>,
#  'urgente': <gensim.models.keyedvectors.Vocab at 0x7f5854c86860>,
#  '2014': <gensim.models.keyedvectors.Vocab at 0x7f5854c869e8>,
#  'facial': <gensim.models.keyedvectors.Vocab at 0x7f5854c86b38>,
#  'plus': <gensim.models.keyedvectors.Vocab at 0x7f5854c86c88>,
#  'vcm': <gensim.models.keyedvectors.Vocab at 0x7f5854c86d30>,
#  'digestivo': <gensim.models.keyedvectors.Vocab at 0x7f5854c86d68>,
#  'ambiente': <gensim.models.keyedvectors.Vocab at 0x7f5854c86dd8>,
#  'evidencia': <gensim.models.keyedvectors.Vocab at 0x7f5854c86e10>,
#  'rechazo': <gensim.models.keyedvectors.Vocab at 0x7f5854c86ef0>,
#  '1c': <gensim.models.keyedvectors.Vocab at 0x7f5854c86f98>,
#  'realizar': <gensim.models.keyedvectors.Vocab at 0x7f5854c86fd0>,
#  '72': <gensim.models.keyedvectors.Vocab at 0x7f5854c880b8>,
#  'impotencia': <gensim.models.keyedvectors.Vocab at 0x7f5854c880f0>,
#  'prostata': <gensim.models.keyedvectors.Vocab at 0x7f5854c88128>,
#  'cardiacos': <gensim.models.keyedvectors.Vocab at 0x7f5854c88160>,
#  '65': <gensim.models.keyedvectors.Vocab at 0x7f5854c88240>,
#  'familiares': <gensim.models.keyedvectors.Vocab at 0x7f5854c88278>,
#  'cribado': <gensim.models.keyedvectors.Vocab at 0x7f5854c88390>,
#  'reg': <gensim.models.keyedvectors.Vocab at 0x7f5854c88438>,
#  'remitido': <gensim.models.keyedvectors.Vocab at 0x7f5854c88470>,
#  'primeras': <gensim.models.keyedvectors.Vocab at 0x7f5854c88550>,
#  'situacion': <gensim.models.keyedvectors.Vocab at 0x7f5854c88588>,
#  'linea': <gensim.models.keyedvectors.Vocab at 0x7f5854c88668>,
#  'tiraje': <gensim.models.keyedvectors.Vocab at 0x7f5854c88710>,
#  'mb': <gensim.models.keyedvectors.Vocab at 0x7f5854c88898>,
#  'vendaje': <gensim.models.keyedvectors.Vocab at 0x7f5854c889e8>,
#  'respuesta': <gensim.models.keyedvectors.Vocab at 0x7f5854c88a58>,
#  'campos': <gensim.models.keyedvectors.Vocab at 0x7f5854c88ba8>,
#  'proximal': <gensim.models.keyedvectors.Vocab at 0x7f5854c88be0>,
#  'eosinofilos': <gensim.models.keyedvectors.Vocab at 0x7f5854c88c88>,
#  'ar': <gensim.models.keyedvectors.Vocab at 0x7f5854c88d68>,
#  'fx': <gensim.models.keyedvectors.Vocab at 0x7f5854c88e10>,
#  'citar': <gensim.models.keyedvectors.Vocab at 0x7f5854c88eb8>,
#  'da': <gensim.models.keyedvectors.Vocab at 0x7f5854c88f60>,
#  '137': <gensim.models.keyedvectors.Vocab at 0x7f5854c88f98>,
#  'importante': <gensim.models.keyedvectors.Vocab at 0x7f5854c8a0b8>,
#  'histerectomia': <gensim.models.keyedvectors.Vocab at 0x7f5854c8a128>,
#  'disminucion': <gensim.models.keyedvectors.Vocab at 0x7f5854c8a160>,
#  'dr': <gensim.models.keyedvectors.Vocab at 0x7f5854c8a208>,
#  'habitos': <gensim.models.keyedvectors.Vocab at 0x7f5854c8a278>,
#  'anormales': <gensim.models.keyedvectors.Vocab at 0x7f5854c8a390>,
#  'conocimiento': <gensim.models.keyedvectors.Vocab at 0x7f5854c8a3c8>,
#  '500mg': <gensim.models.keyedvectors.Vocab at 0x7f5854c8a470>,
#  'neo': <gensim.models.keyedvectors.Vocab at 0x7f5854c8a5f8>,
#  'valorado': <gensim.models.keyedvectors.Vocab at 0x7f5854c8a710>,
#  'aunque': <gensim.models.keyedvectors.Vocab at 0x7f5854c8a8d0>,
#  'corta': <gensim.models.keyedvectors.Vocab at 0x7f5854c8aa58>,
#  'ictus': <gensim.models.keyedvectors.Vocab at 0x7f5854c8ab70>,
#  'asintomatico': <gensim.models.keyedvectors.Vocab at 0x7f5854c8aba8>,
#  'anal': <gensim.models.keyedvectors.Vocab at 0x7f5854c8ad30>,
#  '118': <gensim.models.keyedvectors.Vocab at 0x7f5854c8ae80>,
#  'acompañante': <gensim.models.keyedvectors.Vocab at 0x7f5854c8afd0>,
#  'acudira': <gensim.models.keyedvectors.Vocab at 0x7f5854c8e128>,
#  'articular': <gensim.models.keyedvectors.Vocab at 0x7f5854c8e160>,
#  'hacia': <gensim.models.keyedvectors.Vocab at 0x7f5854c8e2b0>,
#  'diagnostico': <gensim.models.keyedvectors.Vocab at 0x7f5854c8e390>,
#  '94': <gensim.models.keyedvectors.Vocab at 0x7f5854c8e4a8>,
#  'limitacion': <gensim.models.keyedvectors.Vocab at 0x7f5854c8e4e0>,
#  '2009': <gensim.models.keyedvectors.Vocab at 0x7f5854c8e588>,
#  'puede': <gensim.models.keyedvectors.Vocab at 0x7f5854c8e630>,
#  'nexium': <gensim.models.keyedvectors.Vocab at 0x7f5854c8e710>,
#  'amoxicilina': <gensim.models.keyedvectors.Vocab at 0x7f5854c8e780>,
#  'bases': <gensim.models.keyedvectors.Vocab at 0x7f5854c8e828>,
#  'ultimos': <gensim.models.keyedvectors.Vocab at 0x7f5854c8e8d0>,
#  'isquemico': <gensim.models.keyedvectors.Vocab at 0x7f5854c8e908>,
#  'trafico': <gensim.models.keyedvectors.Vocab at 0x7f5854c8e9b0>,
#  '100mg': <gensim.models.keyedvectors.Vocab at 0x7f5854c8eac8>,
#  'cardiomegalia': <gensim.models.keyedvectors.Vocab at 0x7f5854c8ec18>,
#  '46': <gensim.models.keyedvectors.Vocab at 0x7f5854c8ed68>,
#  'romberg': <gensim.models.keyedvectors.Vocab at 0x7f5854c8ee10>,
#  'sincope': <gensim.models.keyedvectors.Vocab at 0x7f5854c8eef0>,
#  'asociada': <gensim.models.keyedvectors.Vocab at 0x7f5854c8ef28>,
#  'ram': <gensim.models.keyedvectors.Vocab at 0x7f5854c8efd0>,
#  'celulas': <gensim.models.keyedvectors.Vocab at 0x7f5854c900f0>,
#  '138': <gensim.models.keyedvectors.Vocab at 0x7f5854c901d0>,
#  'palidez': <gensim.models.keyedvectors.Vocab at 0x7f5854c90278>,
#  'ingresa': <gensim.models.keyedvectors.Vocab at 0x7f5854c90358>,
#  'otoscopia': <gensim.models.keyedvectors.Vocab at 0x7f5854c90470>,
#  'ademas': <gensim.models.keyedvectors.Vocab at 0x7f5854c90550>,
#  'ulcera': <gensim.models.keyedvectors.Vocab at 0x7f5854c90630>,
#  'picnr': <gensim.models.keyedvectors.Vocab at 0x7f5854c906d8>,
#  '12/l': <gensim.models.keyedvectors.Vocab at 0x7f5854c90780>,
#  'revisiones': <gensim.models.keyedvectors.Vocab at 0x7f5854c907b8>,
#  '85': <gensim.models.keyedvectors.Vocab at 0x7f5854c90828>,
#  'mayor': <gensim.models.keyedvectors.Vocab at 0x7f5854c908d0>,
#  'cru': <gensim.models.keyedvectors.Vocab at 0x7f5854c909b0>,
#  'miembro': <gensim.models.keyedvectors.Vocab at 0x7f5854c90ac8>,
#  'dado': <gensim.models.keyedvectors.Vocab at 0x7f5854c90ba8>,
#  'pdt': <gensim.models.keyedvectors.Vocab at 0x7f5854c90c18>,
#  'palpo': <gensim.models.keyedvectors.Vocab at 0x7f5854c90cc0>,
#  'gastrico': <gensim.models.keyedvectors.Vocab at 0x7f5854c90cf8>,
#  'extension': <gensim.models.keyedvectors.Vocab at 0x7f5854c90d30>,
#  'odinofagia': <gensim.models.keyedvectors.Vocab at 0x7f5854c90dd8>,
#  'basofilos': <gensim.models.keyedvectors.Vocab at 0x7f5854c90e10>,
#  '92': <gensim.models.keyedvectors.Vocab at 0x7f5854c90f60>,
#  'compatible': <gensim.models.keyedvectors.Vocab at 0x7f5854c90f98>,
#  'acv': <gensim.models.keyedvectors.Vocab at 0x7f5854c90fd0>,
#  'atipico': <gensim.models.keyedvectors.Vocab at 0x7f5854c93160>,
#  'articulacion': <gensim.models.keyedvectors.Vocab at 0x7f5854c93198>,
#  'libre': <gensim.models.keyedvectors.Vocab at 0x7f5854c93208>,
#  'inferiores': <gensim.models.keyedvectors.Vocab at 0x7f5854c932b0>,
#  '88': <gensim.models.keyedvectors.Vocab at 0x7f5854c93358>,
#  'serologias': <gensim.models.keyedvectors.Vocab at 0x7f5854c93390>,
#  'ser': <gensim.models.keyedvectors.Vocab at 0x7f5854c93400>,
#  '02': <gensim.models.keyedvectors.Vocab at 0x7f5854c93550>,
#  'gastritis': <gensim.models.keyedvectors.Vocab at 0x7f5854c935f8>,
#  'glucemias': <gensim.models.keyedvectors.Vocab at 0x7f5854c93630>,
#  'doble': <gensim.models.keyedvectors.Vocab at 0x7f5854c93710>,
#  'hrs': <gensim.models.keyedvectors.Vocab at 0x7f5854c937f0>,
#  'dedos': <gensim.models.keyedvectors.Vocab at 0x7f5854c93898>,
#  'escasa': <gensim.models.keyedvectors.Vocab at 0x7f5854c939e8>,
#  'ck': <gensim.models.keyedvectors.Vocab at 0x7f5854c93ac8>,
#  'unknown': <gensim.models.keyedvectors.Vocab at 0x7f5854c93be0>,
#  'valorada': <gensim.models.keyedvectors.Vocab at 0x7f5854c93c88>,
#  '93': <gensim.models.keyedvectors.Vocab at 0x7f5854c93d68>,
#  'medicos': <gensim.models.keyedvectors.Vocab at 0x7f5854c93e10>,
#  'auricular': <gensim.models.keyedvectors.Vocab at 0x7f5854c93e48>,
#  '135': <gensim.models.keyedvectors.Vocab at 0x7f5854c93f60>,
#  'remitida': <gensim.models.keyedvectors.Vocab at 0x7f5854c93f28>,
#  'aumenta': <gensim.models.keyedvectors.Vocab at 0x7f5854c970f0>,
#  'tomado': <gensim.models.keyedvectors.Vocab at 0x7f5854c97198>,
#  'inicia': <gensim.models.keyedvectors.Vocab at 0x7f5854c973c8>,
#  'postraumatica': <gensim.models.keyedvectors.Vocab at 0x7f5854c97400>,
#  '2015': <gensim.models.keyedvectors.Vocab at 0x7f5854c97588>,
#  '1/8h': <gensim.models.keyedvectors.Vocab at 0x7f5854c97630>,
#  'mv': <gensim.models.keyedvectors.Vocab at 0x7f5854c97780>,
#  'pleural': <gensim.models.keyedvectors.Vocab at 0x7f5854c97898>,
#  'asintomatica': <gensim.models.keyedvectors.Vocab at 0x7f5854c97940>,
#  'tacto': <gensim.models.keyedvectors.Vocab at 0x7f5854c979e8>,
#  'incluida': <gensim.models.keyedvectors.Vocab at 0x7f5854c97a20>,
#  'dolorosos': <gensim.models.keyedvectors.Vocab at 0x7f5854c97b00>,
#  'neuro': <gensim.models.keyedvectors.Vocab at 0x7f5854c97c18>,
#  'calibre': <gensim.models.keyedvectors.Vocab at 0x7f5854c97cf8>,
#  'curso': <gensim.models.keyedvectors.Vocab at 0x7f5854c97e10>,
#  'dx': <gensim.models.keyedvectors.Vocab at 0x7f5854c97eb8>,
#  'sonda': <gensim.models.keyedvectors.Vocab at 0x7f5854c97f98>,
#  '5/5': <gensim.models.keyedvectors.Vocab at 0x7f5854c97fd0>,
#  'ninguna': <gensim.models.keyedvectors.Vocab at 0x7f5854c991d0>,
#  '1c/8h': <gensim.models.keyedvectors.Vocab at 0x7f5854c992e8>,
#  'aortica': <gensim.models.keyedvectors.Vocab at 0x7f5854c99400>,
#  'capsula': <gensim.models.keyedvectors.Vocab at 0x7f5854c99550>,
#  'lavados': <gensim.models.keyedvectors.Vocab at 0x7f5854c99630>,
#  'restos': <gensim.models.keyedvectors.Vocab at 0x7f5854c99748>,
#  'cp': <gensim.models.keyedvectors.Vocab at 0x7f5854c997b8>,
#  'nacimiento': <gensim.models.keyedvectors.Vocab at 0x7f5854c997f0>,
#  '47': <gensim.models.keyedvectors.Vocab at 0x7f5854c99908>,
#  '24h': <gensim.models.keyedvectors.Vocab at 0x7f5854c99a58>,
#  '1c/8': <gensim.models.keyedvectors.Vocab at 0x7f5854c99b70>,
#  'sala': <gensim.models.keyedvectors.Vocab at 0x7f5854c99c88>,
#  'inmovilizacion': <gensim.models.keyedvectors.Vocab at 0x7f5854c99d30>,
#  'mii': <gensim.models.keyedvectors.Vocab at 0x7f5854c99e10>,
#  'herniorrafia': <gensim.models.keyedvectors.Vocab at 0x7f5854c99e48>,
#  'sobres': <gensim.models.keyedvectors.Vocab at 0x7f5854c99f28>,
#  'eutirox': <gensim.models.keyedvectors.Vocab at 0x7f5854c9c0f0>,
#  'oxigeno': <gensim.models.keyedvectors.Vocab at 0x7f5854c9c240>,
#  'intolerancias': <gensim.models.keyedvectors.Vocab at 0x7f5854c9c320>,
#  '1/8': <gensim.models.keyedvectors.Vocab at 0x7f5854c9c3c8>,
#  'deterioro': <gensim.models.keyedvectors.Vocab at 0x7f5854c9c400>,
#  'cutanea': <gensim.models.keyedvectors.Vocab at 0x7f5854c9c588>,
#  'persistente': <gensim.models.keyedvectors.Vocab at 0x7f5854c9c668>,
#  'hiperemica': <gensim.models.keyedvectors.Vocab at 0x7f5854c9c6a0>,
#  'exantemas': <gensim.models.keyedvectors.Vocab at 0x7f5854c9c7f0>,
#  'exfumador': <gensim.models.keyedvectors.Vocab at 0x7f5854c9c828>,
#  'hermano': <gensim.models.keyedvectors.Vocab at 0x7f5854c9c908>,
#  'estructura': <gensim.models.keyedvectors.Vocab at 0x7f5854c9ca20>,
#  'menos': <gensim.models.keyedvectors.Vocab at 0x7f5854c9cb38>,
#  'predominio': <gensim.models.keyedvectors.Vocab at 0x7f5854c9cb70>,
#  'mid': <gensim.models.keyedvectors.Vocab at 0x7f5854c9cc18>,
#  'cortejo': <gensim.models.keyedvectors.Vocab at 0x7f5854c9ccc0>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x7f5854c9cd30>,
#  '86': <gensim.models.keyedvectors.Vocab at 0x7f5854c9ce10>,
#  'comidas': <gensim.models.keyedvectors.Vocab at 0x7f5854c9cf28>,
#  'positivas': <gensim.models.keyedvectors.Vocab at 0x7f5854c9cfd0>,
#  'vacunas': <gensim.models.keyedvectors.Vocab at 0x7f5854c9f160>,
#  'falange': <gensim.models.keyedvectors.Vocab at 0x7f5854c9f2b0>,
#  '91': <gensim.models.keyedvectors.Vocab at 0x7f5854c9f3c8>,
#  'oftalmologia': <gensim.models.keyedvectors.Vocab at 0x7f5854c9f400>,
#  'umbilical': <gensim.models.keyedvectors.Vocab at 0x7f5854c9f518>,
#  '89': <gensim.models.keyedvectors.Vocab at 0x7f5854c9f630>,
#  'viene': <gensim.models.keyedvectors.Vocab at 0x7f5854c9f748>,
#  ...}

# %% [markdown]
# ### Proceso temporal para añadirle el concepto con su jerarquia:

# %%
# Creación de una columan nueva con el idConcepto+Terminos+Jerarquia
def unir3(row):
    strTerm = ' '.join(row.corpusTerm)
    buff = row.idConcept + '|' + strTerm +'| '+row.jerarquia
    return buff

# %%
SnomedWork['concept'] = SnomedWork[['idConcept','jerarquia','corpusTerm']].apply(unir3, axis=1)

# %%
SnomedWork.head()
# Out:
#   idConcept      jerarquia                                    corpusTerm  \
# 0    102002      Sustancia                       [hemoglobina, okaloosa]
# 1    102002      Sustancia                       [hb, 48, cd7, leu, arg]
# 2    103007      Organismo                    [virus, fibroma, ardillas]
# 3    104001  Procedimiento                    [escision, lesion, rotula]
# 4    104001  Procedimiento  [escision, local, lesion, o, tejido, rotula]
#
#                                                                                                vecSnom  \
# 0  [-0.660218, 0.112245, 0.067039, 0.441094, -0.50456, -0.724666, -0.107986, 0.313558, 0.198024, 1....
# 1  [-0.317944, 1.87942, 1.76004, 1.72051, 0.75724, -1.13105, -0.499457, -1.84984, -0.570444, -0.630...
# 2  [-0.14364, -0.006139, 0.080456, 0.936581, -1.16385, -0.552844, 0.081489, -0.584596, -0.185695, 0...
# 3  [-1.0588, -0.371483, -1.84789, 1.65618, -0.235278, 0.101576, -1.08105, 0.863104, -0.374193, 1.04...
# 4  [-0.178396, -0.865999, -2.62099, 3.59125, -1.68036, -0.115811, -1.95361, 0.583631, -1.50294, 1.5...
#
#                                                        concept
# 0                       102002|hemoglobina okaloosa| Sustancia
# 1                          102002|hb 48 cd7 leu arg| Sustancia
# 2                     103007|virus fibroma ardillas| Organismo
# 3                 104001|escision lesion rotula| Procedimiento
# 4  104001|escision local lesion o tejido rotula| Procedimiento

# %%
print('Comprobacion de tamaño Modelo Espacio Vectorial (1)- 516211 - %d' % len(SnomedWork))
# Out:
# Comprobacion de tamaño Modelo Espacio Vectorial (1)- 516211 - 516211

# %% [markdown]
# ## 3. Métodos Snomed2Vec.Mas_similar() y Snomed2Vec.Similarity.

# %% [markdown]
# ### 4.1. Pruebas del método Snomed2vec.Most_similar():
# Implementacion método Most_Similar para Snomed2Vec. Basado en la implementación de gensim Word2Vec.

# %% [markdown]
# ** Nueva Versión init_Sims para Snomed2Vec:(init_vars)**

# %%
# Definiciones necesarias:
# Definir las siguientes varibles globales.
# Matriz formada por el tamaño global del vocabulario "vocab" y el tamaño "size" del vector de la palabra

#Entrada: Se le pasa el dataframe SnomedWork


def init_vars(data):
    vector_size = len(data['vecSnom'][0])
    vocab_size = len(data['vecSnom'])
    print(vector_size)
    print(vocab_size)
    
    logging.info("precomputing L2-norms of word weight vectors")
    
    index2word = data['concept'].tolist() # map from a word's matrix index (int) to word (string)
    
    syn0 = np.array(data['vecSnom'].tolist(), dtype=REAL)
    syn0[np.isnan(syn0)] = 0.0
    
    syn0norm = zeros((vocab_size, vector_size), dtype=REAL)
    np.seterr(divide='ignore', invalid='ignore')
    
    syn0norm = (syn0 / sqrt((syn0 ** 2).sum(-1))[..., newaxis]).astype(REAL)
    
    
    return syn0, index2word, syn0norm

# %%
syn0, index2word, syn0norm = init_vars(SnomedWork)
# Out:
# 2018-10-30 12:00:50,217 : INFO : precomputing L2-norms of word weight vectors
# 300
# 516211

# %%
def vectorSnomed(lstgrams,model,size):
    output=[]
    buffer=np.zeros((size,), dtype=np.float32)
    for item in lstgrams:
        try:
            buffer = buffer + model.word_vec(item)
        except:
            buffer = buffer + np.zeros((size,), dtype=REAL)
            #break
    #output.extend( buffer)
    return buffer

# %%
def mas_similar(positive=[], model=w2vModel, topn=10):
    
    vector=vectorSnomed(positive,model,300)
    vectorNorm = (vector / sqrt((vector ** 2).sum(-1))[..., newaxis]).astype(REAL)
    
    mean = []
    mean.append(vectorNorm)
    mean = matutils.unitvec(array(mean).mean(axis=0)).astype(REAL)
        
    limited = syn0norm
    dists = dot(limited, mean)
    dists[np.isnan(dists)] = 0.0
    
    best = matutils.argsort(dists, topn=topn, reverse=True)
        
    result = [(index2word[sim], float(dists[sim])) for sim in best]
    return result[:topn]

# %% [markdown]
# ### Pruebas de ejecucion:

# %%
term=['infarto', 'miocardio', 'agudo']
lconcept=mas_similar(term, topn=1000)

# %%
lconcept
# Out:
# [('57054005|infarto agudo miocardio| Hallazgo clínico', 0.9999999403953552),
#  ('52035003|infarto agudo miocardio anteroapical| Hallazgo clínico',
#   0.9787636995315552),
#  ('62695002|infarto agudo miocardio anteroseptal| Hallazgo clínico',
#   0.9710325002670288),
#  ('233838001|infarto agudo miocardio posterior| Hallazgo clínico',
#   0.9674647450447083),
#  ('233835003|infarto agudo miocardio diseminado| Hallazgo clínico',
#   0.9669334292411804),
#  ('703212004|infarto agudo miocardio procedimiento| Hallazgo clínico',
#   0.9650102257728577),
#  ('79009004|infarto agudo miocardio septal| Hallazgo clínico',
#   0.9519761800765991),
#  ('59063002|infarto agudo miocardio pared apicolateral| Hallazgo clínico',
#   0.9467006325721741),
#  ('70998009|infarto agudo miocardio pared posterobasal| Hallazgo clínico',
#   0.9440363049507141),
#  ('71023004|pericarditis infarto agudo miocardio| Hallazgo clínico',
#   0.9438134431838989),
#  ('76593002|infarto agudo miocardio pared inferoposterior| Hallazgo clínico',
#   0.9380706548690796),
#  ('70422006|infarto subendocardico agudo| Hallazgo clínico',
#   0.9364050030708313),
#  ('65547006|infarto agudo miocardio pared inferolateral| Hallazgo clínico',
#   0.9357978701591492),
#  ('55470003|infarto agudo| Estructura corporal', 0.9356862306594849),
#  ('73795002|infarto agudo miocardio pared inferior| Hallazgo clínico',
#   0.9293085932731628),
#  ('70211005|infarto agudo miocardio pared anterolateral| Hallazgo clínico',
#   0.9256477355957031),
#  ('54329005|infarto agudo miocardio pared anterior| Hallazgo clínico',
#   0.9243710041046143),
#  ('30277009|infarto agudo miocardio ruptura ventricular| Hallazgo clínico',
#   0.9241436123847961),
#  ('58612006|infarto agudo miocardio pared lateral| Hallazgo clínico',
#   0.9224095940589905),
#  ('194856005|infarto miocardio subsecuente| Hallazgo clínico',
#   0.9207841157913208),
#  ('22298006|infarto miocardio| Hallazgo clínico', 0.9172461628913879),
#  ('304914007|infarto agudo miocardio tipo q| Hallazgo clínico',
#   0.9127337336540222),
#  ('15990001|infarto agudo miocardio pared posterolateral| Hallazgo clínico',
#   0.9123116731643677),
#  ('1755008|infarto miocardio cicatrizado| Hallazgo clínico',
#   0.9094552993774414),
#  ('73795002|infarto agudo miocardio pared diafragmatica| Hallazgo clínico',
#   0.9054713249206543),
#  ('426107000|infarto lacunar agudo| Hallazgo clínico', 0.8879565000534058),
#  ('70422006|infarto no transparietal agudo| Hallazgo clínico',
#   0.8832635283470154),
#  ('399211009|antecedente infarto miocardio| Situación con contexto explícito',
#   0.8830029964447021),
#  ('71023004|pericarditis secundaria a infarto agudo miocardio| Hallazgo clínico',
#   0.8828741312026978),
#  ('287292009|reseccion infarto miocardio| Procedimiento', 0.8827787637710571),
#  ('64627002|infarto agudo miocardio pared lateral alta| Hallazgo clínico',
#   0.8781012892723083),
#  ('307140009|infarto agudo miocardio sin onda q| Hallazgo clínico',
#   0.8768104314804077),
#  ('371068009|infarto miocardio complicacion| Hallazgo clínico',
#   0.8766334652900696),
#  ('282006|infarto agudo miocardio pared basal lateral| Hallazgo clínico',
#   0.8760626912117004),
#  ('233847009|ruptura cardiaca posterior a infarto agudo miocardio| Hallazgo clínico',
#   0.8745205402374268),
#  ('22323009|infarto agudo intestino| Hallazgo clínico', 0.8676855564117432),
#  ('113155009|educacion infarto miocardio| Procedimiento', 0.8672373294830322),
#  ('1755008|infarto antiguo miocardio| Hallazgo clínico', 0.866733968257904),
#  ('129574000|infarto miocardio posquirurgico| Hallazgo clínico',
#   0.8646068572998047),
#  ('394710008|primer infarto miocardio| Hallazgo clínico', 0.863639235496521),
#  ('371068009|infarto miocardio complicado| Hallazgo clínico',
#   0.8603136539459229),
#  ('194802003|infarto miocardio posterior verdadero| Hallazgo clínico',
#   0.8593559861183167),
#  ('233840006|infarto antiguo miocardio inferior| Hallazgo clínico',
#   0.8566742539405823),
#  ('194809007|infarto auricular agudo| Hallazgo clínico', 0.8522030115127563),
#  ('164865005|infarto miocardio electrocardiograma| Hallazgo clínico',
#   0.8507703542709351),
#  ('428752002|infarto miocardio reciente| Situación con contexto explícito',
#   0.8499342203140259),
#  ('194861007|ciertas complicaciones actuales luego infarto agudo miocardio| Hallazgo clínico',
#   0.8486815690994263),
#  ('401303003|infarto agudo miocardio elevacion segmento st| Hallazgo clínico',
#   0.8485604524612427),
#  ('73999000|infarto miocardio posterior ecg| Hallazgo clínico',
#   0.8473042249679565),
#  ('233842003|infarto antiguo miocardio posterior| Hallazgo clínico',
#   0.8463159799575806),
#  ('73999000|infarto miocardio posterior electrocardiograma| Hallazgo clínico',
#   0.8428478240966797),
#  ('194858006|infarto miocardio subsiguiente pared inferior| Hallazgo clínico',
#   0.8420763611793518),
#  ('194862000|hemopericardio complicacion actual luego infarto agudo miocardio| Hallazgo clínico',
#   0.8409944176673889),
#  ('401314000|infarto agudo miocardio sin elevacion segmento st| Hallazgo clínico',
#   0.8400895595550537),
#  ('233841005|infarto antiguo miocardio lateral| Hallazgo clínico',
#   0.8400701284408569),
#  ('58148009|miocardio subendocardico| Estructura corporal',
#   0.8393295407295227),
#  ('193145001|miocardio subendocardico| Estructura corporal',
#   0.8393295407295227),
#  ('193145001|miocardio subendocardico| Estructura corporal',
#   0.8393295407295227),
#  ('285721000119104|antecedente infarto agudo miocardio elevacion segmento st| Situación con contexto explícito',
#   0.8390383124351501),
#  ('233839009|infarto antigua miocardio anterior| Hallazgo clínico',
#   0.8379077911376953),
#  ('429731003|infarto miocardio anterior electrocardiograma| Hallazgo clínico',
#   0.8371927738189697),
#  ('7326005|infarto miocardio inferior electrocardiograma| Hallazgo clínico',
#   0.835988461971283),
#  ('15712961000119108|infarto agudo pared anteroseptal miocardio elevacion segmento st| Hallazgo clínico',
#   0.835929274559021),
#  ('194857001|infarto miocardio subsiguiente pared anterior| Hallazgo clínico',
#   0.8356539011001587),
#  ('723860000|arritmia complicacion actual despues infarto agudo miocardio| Hallazgo clínico',
#   0.835601806640625),
#  ('15713161000119100|infarto agudo tabique miocardio elevacion segmento st| Hallazgo clínico',
#   0.8350405693054199),
#  ('703251009|infarto agudo pared inferior miocardio compromiso ventriculo derecho| Hallazgo clínico',
#   0.8347796201705933),
#  ('233826005|infarto agudo no q anteroseptal| Hallazgo clínico',
#   0.8343251347541809),
#  ('703252002|infarto agudo pared anterior miocardio compromiso ventriculo derecho| Hallazgo clínico',
#   0.8320740461349487),
#  ('85844000|infarto transparietal| Estructura corporal', 0.8313250541687012),
#  ('15960981000119105|trombo mural ventriculo izquierdo posterior a infarto agudo miocardio| Hallazgo clínico',
#   0.8294323682785034),
#  ('281093002|miocardio hibernante| Hallazgo clínico', 0.8279250264167786),
#  ('736978009|trombo mural ventriculo derecho posterior a infarto agudo miocardio| Hallazgo clínico',
#   0.8276636600494385),
#  ('15713201000119105|infarto agudo miocardio pared posterobasal elevacion segmento st| Hallazgo clínico',
#   0.8275445103645325),
#  ('723858002|aneurisma ventricular complicacion actual posterior a infarto agudo miocardio| Hallazgo clínico',
#   0.825344443321228),
#  ('233832000|infarto agudo no q inferolateral| Hallazgo clínico',
#   0.8228604793548584),
#  ('15713041000119103|infarto agudo pared posterior miocardio elevacion segmento st| Hallazgo clínico',
#   0.8225688338279724),
#  ('15712881000119105|infarto agudo pared anterolateral miocardio elevacion segmento st| Hallazgo clínico',
#   0.8223464488983154),
#  ('233828006|infarto agudo no q anterolateral| Hallazgo clínico',
#   0.8220789432525635),
#  ('15712921000119103|infarto agudo pared lateral miocardio elevacion segmento st| Hallazgo clínico',
#   0.8206890821456909),
#  ('703213009|infarto agudo pared inferior miocardio elevacion segmento st| Hallazgo clínico',
#   0.8205245733261108),
#  ('703164000|infarto agudo pared anterior miocardio elevacion segmento st| Hallazgo clínico',
#   0.8193605542182922),
#  ('164867002|infarto miocardio antiguo electrocardiograma| Hallazgo clínico',
#   0.8192769289016724),
#  ('10273003|infarto agudo musculo papilar| Hallazgo clínico',
#   0.8180574774742126),
#  ('15712841000119100|infarto agudo pared posterolateral miocardio elevacion segmento st| Hallazgo clínico',
#   0.817375659942627),
#  ('233837006|infarto agudo no q masivo| Hallazgo clínico', 0.8172640800476074),
#  ('31092005|infarto zahn| Estructura corporal', 0.8163734078407288),
#  ('55641003|infarto| Estructura corporal', 0.8163734078407288),
#  ('81037000|infarto lagunar| Estructura corporal', 0.8149996399879456),
#  ('164865005|electrocardiograma : infarto miocardio| Hallazgo clínico',
#   0.8145747184753418),
#  ('266897007|antecedente familiar infarto miocardio| Situación con contexto explícito',
#   0.8135749101638794),
#  ('233830008|infarto agudo no q inferior| Hallazgo clínico',
#   0.8135538697242737),
#  ('22323009|infarto intestinal agudo| Hallazgo clínico', 0.8132245540618896),
#  ('74281007|miocardio| Estructura corporal', 0.8098224997520447),
#  ('362012001|miocardio| Estructura corporal', 0.8098224997520447),
#  ('362012001|miocardio| Estructura corporal', 0.8098224997520447),
#  ('230692004|infarto precerebral| Hallazgo clínico', 0.8097822666168213),
#  ('723859005|embolia pulmonar complicacion actual despues infarto agudo miocardio| Hallazgo clínico',
#   0.8091709613800049),
#  ('233825009|infarto agudo onda q anteroseptal| Hallazgo clínico',
#   0.8091707825660706),
#  ('71911007|infarto cicatrizado| Estructura corporal', 0.8091146945953369),
#  ('703326006|insuficiencia valvula mitral debida a infarto agudo miocardio| Hallazgo clínico',
#   0.8043205738067627),
#  ('314207007|infarto miocardio sin onda q| Hallazgo clínico',
#   0.8038613796234131),
#  ('194867006|ruptura musculo papilar complicacion actual luego infarto agudo miocardio| Hallazgo clínico',
#   0.8036553859710693),
#  ('233834004|infarto agudo no q lateral| Hallazgo clínico',
#   0.8010547757148743),
#  ('23311000119105|infarto agudo miocardio debido a oclusion arteria coronaria derecha| Hallazgo clínico',
#   0.7998677492141724),
#  ('17531000119105|infarto agudo miocardio debido a oclusion arteria coronaria izquierda| Hallazgo clínico',
#   0.7994922995567322),
#  ('233831007|infarto agudo onda q inferolateral| Hallazgo clínico',
#   0.7965803146362305),
#  ('85844000|infarto a traves miocardio| Estructura corporal',
#   0.795068085193634),
#  ('233827001|infarto agudo onda q anterolateral| Hallazgo clínico',
#   0.7949119806289673),
#  ('703326006|regurgitacion valvula mitral debida a infarto agudo miocardio| Hallazgo clínico',
#   0.7940689325332642),
#  ('233836002|infarto agudo onda q masivo| Hallazgo clínico',
#   0.7936623096466064),
#  ('233829003|infarto agudo onda q inferior| Hallazgo clínico',
#   0.7917670011520386),
#  ('281092007|miocardio aturdido| Hallazgo clínico', 0.7891125679016113),
#  ('63081009|infarto agudo medula espinal| Hallazgo clínico',
#   0.7885481119155884),
#  ('77255002|infarto trombotico| Hallazgo clínico', 0.7870808243751526),
#  ('233833005|infarto agudo onda q lateral| Hallazgo clínico',
#   0.7853724360466003),
#  ('58148009|estructura miocardio subendocardico| Estructura corporal',
#   0.7835079431533813),
#  ('194866002|ruptura cuerdas tendinosas complicacion actual luego infarto agudo miocardio| Hallazgo clínico',
#   0.7834941148757935),
#  ('194865003|ruptura pared cardiaca sin hemopericardio complicacion actual luego infarto agudo miocardio| Hallazgo clínico',
#   0.7807440757751465),
#  ('703165004|infarto agudo pared anterior miocardio elevacion segmento st compromiso ventriculo derecho| Hallazgo clínico',
#   0.7786815762519836),
#  ('38640009|infarto anemico| Estructura corporal', 0.7785650491714478),
#  ('103011000119106|arteriosclerosis coronaria paciente antecedente infarto miocardio| Situación con contexto explícito',
#   0.7775182723999023),
#  ('72647007|infarto masivo| Estructura corporal', 0.7744879126548767),
#  ('194863005|defecto tabique auricular complicacion actual luego infarto agudo miocardio| Hallazgo clínico',
#   0.7742780447006226),
#  ('37906005|infarto embolico| Hallazgo clínico', 0.7733335494995117),
#  ('703253007|infarto agudo pared inferior miocardio elevacion segmento st y compromiso ventriculo derecho| Hallazgo clínico',
#   0.7712229490280151),
#  ('233843008|infarto miocardico silente| Hallazgo clínico',
#   0.7703673243522644),
#  ('194821006|trombosis coronaria no deriva infarto miocardio| Hallazgo clínico',
#   0.7703454494476318),
#  ('32574007|infarto miocardio diagnosticado ecg sin presentar sintomas| Hallazgo clínico',
#   0.7684295177459717),
#  ('75204008|infarto omental| Hallazgo clínico', 0.7675869464874268),
#  ('315287002|infusion insulina glucosa diabetes mellitus infarto agudo miocardio| Procedimiento',
#   0.7664576768875122),
#  ('95830009|infarto pituitario| Hallazgo clínico', 0.7654243111610413),
#  ('703211006|infarto miocardio elevacion ulterior segmento st| Hallazgo clínico',
#   0.7639850974082947),
#  ('315287002|infusion insulina glucosa poe diabetes mellitus infarto agudo miocardio| Procedimiento',
#   0.7631622552871704),
#  ('126732009|neoplasia miocardio| Hallazgo clínico', 0.7629678249359131),
#  ('15713121000119105|infarto agudo miocardio elevacion segmento st debido a oclusion arteria coronaria derecha| Hallazgo clínico',
#   0.7624359130859375),
#  ('15713081000119108|infarto agudo miocardio elevacion segmento st debido a oclusion arteria coronaria izquierda| Hallazgo clínico',
#   0.7622414827346802),
#  ('66189004|sindrome postinfarto miocardio| Hallazgo clínico',
#   0.7608691453933716),
#  ('722985001|infarto venoso agudo medula espinal| Hallazgo clínico',
#   0.7602961659431458),
#  ('703360004|infarto miocardio sin elevacion ulterior segmento st| Hallazgo clínico',
#   0.7585338354110718),
#  ('19914004|miocardio posterior| Estructura corporal', 0.7582575082778931),
#  ('192986001|miocardio posterior| Estructura corporal', 0.7582575082778931),
#  ('192986001|miocardio posterior| Estructura corporal', 0.7582575082778931),
#  ('427296003|infarto talamico| Hallazgo clínico', 0.7582335472106934),
#  ('6975006|miocardio anterior| Estructura corporal', 0.7574911117553711),
#  ('192901008|miocardio anterior| Estructura corporal', 0.7574911117553711),
#  ('192901008|miocardio anterior| Estructura corporal', 0.7574911117553711),
#  ('311796008|infarto miocardico subendocardico posquirurgico| Hallazgo clínico',
#   0.7571817636489868),
#  ('698593009|antecedente infarto miocardio sin elevacion segmento st| Situación con contexto explícito',
#   0.7571060657501221),
#  ('314003000|infarto coroideo| Hallazgo clínico', 0.7570397853851318),
#  ('81037000|infarto lacunar| Estructura corporal', 0.7566437125205994),
#  ('230698000|infarto lacunar| Hallazgo clínico', 0.7566437125205994),
#  ('57809008|enfermedad miocardio| Hallazgo clínico', 0.7531174421310425),
#  ('192897002|mielopatia infarto agudo medula espinal| Hallazgo clínico',
#   0.7526353597640991),
#  ('285981000119103|infarto agudo miocardio elevacion segmento st afecta a arteria coronaria descendente anterior izquierda| Hallazgo clínico',
#   0.752548336982727),
#  ('190513003|miocardio region anteroseptal| Estructura corporal',
#   0.7521957159042358),
#  ('190513003|miocardio region anteroseptal| Estructura corporal',
#   0.7521957159042358),
#  ('22298006|infarto cardiaco| Hallazgo clínico', 0.7519910335540771),
#  ('28208008|infarto edematoso| Estructura corporal', 0.750359058380127),
#  ('238560007|podoponfolix agudo| Hallazgo clínico', 0.7503329515457153),
#  ('70627009|reseccion miocardio| Procedimiento', 0.7497371435165405),
#  ('903008|infarto coriorretiniana| Hallazgo clínico', 0.7492654323577881),
#  ('723861001|choque cardiogenico no relacionado complicaciones mecanicas complicacion curso posterior a infarto agudo miocardio| Hallazgo clínico',
#   0.74824059009552),
#  ('723861001|shock cardiogenico no relacionado complicaciones mecanicas complicacion actual posterior a infarto agudo miocardio| Hallazgo clínico',
#   0.7477256655693054),
#  ('25106000|infarto inminente| Hallazgo clínico', 0.7473140954971313),
#  ('193068007|miocardio lateral| Estructura corporal', 0.7467529773712158),
#  ('193068007|miocardio lateral| Estructura corporal', 0.7467529773712158),
#  ('273000|miocardio lateral| Estructura corporal', 0.7467529773712158),
#  ('164868007|infarto anteroseptal electrocardiograma| Hallazgo clínico',
#   0.7461836338043213),
#  ('703209002|infarto pared inferior miocardio elevacion ulterior segmento st| Hallazgo clínico',
#   0.7447575926780701),
#  ('723861001|choque cardiogenico no relacionado complicaciones mecanicas complicacion actual posterior a infarto agudo miocardio| Hallazgo clínico',
#   0.7445355653762817),
#  ('285991000119100|infarto agudo miocardio elevacion segmento st afecta a arteria coronaria izquierda principal| Hallazgo clínico',
#   0.7442354559898376),
#  ('703210007|infarto pared anterior miocardio elevacion ulterior segmento st| Hallazgo clínico',
#   0.7439358830451965),
#  ('3558002|infarto mesenterico| Hallazgo clínico', 0.7427311539649963),
#  ('78741000119103|oclusion coronaria aguda no ocasiona infarto miocardio| Hallazgo clínico',
#   0.7425882816314697),
#  ('64662007|infarto pulmonar| Hallazgo clínico', 0.7423499822616577),
#  ('74281007|estructura miocardio| Estructura corporal', 0.7415814995765686),
#  ('74310003|infarto hemorragico| Estructura corporal', 0.7408972978591919),
#  ('35696001|infarto roto| Estructura corporal', 0.7399318218231201),
#  ('71911007|infarto antiguo| Estructura corporal', 0.739709734916687),
#  ('405547004|absceso miocardio| Hallazgo clínico', 0.7386828660964966),
#  ('461000119108|antecedente infarto miocardio ultimas ocho semanas| Situación con contexto explícito',
#   0.7383108139038086),
#  ('190852001|miocardio region inferolateral| Estructura corporal',
#   0.7377640008926392),
#  ('16239001|miocardio region inferolateral| Estructura corporal',
#   0.7377640008926392),
#  ('190852001|miocardio region inferolateral| Estructura corporal',
#   0.7377640008926392),
#  ('194868001|trombosis auricular ventricular y apendice auricular complicacion actual luego infarto agudo miocardio| Hallazgo clínico',
#   0.7371848821640015),
#  ('308065005|antecedente : infarto miocardio ultimo año| Situación con contexto explícito',
#   0.7359467148780823),
#  ('251052000|miocardio hallazgo| Hallazgo clínico', 0.7358734607696533),
#  ('268585006|infarto placentario| Hallazgo clínico', 0.735701322555542),
#  ('161502000|antecedente : infarto miocardio 60 años| Situación con contexto explícito',
#   0.7339385747909546),
#  ('164870003|infarto sudendocardico electrocardiograma| Hallazgo clínico',
#   0.7338755130767822),
#  ('230701008|infarto lacunar sensoriomotor puro| Hallazgo clínico',
#   0.7321951985359192),
#  ('275122004|antecedente familiar infarto miocardio 60 años| Situación con contexto explícito',
#   0.7309768199920654),
#  ('723082006|infarto cerebral silencioso| Hallazgo clínico',
#   0.7300062775611877),
#  ('432504007|infarto cerebral| Hallazgo clínico', 0.7292909622192383),
#  ('710031008|isquemia inducible manifiesta prueba esfuerzo posterior a infarto miocardio| Hallazgo clínico',
#   0.7292560338973999),
#  ('22298006|infarto corazon| Hallazgo clínico', 0.7287982702255249),
#  ('235852001|infarto transmural intestino| Hallazgo clínico',
#   0.7284425497055054),
#  ('66189004|pericarditis posinfarto miocardio| Hallazgo clínico',
#   0.7271218299865723),
#  ('64662007|infarto pulmon| Hallazgo clínico', 0.7267066836357117),
#  ('737438001|plan manejo clinico infarto miocardio| Objeto físico',
#   0.7249003648757935),
#  ('63884000|fallo agudo| Hallazgo clínico', 0.722671627998352),
#  ('80475003|infarto mesenterico trombotico| Hallazgo clínico',
#   0.7218190431594849),
#  ('387828005|biopsia miocardio| Procedimiento', 0.7208716869354248),
#  ('45456005|infarto renal| Hallazgo clínico', 0.7207803726196289),
#  ('192084000|miocardio ventriculo| Estructura corporal', 0.7207777500152588),
#  ('192084000|miocardio ventriculo| Estructura corporal', 0.7207777500152588),
#  ('418044006|infarto miocardio fase recuperacion| Hallazgo clínico',
#   0.7207581996917725),
#  ('703330009|insuficiencia valvula mitral debida a infarto agudo miocardio ruptura musculo papilar y cuerdas tendinosas| Hallazgo clínico',
#   0.7200818061828613),
#  ('428752002|infarto miocardico reciente| Situación con contexto explícito',
#   0.7199380397796631),
#  ('238550003|quiropodoponfolix agudo| Hallazgo clínico', 0.7197264432907104),
#  ('238550003|queiropodoponfolix agudo| Hallazgo clínico', 0.7197264432907104),
#  ('75204008|infarto epiplon| Hallazgo clínico', 0.7195330262184143),
#  ('75204008|infarto epiplon| Hallazgo clínico', 0.7195330262184143),
#  ('24728001|incision miocardio| Procedimiento', 0.7186602354049683),
#  ('233823002|isquemia miocardio silente| Hallazgo clínico',
#   0.7179946899414062),
#  ('60007006|infarto multifocal| Estructura corporal', 0.7177954912185669),
#  ('35696001|infarto perforado| Estructura corporal', 0.717479407787323),
#  ('7872004|miocardio ventricular| Estructura corporal', 0.7171562910079956),
#  ('83727005|infarto pulmonar hemorragico| Hallazgo clínico',
#   0.7167540192604065),
#  ('57658009|infarto mesenterico embolico| Hallazgo clínico',
#   0.7164968252182007),
#  ('119377007|especimen miocardio| Espécimen', 0.716060996055603),
#  ('161502000|antecedente : infarto miocardio menores 60 años| Situación con contexto explícito',
#   0.7156504988670349),
#  ('164869004|infarto posteroinferior electrocardiograma| Hallazgo clínico',
#   0.7156233787536621),
#  ('429391004|nuevo infarto miocardio comparacion estudio previo| Hallazgo clínico',
#   0.7155383825302124),
#  ('311793000|infarto miocardico transmural pared inferior posquirurgico| Hallazgo clínico',
#   0.7154159545898438),
#  ('190441001|miocardio region posteroseptal| Estructura corporal',
#   0.7151236534118652),
#  ('190441001|miocardio region posteroseptal| Estructura corporal',
#   0.7151236534118652),
#  ('703330009|regurgitacion valvula mitral debida a infarto agudo miocardio ruptura musculo papilar y cuerdas tendinosas| Hallazgo clínico',
#   0.7145636081695557),
#  ('418918009|infarto macular| Hallazgo clínico', 0.7144484519958496),
#  ('22996003|infarto esplenico| Hallazgo clínico', 0.7134044766426086),
#  ('703328007|insuficiencia valvula mitral debida a infarto agudo miocardio sin ruptura musculo papilar y cuerdas tendinosas| Hallazgo clínico',
#   0.7129731178283691),
#  ('164868007|electrocardiograma : infarto anteroseptal| Hallazgo clínico',
#   0.7127277851104736),
#  ('119377007|muestra miocardio| Espécimen', 0.7126021981239319),
#  ('311792005|infarto miocardico transmural pared anterior posquirurgico| Hallazgo clínico',
#   0.7120711803436279),
#  ('79770005|infarto septico| Estructura corporal', 0.7118089199066162),
#  ('371824008|isquemia miocardica manifiesta prueba estres realizada despues infarto miocardio| Hallazgo clínico',
#   0.7114191055297852),
#  ('45456005|infarto riñon| Hallazgo clínico', 0.7112872004508972),
#  ('95460007|infarto cerebeloso| Hallazgo clínico', 0.7099875807762146),
#  ('164868007|ecg : infarto anteroseptal| Hallazgo clínico',
#   0.7099189758300781),
#  ('703328007|regurgitacion valvula mitral debida a infarto agudo miocardio sin ruptura musculo papilar y cuerdas tendinosas| Hallazgo clínico',
#   0.7080816030502319),
#  ('164871004|infarto lateral electrocardiograma| Hallazgo clínico',
#   0.7073658108711243),
#  ('77296004|infarto mama| Hallazgo clínico', 0.7067193984985352),
#  ('230706003|infarto cerebral hemorragico| Hallazgo clínico',
#   0.7064623832702637),
#  ('3129009|infarto ovario| Hallazgo clínico', 0.7064313888549805),
#  ('3129009|infarto ovario| Hallazgo clínico', 0.7064313888549805),
#  ('161503005|antecedente : infarto miocardio mayores 60 años| Situación con contexto explícito',
#   0.7063151597976685),
#  ('52481007|infarto evolucion| Estructura corporal', 0.7062722444534302),
#  ('235851008|infarto hemorragico intestino| Hallazgo clínico',
#   0.7059931755065918),
#  ('13570001000004105|infarto recto| Hallazgo clínico', 0.70546555519104),
#  ('164870003|ecg : infarto subendocardico| Hallazgo clínico',
#   0.7050907611846924),
#  ('449758002|infarto traumatico| Estructura corporal', 0.7047200798988342),
#  ('275123009|antecedente familiar infarto miocardio despues 60 años| Situación con contexto explícito',
#   0.7046143412590027),
#  ('161503005|antecedente : infarto miocardio despues 60 años| Situación con contexto explícito',
#   0.7045923471450806),
#  ('55470003|infarto reciente| Estructura corporal', 0.704116702079773),
#  ('56229006|infarto difuso| Estructura corporal', 0.7037809491157532),
#  ('17890003|infarto higado| Hallazgo clínico', 0.7025474309921265),
#  ('98641000119100|broncoespasmo agudo| Hallazgo clínico', 0.7021416425704956),
#  ('164865005|ecg : infarto miocardico| Hallazgo clínico', 0.70182204246521),
#  ('10971000087107|isquemia miocardio cirugia| Hallazgo clínico',
#   0.7017228603363037),
#  ('164865005|electrocardiograma : infarto miocardico| Hallazgo clínico',
#   0.701262354850769),
#  ('85503007|injerto omento miocardio| Procedimiento', 0.7004109621047974),
#  ('413444003|isquemia aguda miocardio| Hallazgo clínico', 0.6995809078216553),
#  ('233885007|pericarditis posterior a infarto| Hallazgo clínico',
#   0.6991044282913208),
#  ('28536002|megacolon agudo| Hallazgo clínico', 0.6987020373344421),
#  ('19914004|estructura miocardio posterior| Estructura corporal',
#   0.6974759101867676),
#  ('723005006|efluvio telogeno agudo| Hallazgo clínico', 0.697396993637085),
#  ('18131002|agudo fulminante| Calificador', 0.6969171762466431),
#  ('3129009|infarto ovarico| Hallazgo clínico', 0.696506142616272),
#  ('33793000|infarto testiculo| Hallazgo clínico', 0.6963160634040833),
#  ('33793000|infarto testiculo| Hallazgo clínico', 0.6963160634040833),
#  ('17890003|infarto hepatico| Hallazgo clínico', 0.6961150765419006),
#  ('41380003|estudio rastreo radioisotopos deteccion infarto miocardio| Procedimiento',
#   0.6960817575454712),
#  ('73050001|miocardio region anterolateral| Estructura corporal',
#   0.6955932378768921),
#  ('190762001|miocardio region anterolateral| Estructura corporal',
#   0.6955932378768921),
#  ('190762001|miocardio region anterolateral| Estructura corporal',
#   0.6955932378768921),
#  ('95830009|infarto hipofisis| Hallazgo clínico', 0.6946139335632324),
#  ('67875004|grito agudo| Hallazgo clínico', 0.6936080455780029),
#  ('16239001|estructura miocardio region inferolateral| Estructura corporal',
#   0.6933243274688721),
#  ('413844008|isquemia cronica miocardio| Hallazgo clínico',
#   0.6930948495864868),
#  ('164867002|ecg : infarto miocardico antiguo| Hallazgo clínico',
#   0.6930060386657715),
#  ('240828008|absceso filarial agudo malasia| Hallazgo clínico',
#   0.6924673318862915),
#  ('6975006|estructura miocardio anterior| Estructura corporal',
#   0.6914675235748291),
#  ('19365003|empiema agudo| Estructura corporal', 0.6910803914070129),
#  ('273000|estructura miocardio lateral| Estructura corporal',
#   0.6910457015037537),
#  ('164861001|isquemia miocardio electrocardiograma| Hallazgo clínico',
#   0.6909373998641968),
#  ('80377005|escision aneurisma miocardio| Procedimiento', 0.6898228526115417),
#  ('109602002|absceso dentoalveolar agudo| Hallazgo clínico',
#   0.689710259437561),
#  ('164867002|electrocardiograma : infarto miocardico antiguo| Hallazgo clínico',
#   0.6895917654037476),
#  ('192038005|fuga agudo reaccion estres agudo| Hallazgo clínico',
#   0.6895669102668762),
#  ('17475005|miocardio auricular| Estructura corporal', 0.6895208358764648),
#  ('91862002|absceso paradontal agudo| Hallazgo clínico', 0.6888435482978821),
#  ('116034001|absceso agudo| Estructura corporal', 0.6888435482978821),
#  ('164869004|electrocardiograma : infarto posterior/inferior| Hallazgo clínico',
#   0.6872637867927551),
#  ('240126009|infarto muscular isquemico| Hallazgo clínico',
#   0.6856497526168823),
#  ('56675007|fallo cardiaco agudo| Hallazgo clínico', 0.6856000423431396),
#  ('164870003|electrocardiograma : infarto sudendocardico| Hallazgo clínico',
#   0.6853479146957397),
#  ('275508008|infarto colonico| Hallazgo clínico', 0.685279130935669),
#  ('77296004|infarto mamario| Hallazgo clínico', 0.6851743459701538),
#  ('192037000|panico agudo reaccion estres agudo| Hallazgo clínico',
#   0.684471607208252),
#  ('64077000|degeneracion miocardio| Hallazgo clínico', 0.6842809915542603),
#  ('164866006|electrocardiograma : sin infarto miocardico| Hallazgo clínico',
#   0.6842764616012573),
#  ('164866006|ecg : sin infarto miocardico| Hallazgo clínico',
#   0.6839508414268494),
#  ('697976003|isquemia microvascular miocardio| Hallazgo clínico',
#   0.6838310956954956),
#  ('315622004|antecedente familiar infarto miocardio femenino primer grado edad desconocida| Situación con contexto explícito',
#   0.6836054921150208),
#  ('164869004|ecg : infarto posterior/inferior| Hallazgo clínico',
#   0.6826820373535156),
#  ('85108007|catarro tubotimpanico agudo| Hallazgo clínico',
#   0.6823081374168396),
#  ('240833007|absceso filariasico agudo timoriano| Hallazgo clínico',
#   0.6815629601478577),
#  ('315621006|antecedente familiar infarto miocardio femenino primer grado edad conocida| Situación con contexto explícito',
#   0.6807035207748413),
#  ('47292005|tuberculosis miocardio| Hallazgo clínico', 0.6797633767127991),
#  ('43618000|infarto microscopico| Estructura corporal', 0.6797051429748535),
#  ('85096001|infarto suprarrenal| Hallazgo clínico', 0.6796501874923706),
#  ('192039002|estupor agudo reaccion a estres agudo| Hallazgo clínico',
#   0.6782751083374023),
#  ('315619001|antecedente familiar infarto miocardio masculino primer grado edad conocida| Situación con contexto explícito',
#   0.6778756976127625),
#  ('47559000|infarto zona divisoria| Estructura corporal', 0.6775710582733154),
#  ('230699008|infarto lacunar motor puro| Hallazgo clínico',
#   0.6774659156799316),
#  ('191501001|confusional agudo postraumatico| Hallazgo clínico',
#   0.677114725112915),
#  ('22035000|infarto prostata| Hallazgo clínico', 0.6769181489944458),
#  ('85096001|infarto adrenal| Hallazgo clínico', 0.6762878894805908),
#  ('192038005|fuga agudo reaccion a estres agudo| Hallazgo clínico',
#   0.6758743524551392),
#  ('32574007|infarto miocardio antiguo diagnosticado electrocardiograma y/u metodo complementario actualmente asintomatico| Hallazgo clínico',
#   0.6756027936935425),
#  ('191910002|miocardio auricula| Estructura corporal', 0.675564169883728),
#  ('191910002|miocardio auricula| Estructura corporal', 0.675564169883728),
#  ('195243003|secuelas infarto cerebral| Hallazgo clínico', 0.6751528978347778),
#  ('236490006|infarto renal arterial| Hallazgo clínico', 0.6748865842819214),
#  ('25702006|alcoholismo agudo| Hallazgo clínico', 0.6746678352355957),
#  ('72940007|absceso areolar agudo| Hallazgo clínico', 0.6745338439941406),
#  ('22996003|infarto bazo| Hallazgo clínico', 0.6744612455368042),
#  ('190593002|miocardio region diafragmatica| Estructura corporal',
#   0.6744140386581421),
#  ('72542009|miocardio region diafragmatica| Estructura corporal',
#   0.6744140386581421),
#  ('190593002|miocardio region diafragmatica| Estructura corporal',
#   0.6744140386581421),
#  ('72940007|absceso agudo areola| Hallazgo clínico', 0.6735389232635498),
#  ('25263003|injerto miocardio revascularizacion| Procedimiento',
#   0.6732797622680664),
#  ('22035000|infarto prostatico| Hallazgo clínico', 0.6719539165496826),
#  ('189283000|miocardio tabique ventricular| Estructura corporal',
#   0.671901524066925),
#  ('189283000|miocardio tabique ventricular| Estructura corporal',
#   0.671901524066925),
#  ('192037000|panico agudo reaccion a estres agudo| Hallazgo clínico',
#   0.6715925335884094),
#  ('164871004|ecg : infarto lateral| Hallazgo clínico', 0.6715857982635498),
#  ('109602002|absceso periapical agudo| Hallazgo clínico', 0.6705402135848999),
#  ('33272004|miocardio region posterolateral| Estructura corporal',
#   0.6703612804412842),
#  ('190685007|miocardio region posterolateral| Estructura corporal',
#   0.6703612804412842),
#  ('190685007|miocardio region posterolateral| Estructura corporal',
#   0.6703612804412842),
#  ('88380005|sindrome lactoalcalino agudo| Hallazgo clínico',
#   0.6702637672424316),
#  ('230696001|infarto circulacion cerebral posterior| Hallazgo clínico',
#   0.6699844598770142),
#  ('84437006|neumotorax agudo| Hallazgo clínico', 0.6697158217430115),
#  ('36560003|infarto quistico| Estructura corporal', 0.6696974635124207),
#  ('49848007|miocardio ventriculo izquierdo| Estructura corporal',
#   0.6694008708000183),
#  ('362021000|miocardio ventriculo izquierdo| Estructura corporal',
#   0.6694008708000183),
#  ('362021000|miocardio ventriculo izquierdo| Estructura corporal',
#   0.6694008708000183),
#  ('240828008|absceso filariasico agudo malasia| Hallazgo clínico',
#   0.6689314246177673),
#  ('81077008|reuma articular agudo| Hallazgo clínico', 0.6683371663093567),
#  ('164871004|electrocardiograma : infarto lateral| Hallazgo clínico',
#   0.6680349111557007),
#  ('23671000119107|secuela infarto cerebral isquemico| Hallazgo clínico',
#   0.6675519347190857),
#  ('362020004|miocardio ventriculo derecho| Estructura corporal',
#   0.6658231019973755),
#  ('362020004|miocardio ventriculo derecho| Estructura corporal',
#   0.6658231019973755),
#  ('22050009|miocardio ventriculo derecho| Estructura corporal',
#   0.6658231019973755),
#  ('230708002|infarto hemorragico circulacion cerebral posterior| Hallazgo clínico',
#   0.6654509902000427),
#  ('429235008|antecedente infarto cerebral cardioembolico| Situación con contexto explícito',
#   0.6651014089584351),
#  ('445760005|esguince agudo cuello| Hallazgo clínico', 0.6650820970535278),
#  ('93914000|neoplasia maligna miocardio| Hallazgo clínico',
#   0.6645807027816772),
#  ('10633002|fallo cardiaco congestivo agudo| Hallazgo clínico',
#   0.6642225980758667),
#  ('230693009|infarto circulacion cerebral anterior| Hallazgo clínico',
#   0.6640653610229492),
#  ('39848009|estrema cervical agudo| Hallazgo clínico', 0.6638328433036804),
#  ('230707007|infarto hemorragico circulacion cerebral anterior| Hallazgo clínico',
#   0.6638185977935791),
#  ('26424001|ataque reumatico agudo| Hallazgo clínico', 0.6630951166152954),
#  ('722986000|infarto venoso cronico medula espinal| Hallazgo clínico',
#   0.663053572177887),
#  ('95830009|infarto hipofisario| Hallazgo clínico', 0.6623325347900391),
#  ('396348002|eczema agudo| Hallazgo clínico', 0.6617730259895325),
#  ('195501006|infarto vaso linfatico| Hallazgo clínico', 0.6617575883865356),
#  ('73050001|estructura miocardio region anterolateral| Estructura corporal',
#   0.6607721447944641),
#  ('43630006|signos electrocardiograficos infarto anterolateral| Hallazgo clínico',
#   0.6607484817504883),
#  ('10846005|miocardio region posterior tabique| Estructura corporal',
#   0.6606712341308594),
#  ('71292007|infarto antiguo y reciente| Estructura corporal',
#   0.6606398224830627),
#  ('251272004|espesor miocardio| Entidad observable', 0.6590319871902466),
#  ('109602002|absceso apical agudo| Hallazgo clínico', 0.6589955687522888),
#  ('240833007|absceso filariasico agudo timor| Hallazgo clínico',
#   0.6549153923988342),
#  ('304527002|asma agudo| Hallazgo clínico', 0.6548541784286499),
#  ('65710008|fallo respiratorio agudo| Hallazgo clínico', 0.6546709537506104),
#  ('85503007|injerto epiplon miocardio| Procedimiento', 0.6544129848480225),
#  ('472322002|trastorno miocardio fetal| Hallazgo clínico', 0.6539369225502014),
#  ('307766002|infarto hemisferio cerebral izquierdo| Hallazgo clínico',
#   0.6538883447647095),
#  ('47559000|infarto zona vascular divisoria| Estructura corporal',
#   0.6532523036003113),
#  ('20706007|miocardio region anterior tabique| Estructura corporal',
#   0.6530138254165649),
#  ('11859008|infarto tiroideo| Hallazgo clínico', 0.6529145240783691),
#  ('33793000|infarto testicular| Hallazgo clínico', 0.6520827412605286),
#  ('92238001|neoplasia benigna miocardio| Hallazgo clínico', 0.652033805847168),
#  ('1077002|signos electrocardiograficos infarto septal| Hallazgo clínico',
#   0.6517417430877686),
#  ('236491005|infarto renal venoso| Hallazgo clínico', 0.6514009833335876),
#  ('212438008|absceso agudo cara| Hallazgo clínico', 0.6508779525756836),
#  ('73999000|signos electrocardiograficos infarto posterior| Hallazgo clínico',
#   0.6504451036453247),
#  ('384993003|infarto venoso hemorragico periventricular| Hallazgo clínico',
#   0.6503512859344482),
#  ('307767006|infarto hemisferio cerebral derecho| Hallazgo clínico',
#   0.6503063440322876),
#  ('192042008|estres postraumatico agudo| Hallazgo clínico',
#   0.6491408348083496),
#  ('195185009|infarto cerebral trombosis arterias precerebrales| Hallazgo clínico',
#   0.6491403579711914),
#  ('81077008|reumatismo articular agudo| Hallazgo clínico', 0.6489697098731995),
#  ('233706004|edema pulmonar agudo farmacogeno| Hallazgo clínico',
#   0.6481748819351196),
#  ('417017003|sindrome cerebeloso agudo| Hallazgo clínico', 0.6475051045417786),
#  ('41466009|estudio imagenes miocardio fraccion eyeccion deteccion infarto tecnica primer pase| Procedimiento',
#   0.6471606492996216),
#  ('233846000|defecto ventricular septal posterior a infarto| Hallazgo clínico',
#   0.6471576690673828),
#  ('230700009|infarto lacunar sensitivo puro| Hallazgo clínico',
#   0.6470617651939392),
#  ('471863000|trastorno miocardio debido a hemoglobinopatia drepanocitica| Hallazgo clínico',
#   0.6463251113891602),
#  ('39848009|esguince cervical agudo| Hallazgo clínico', 0.6461750268936157),
#  ('445760005|esguince cervical agudo| Hallazgo clínico', 0.6461750268936157),
#  ('276219001|infarto cerebral occipital| Hallazgo clínico',
#   0.6461268067359924),
#  ('194750008|degeneracion reumatica miocardio| Hallazgo clínico',
#   0.6458439826965332),
#  ('197119006|estreñimiento agudo| Hallazgo clínico', 0.6458152532577515),
#  ('13570001000004105|infarto rectal| Hallazgo clínico', 0.6457788944244385),
#  ('72542009|estructura miocardio region diafragmatica| Estructura corporal',
#   0.6457444429397583),
#  ('7872004|miocardio ventriculo corazon| Estructura corporal',
#   0.644443154335022),
#  ('7326005|signos electrocardiograficos infarto inferior| Hallazgo clínico',
#   0.6442660689353943),
#  ('403177004|ampolla edema agudo| Hallazgo clínico', 0.6432850360870361),
#  ('230602005|infarto embolico tronco nervioso| Hallazgo clínico',
#   0.6432183980941772),
#  ('471875005|miocardiopatia no compactada miocardio ventricular| Hallazgo clínico',
#   0.6429526805877686),
#  ('195186005|infarto cerebral embolia arterias precerebrales| Hallazgo clínico',
#   0.6427886486053467),
#  ('440697006|antecedente familiar infarto cerebral| Situación con contexto explícito',
#   0.6427546739578247),
#  ('275104002|antecedente familiar infarto cerebral| Situación con contexto explícito',
#   0.6427546739578247),
#  ('40829002|edema agudo| Estructura corporal', 0.642657995223999),
#  ('102587001|dolor pecho agudo| Hallazgo clínico', 0.6418101787567139),
#  ('49848007|estructura miocardio ventriculo izquierdo| Estructura corporal',
#   0.6404310464859009),
#  ('402491006|calcinosis luego infarto venoso/arterial| Hallazgo clínico',
#   0.6400704383850098),
#  ('33272004|estructura miocardio region posterolateral| Estructura corporal',
#   0.6399719715118408),
#  ('230695002|infarto parcial cerebral anterior| Hallazgo clínico',
#   0.6393386721611023),
#  ('46421000119102|trastorno comportamiento secuela infarto cerebral| Hallazgo clínico',
#   0.6392567157745361),
#  ('8573003|sangrado agudo| Estructura corporal', 0.6385805606842041),
#  ('726039004|tejido intersticial miocardio| Estructura corporal',
#   0.6384795904159546),
#  ('7076002|tejido intersticial miocardio| Estructura corporal',
#   0.6384795904159546),
#  ('276590002|sindrome agudo laceracion tentorial| Hallazgo clínico',
#   0.6383663415908813),
#  ('51741000119105|dolor tobillo agudo| Hallazgo clínico', 0.6381325125694275),
#  ('208921000|desgarro meniscal agudo externo| Hallazgo clínico',
#   0.637996256351471),
#  ('401066000|antecedente familiar infarto miocardio familiar femenino primer grado menor 65 años| Situación con contexto explícito',
#   0.6378676295280457),
#  ('40541001|edema agudo pulmon| Hallazgo clínico', 0.6376567482948303),
#  ('186738001|vertigo epidemico agudo| Hallazgo clínico', 0.6375930309295654),
#  ('401067009|antecedente familiar : infarto miocardio familiar masculino primer grado 55 años| Situación con contexto explícito',
#   0.6374010443687439),
#  ('36225005|fallo renal agudo consecuencia procedimiento| Hallazgo clínico',
#   0.6371291279792786),
#  ('22050009|estructura miocardio ventriculo derecho| Estructura corporal',
#   0.6367092132568359),
#  ('72542009|miocardio cara inferior ventriculo izquierdo| Estructura corporal',
#   0.6366756558418274),
#  ('190926008|miocardio cara inferior ventriculo izquierdo| Estructura corporal',
#   0.6366756558418274),
#  ('190926008|miocardio cara inferior ventriculo izquierdo| Estructura corporal',
#   0.6366756558418274),
#  ('9209005|abdomen agudo| Hallazgo clínico', 0.6361982822418213),
#  ('111274000|absceso sinusal agudo| Hallazgo clínico', 0.63564133644104),
#  ('444227004|sindrome dolor agudo postoracotomia| Hallazgo clínico',
#   0.6355587244033813),
#  ('274663001|dolor agudo| Hallazgo clínico', 0.6353078484535217),
#  ('16698000|absceso agudo mama| Hallazgo clínico', 0.6351591348648071),
#  ('17475005|miocardio auricula cardiaca| Estructura corporal',
#   0.6349483728408813),
#  ('8608001|margen agudo corazon| Estructura corporal', 0.6341790556907654),
#  ('125294002|enfisema agudo| Estructura corporal', 0.6341654062271118),
#  ('237656000|tumor esplenico agudo| Hallazgo clínico', 0.6341028809547424),
#  ('401066000|antecedente familiar : infarto miocardio familiar femenino primer grado 65 años| Situación con contexto explícito',
#   0.6339002847671509),
#  ('43618000|infarto focal| Estructura corporal', 0.6337634325027466),
#  ('362018002|miocardio auricula derecha| Estructura corporal',
#   0.6328415870666504),
#  ('362018002|miocardio auricula derecha| Estructura corporal',
#   0.6328415870666504),
#  ('27295003|miocardio auricula derecha| Estructura corporal',
#   0.6328415870666504),
#  ('230602005|infarto embolia tronco nervioso| Hallazgo clínico',
#   0.6325242519378662),
#  ('175176000|trastorno genitourinario agudo| Hallazgo clínico',
#   0.6323851346969604),
#  ('40541001|edema pulmonar agudo| Hallazgo clínico', 0.6316705942153931),
#  ('315622004|antecedente familiar infarto miocardio familiar primer grado sexo femenino edad desconocida| Situación con contexto explícito',
#   0.6316043734550476),
#  ('15713008|miocardio auricula izquierda| Estructura corporal',
#   0.6315306425094604),
#  ('189936008|miocardio auricula izquierda| Estructura corporal',
#   0.6315306425094604),
#  ('189936008|miocardio auricula izquierda| Estructura corporal',
#   0.6315306425094604),
#  ('401067009|antecedente familiar : infarto miocardio familiar masculino primer grado menor 55 años| Situación con contexto explícito',
#   0.6313310265541077),
#  ('107401000119105|dolor posoperatorio agudo| Hallazgo clínico',
#   0.6311361789703369),
#  ('7872004|estructura miocardio ventriculo corazon| Estructura corporal',
#   0.6307763457298279),
#  ('438405000|llanto agudo| Hallazgo clínico', 0.6305429339408875),
#  ('394659003|sindrome coronario agudo| Hallazgo clínico', 0.6304579973220825),
#  ('67195008|trastorno stress agudo| Hallazgo clínico', 0.6300453543663025),
#  ('128487001|trastorno cardiovascular agudo| Hallazgo clínico',
#   0.6300421953201294),
#  ('127334004|trastorno agudo piel| Hallazgo clínico', 0.6294859647750854),
#  ('10846005|estructura miocardio region posterior tabique| Estructura corporal',
#   0.629286527633667),
#  ('315620007|antecedente familiar infarto miocardio familiar primer grado sexo masculino edad desconocida| Situación con contexto explícito',
#   0.6292031407356262),
#  ('403178009|eczema craquele edema agudo| Hallazgo clínico',
#   0.628911018371582),
#  ('363437005|tumor maligno miocardio| Hallazgo clínico', 0.6285847425460815),
#  ('268617001|episodio esquizofrenico agudo| Hallazgo clínico',
#   0.6284579634666443),
#  ('57965003|sindrome glomerulonefritico agudo benigno hemorragico| Hallazgo clínico',
#   0.6281793713569641),
#  ('192041001|malestar circunstancial agudo| Hallazgo clínico',
#   0.62816321849823),
#  ('27719009|sangrado gi agudo| Hallazgo clínico', 0.6279767751693726),
#  ('23971007|vomito agudo| Hallazgo clínico', 0.6278224587440491),
#  ('722829006|dolor escrotal agudo| Hallazgo clínico', 0.6271476745605469),
#  ('85521005|sangrado gi inferior agudo| Hallazgo clínico', 0.6270977258682251),
#  ('238806009|edema hemorragico agudo infantil| Hallazgo clínico',
#   0.6268333196640015),
#  ('762348004|insomnio agudo| Hallazgo clínico', 0.6264543533325195),
#  ('315621006|antecedente familiar infarto miocardio familiar primer grado sexo femenino edad conocida| Situación con contexto explícito',
#   0.6263576745986938),
#  ('128480004|trastorno agudo sistema hemopoyetico| Concepto especial',
#   0.6263189315795898),
#  ('204394002|anomalia congenita miocardio| Hallazgo clínico',
#   0.6256012916564941),
#  ('67195008|trastorno estres agudo| Hallazgo clínico', 0.6251164674758911),
#  ('16119006|absceso agudo mandibula| Hallazgo clínico', 0.6250886917114258),
#  ('16698000|absceso mamario agudo| Hallazgo clínico', 0.6250511407852173),
#  ('125249008|desplazamiento agudo| Estructura corporal', 0.6248965263366699),
#  ('432439005|efecto inotropico negativo miocardio| Hallazgo clínico',
#   0.6243125796318054),
#  ('58898007|trasudado inflamatorio agudo| Estructura corporal',
#   0.6242899298667908),
#  ('373933003|inicio agudo| Calificador', 0.624283492565155),
#  ('116290004|dolor abdominal agudo| Hallazgo clínico', 0.624243438243866),
#  ('315619001|antecedente familiar infarto miocardio familiar primer grado sexo masculino edad conocida| Situación con contexto explícito',
#   0.6240209341049194),
#  ('230694003|infarto accidente cerebrovascular circulacion cerebral anterior| Hallazgo clínico',
#   0.623820960521698),
#  ('109602002|absceso alveolar agudo| Hallazgo clínico', 0.6231184005737305),
#  ('11011007|eczema infantil agudo| Hallazgo clínico', 0.6229932308197021),
#  ('38938002|sangrado gi superior agudo| Hallazgo clínico', 0.6229913234710693),
#  ('95830009|infarto glandula pituitaria| Hallazgo clínico',
#   0.6227876543998718),
#  ('17475005|estructura miocardio auricula cardiaca| Estructura corporal',
#   0.6224719285964966),
#  ('432249006|infarto medula espinal| Hallazgo clínico', 0.622406005859375),
#  ('429391004|infarto miocardico nuevo comparacion estudio previo| Hallazgo clínico',
#   0.6217552423477173),
#  ('240386002|muermo supurante localizado agudo| Hallazgo clínico',
#   0.6215367317199707),
#  ('230518009|infarto cintilla optica| Hallazgo clínico', 0.6214261054992676),
#  ('20706007|estructura miocardio region anterior tabique| Estructura corporal',
#   0.6214221119880676),
#  ('188708001|miocardio apex corazon| Estructura corporal', 0.6210592985153198),
#  ('428196007|infarto e isquemia miocardica combinados| Hallazgo clínico',
#   0.620735764503479),
#  ('62695002|iam anteroseptal| Hallazgo clínico', 0.6205493807792664),
#  ('191505005|confusional agudo origen cerebrovascular| Hallazgo clínico',
#   0.6205065846443176),
#  ('91862002|absceso periodontal agudo| Hallazgo clínico', 0.6202428340911865),
#  ('128481000|trastorno musculoesqueletico agudo| Hallazgo clínico',
#   0.6201564073562622),
#  ('293831000119105|infarto cerebral debido a estenosis arteria precerebral| Hallazgo clínico',
#   0.6201461553573608),
#  ('208923002|desgarro meniscal agudo externo asta posterior| Hallazgo clínico',
#   0.6194045543670654),
#  ('408863003|riesgo evento cardiaco isquemico agudo| Hallazgo clínico',
#   0.6187851428985596),
#  ('47559000|infarto zona vascular limitrofe| Estructura corporal',
#   0.6182816028594971),
#  ('398244008|drenaje absceso apical agudo| Procedimiento', 0.6180846691131592),
#  ('246079009|mecanismo infarto| ', 0.618008017539978),
#  ('208916003|desgarro meniscal agudo interno asta posterior| Hallazgo clínico',
#   0.6178861856460571),
#  ('236573002|cambios limitrofes rechazo agudo| Hallazgo clínico',
#   0.6177518367767334),
#  ('125081000119106|infarto cerebral debido a oclusion arteria precerebral| Hallazgo clínico',
#   0.617501974105835),
#  ('421946003|consulta dolor agudo| Procedimiento', 0.6172578930854797),
#  ('396348002|eccema agudo| Hallazgo clínico', 0.6169444918632507),
#  ('722829006|dolor agudo escroto| Hallazgo clínico', 0.6169252991676331),
#  ('85821003|sindrome cerebral agudo no psicotico| Hallazgo clínico',
#   0.6166319847106934),
#  ('76940009|volvulo gastrico agudo| Hallazgo clínico', 0.6164125204086304),
#  ('125115006|eritema agudo| Hallazgo clínico', 0.6164029240608215),
# ...
#  ('55230008|anastomosis quirurgica arteria mamaria interna miocardio| Procedimiento',
#   0.563277542591095),
#  ('415473003|coronavirus tw kc2 sindrome respiratorio agudo severo| Organismo',
#   0.5631782412528992),
#  ('415388009|coronavirus gz60 sindrome respiratorio agudo severo| Organismo',
#   0.5631160736083984),
#  ('415475005|coronavirus tw ym4 sindrome respiratorio agudo severo| Organismo',
#   0.5631126761436462),
#  ('67782005|sindrome distress respiratorio agudo adulto| Hallazgo clínico',
#   0.5628668665885925),
#  ('415468009|coronavirus tw hp2 sindrome respiratorio agudo severo| Organismo',
#   0.562839150428772),
#  ('415467004|coronavirus tw hp1 sindrome respiratorio agudo severo| Organismo',
#   0.5626252889633179),
#  ('415470000|coronavirus tw hp4 sindrome respiratorio agudo severo| Organismo',
#   0.5623809695243835),
#  ('415410008|coronavirus hzs2 fb sindrome respiratorio agudo severo| Organismo',
#   0.5623470544815063),
#  ('415462005|coronavirus tw sindrome respiratorio agudo severo| Organismo',
#   0.562191903591156),
#  ('415464006|coronavirus tw gd2 sindrome respiratorio agudo severo| Organismo',
#   0.562152624130249),
#  ('716379000|higado graso agudo embarazo| Hallazgo clínico',
#   0.5619640946388245),
#  ('195963002|enfisema vesicular agudo| Hallazgo clínico', 0.5615407228469849),
#  ('415465007|coronavirus tw gd3 sindrome respiratorio agudo severo| Organismo',
#   0.5615068674087524),
#  ('415360003|coronavirus sindrome respiratorio agudo severo| Organismo',
#   0.5611938238143921),
#  ('415391009|coronavirus hgz8l1 b sindrome respiratorio agudo severo| Organismo',
#   0.5611644983291626),
#  ('415382005|coronavirus gz b sindrome respiratorio agudo severo| Organismo',
#   0.5608847141265869),
#  ('110553006|arteria coronaria y miocardio sitio combinado| Estructura corporal',
#   0.5607419013977051),
#  ('709905009|anticuerpo anti coronavirus urbani sindrome respiratorio agudo severo| Sustancia',
#   0.5607388019561768),
#  ('415474009|coronavirus tw ph1 sindrome respiratorio agudo severo| Organismo',
#   0.5604541301727295),
#  ('56900004|infarto trompa falopio| Hallazgo clínico', 0.5604237914085388),
#  ('56900004|infarto trompa falopio| Hallazgo clínico', 0.5604237914085388),
#  ('415498002|coronavirus zs b sindrome respiratorio agudo severo| Organismo',
#   0.560403048992157),
#  ('128487001|trastorno agudo aparato cardiovascular| Hallazgo clínico',
#   0.560379147529602),
#  ('415398003|coronavirus hpz 2003 sindrome respiratorio agudo grave| Organismo',
#   0.560103178024292),
#  ('415368005|coronavirus cuhk ag01 sindrome respiratorio agudo severo| Organismo',
#   0.5598970055580139),
#  ('197685009|sindrome nefritico agudo glomerulonefritis proliferativa endocapilar difusa| Hallazgo clínico',
#   0.5598868727684021),
#  ('415400004|coronavirus hsz a sindrome respiratorio agudo severo| Organismo',
#   0.5598241090774536),
#  ('77285007|infarto placentario afecta manejo situacion materna| Hallazgo clínico',
#   0.5596111416816711),
#  ('402165001|efecto agudo rayos ultravioletas piel normal| Hallazgo clínico',
#   0.5595991015434265),
#  ('415369002|coronavirus cuhk ag02 sindrome respiratorio agudo severo| Organismo',
#   0.559529185295105),
#  ('415370001|coronavirus cuhk ag03 sindrome respiratorio agudo severo| Organismo',
#   0.5593820810317993),
#  ('59063002|iam pared apicolateral| Hallazgo clínico', 0.5593538284301758),
#  ('62658002|resonancia magnetica torax y miocardio| Procedimiento',
#   0.5591950416564941),
#  ('415372009|coronavirus cuhk su10 sindrome respiratorio agudo severo| Organismo',
#   0.5588210821151733),
#  ('415395000|coronavirus hku 65806 sindrome respiratorio agudo severo| Organismo',
#   0.5583988428115845),
#  ('415373004|coronavirus cuhk w1 sindrome respiratorio agudo severo| Organismo',
#   0.5582166910171509),
#  ('63670007|imagenes miocardicas deteccion infarto tecnica plana| Procedimiento',
#   0.5581343173980713),
#  ('415396004|coronavirus hku 66078 sindrome respiratorio agudo severo| Organismo',
#   0.5580832958221436),
#  ('415397008|coronavirus hong kong/03/2003 sindrome respiratorio agudo severo| Organismo',
#   0.5580464005470276),
#  ('103301009|vertigo inicio agudo vomitos e incapacidad pie| Hallazgo clínico',
#   0.5578927993774414),
#  ('709904008|anticuerpo anti coronavirus sindrome respiratorio agudo severo| Sustancia',
#   0.5576319694519043),
#  ('415394001|coronavirus hku 39849 sindrome respiratorio agudo severo| Organismo',
#   0.5573019981384277),
#  ('415393007|coronavirus hku 36871 sindrome respiratorio agudo severo| Organismo',
#   0.557270884513855),
#  ('401300000|prueba deteccion selectiva sindrome respiratorio agudo severo| Procedimiento',
#   0.5570710301399231),
#  ('415389001|coronavirus hb sindrome respiratorio agudo severo| Organismo',
#   0.5566864013671875),
#  ('402327004|brote pustular generalizado agudo placa psoriasis preexistente| Hallazgo clínico',
#   0.5565930604934692),
#  ('279035001|dolor toracico dorsal agudo| Hallazgo clínico',
#   0.5560097694396973),
#  ('415403002|coronavirus hsz cb sindrome respiratorio agudo severo| Organismo',
#   0.5558311939239502),
#  ('208924008|desgarro agudo menisco externo asa balde| Hallazgo clínico',
#   0.555659294128418),
#  ('238560007|pongolix agudo pies| Hallazgo clínico', 0.5556493997573853),
#  ('64432007|estudios imagenes radioisotopicas miocardio| Procedimiento',
#   0.5555194020271301),
#  ('415376007|coronavirus fra sindrome respiratorio agudo severo| Organismo',
#   0.5554699897766113),
#  ('197684008|sindrome nefritico agudo glomerulonefritis proliferativa mesangial difusa| Hallazgo clínico',
#   0.5554175972938538),
#  ('707785005|arn coronavirus urbani sindrome respiratorio agudo severo| Sustancia',
#   0.5552572011947632),
#  ('415402007|coronavirus hsz bc sindrome respiratorio agudo severo| Organismo',
#   0.5545927286148071),
#  ('707540007|distres respiratorio agudo neonatal| Hallazgo clínico',
#   0.554356575012207),
#  ('278853003|trastorno psicotico agudo similar a esquizofrenia| Hallazgo clínico',
#   0.5534919500350952),
#  ('461420008|origen anomalo arteria coronaria angulo agudo menor 45 grados relacion aorta| Hallazgo clínico',
#   0.5530424118041992),
#  ('9953008|daño hepatico agudo alcohol| Hallazgo clínico', 0.5529067516326904),
#  ('415371002|coronavirus cuhk l2 sindrome respiratorio agudo severo| Organismo',
#   0.5527835488319397),
#  ('707784009|arn coronavirus sindrome respiratorio agudo severo| Sustancia',
#   0.5525952577590942),
#  ('230434009|convulsiones respuesta a evento agudo| Hallazgo clínico',
#   0.552564263343811),
#  ('398447004|sindrome respiratorio agudo grave| Hallazgo clínico',
#   0.5522689819335938),
#  ('415406005|coronavirus hzs2 bb sindrome respiratorio agudo grave| Organismo',
#   0.5519341826438904),
#  ('197682007|sindrome nefritico agudo lesiones glomerulares focales y segmentarias| Hallazgo clínico',
#   0.5514176487922668),
#  ('415418001|coronavirus ns 1 sindrome respiratorio agudo severo| Organismo',
#   0.5508695840835571),
#  ('10519008|edema agudo pulmon humos y/o vapores| Hallazgo clínico',
#   0.5508331060409546),
#  ('415411007|coronavirus hzs2 fc sindrome respiratorio agudo grave| Organismo',
#   0.5508193373680115),
#  ('415409003|coronavirus hzs2 e sindrome respiratorio agudo severo| Organismo',
#   0.550637423992157),
#  ('415458004|coronavirus taiwan tc1 sindrome respiratorio agudo grave| Organismo',
#   0.5505853891372681),
#  ('415459007|coronavirus taiwan tc2 sindrome respiratorio agudo grave| Organismo',
#   0.5505738258361816),
#  ('415496003|coronavirus vietnam sindrome respiratorio agudo grave| Organismo',
#   0.5503582954406738),
#  ('444482005|exposicion a sindrome respiratorio agudo severo coronavirus| Evento',
#   0.5502022504806519),
#  ('415399006|coronavirus hsr 1 sindrome respiratorio agudo severo| Organismo',
#   0.5501500964164734),
#  ('415460002|coronavirus taiwan tc3 sindrome respiratorio agudo grave| Organismo',
#   0.5500774383544922),
#  ('415457009|coronavirus taiwan sindrome respiratorio agudo grave| Organismo',
#   0.549898624420166),
#  ('415404008|coronavirus hsz cc sindrome respiratorio agudo severo| Organismo',
#   0.5497646331787109),
#  ('415495004|coronavirus urbani sindrome respiratorio agudo grave| Organismo',
#   0.5495865345001221),
#  ('402229003|eccema mano agudo constitucional| Hallazgo clínico',
#   0.549583375453949),
#  ('63077009|implante vasos sanguineos miocardio| Procedimiento',
#   0.5495760440826416),
#  ('197686005|sindrome nefritico agudo glomerulonefritis mesangiocapilar difusa| Hallazgo clínico',
#   0.5494586229324341),
#  ('415471001|coronavirus tw jc2 sindrome respiratorio agudo grave| Organismo',
#   0.5487790703773499),
#  ('415472008|coronavirus tw kc1 sindrome respiratorio agudo grave| Organismo',
#   0.548567533493042),
#  ('415466008|coronavirus tw gd5 sindrome respiratorio agudo grave| Organismo',
#   0.5483611822128296),
#  ('415422006|coronavirus sf098 sindrome respiratorio agudo grave| Organismo',
#   0.548276424407959),
#  ('415383000|coronavirus gz c sindrome respiratorio agudo severo| Organismo',
#   0.5482717752456665),
#  ('415436001|coronavirus sin3408 sindrome respiratorio agudo grave| Organismo',
#   0.5482556223869324),
#  ('415384006|coronavirus gz d sindrome respiratorio agudo severo| Organismo',
#   0.5482123494148254),
#  ('203375003|desplazamiento agudo no traumatico epifisis femoral superior proceso cronico previo| Hallazgo clínico',
#   0.5481637716293335),
#  ('415434003|coronavirus sin2774 sindrome respiratorio agudo grave| Organismo',
#   0.5481607913970947),
#  ('415475005|coronavirus tw ym4 sindrome respiratorio agudo grave| Organismo',
#   0.5479340553283691),
#  ('415473003|coronavirus tw kc2 sindrome respiratorio agudo grave| Organismo',
#   0.547914445400238),
#  ('415485006|coronavirus tw8 sindrome respiratorio agudo grave| Organismo',
#   0.5479090213775635),
#  ('415490009|coronavirus twh sindrome respiratorio agudo grave| Organismo',
#   0.5478802919387817),
#  ('415499005|coronavirus zs c sindrome respiratorio agudo severo| Organismo',
#   0.5478081703186035),
#  ('415423001|coronavirus sf099 sindrome respiratorio agudo grave| Organismo',
#   0.547785758972168),
#  ('415405009|coronavirus hsz2 a sindrome respiratorio agudo grave| Organismo',
#   0.5477474927902222),
#  ('415420003|coronavirus pumc02 sindrome respiratorio agudo grave| Organismo',
#   0.5477433800697327),
#  ('415468009|coronavirus tw hp2 sindrome respiratorio agudo grave| Organismo',
#   0.5477283596992493),
#  ('415484005|coronavirus tw7 sindrome respiratorio agudo grave| Organismo',
#   0.5477026700973511),
#  ('415390005|coronavirus hgz8l1 a sindrome respiratorio agudo grave| Organismo',
#   0.5476869940757751),
#  ('415414004|coronavirus lc2 sindrome respiratorio agudo grave| Organismo',
#   0.5476772785186768),
#  ('415488008|coronavirus twc2 sindrome respiratorio agudo grave| Organismo',
#   0.5476333498954773),
#  ('415452003|coronavirus sod sindrome respiratorio agudo grave| Organismo',
#   0.5476268529891968),
#  ('415378008|coronavirus gd01 sindrome respiratorio agudo grave| Organismo',
#   0.5475457310676575),
#  ('415401000|coronavirus hsz bb sindrome respiratorio agudo grave| Organismo',
#   0.5475419759750366),
#  ('415467004|coronavirus tw hp1 sindrome respiratorio agudo grave| Organismo',
#   0.5475348830223083),
#  ('415421004|coronavirus pumc03 sindrome respiratorio agudo grave| Organismo',
#   0.5475195646286011),
#  ('415454002|coronavirus sz13 sindrome respiratorio agudo grave| Organismo',
#   0.5474869012832642),
#  ('195231004|oclusion y estenosis arterias cerebrales no deriva infarto cerebral| Hallazgo clínico',
#   0.5474678874015808),
#  ('415380002|coronavirus gd69 sindrome respiratorio agudo grave| Organismo',
#   0.5474661588668823),
#  ('232082003|glaucoma iatrogenico angulo agudo| Hallazgo clínico',
#   0.547463595867157),
#  ('415407001|coronavirus hzs2 c sindrome respiratorio agudo severo| Organismo',
#   0.5474122762680054),
#  ('415381003|coronavirus gz a sindrome respiratorio agudo grave| Organismo',
#   0.5474047660827637),
#  ('415413005|coronavirus lc1 sindrome respiratorio agudo grave| Organismo',
#   0.5473995208740234),
#  ('415416002|coronavirus lc4 sindrome respiratorio agudo grave| Organismo',
#   0.5473940372467041),
#  ('415437005|coronavirus sin3725v sindrome respiratorio agudo grave| Organismo',
#   0.547353982925415),
#  ('415455001|coronavirus sz16 sindrome respiratorio agudo grave| Organismo',
#   0.5473491549491882),
#  ('415364007|coronavirus bj03 sindrome respiratorio agudo grave| Organismo',
#   0.5473384857177734),
#  ('415449006|coronavirus sinp3 sindrome respiratorio agudo grave| Organismo',
#   0.5473312735557556),
#  ('415470000|coronavirus tw hp4 sindrome respiratorio agudo grave| Organismo',
#   0.5473167896270752),
#  ('415448003|coronavirus sinp2 sindrome respiratorio agudo grave| Organismo',
#   0.5472915172576904),
#  ('415491008|coronavirus twj sindrome respiratorio agudo grave| Organismo',
#   0.5472664833068848),
#  ('415478007|coronavirus tw11 sindrome respiratorio agudo grave| Organismo',
#   0.5472548007965088),
#  ('415410008|coronavirus hzs2 fb sindrome respiratorio agudo grave| Organismo',
#   0.5472214221954346),
#  ('415494000|coronavirus twy sindrome respiratorio agudo grave| Organismo',
#   0.5472177267074585),
#  ('415445000|coronavirus sin852 sindrome respiratorio agudo grave| Organismo',
#   0.5471867322921753),
#  ('415392002|coronavirus hgz8l2 sindrome respiratorio agudo grave| Organismo',
#   0.547182023525238),
#  ('415415003|coronavirus lc3 sindrome respiratorio agudo grave| Organismo',
#   0.5471789836883545),
#  ('415430007|coronavirus sin2500 sindrome respiratorio agudo grave| Organismo',
#   0.5471755266189575),
#  ('415480001|coronavirus tw3 sindrome respiratorio agudo grave| Organismo',
#   0.5471638441085815),
#  ('415365008|coronavirus bj04 sindrome respiratorio agudo grave| Organismo',
#   0.5471392869949341),
#  ('415438000|coronavirus sin842 sindrome respiratorio agudo grave| Organismo',
#   0.5471155047416687),
#  ('415379000|coronavirus gd03t0013 sindrome respiratorio agudo grave| Organismo',
#   0.5471111536026001),
#  ('415440005|coronavirus sin846 sindrome respiratorio agudo grave| Organismo',
#   0.5470801591873169),
#  ('415427000|coronavirus sin3765v sindrome respiratorio agudo grave| Organismo',
#   0.5470544695854187),
#  ('415374005|coronavirus cw037 sindrome respiratorio agudo grave| Organismo',
#   0.5470536351203918),
#  ('415386008|coronavirus gz43 sindrome respiratorio agudo grave| Organismo',
#   0.5470479130744934),
#  ('415419009|coronavirus pumc01 sindrome respiratorio agudo grave| Organismo',
#   0.5470386743545532),
#  ('415456000|coronavirus sz3 sindrome respiratorio agudo grave| Organismo',
#   0.5470285415649414),
#  ('415493006|coronavirus tws sindrome respiratorio agudo grave| Organismo',
#   0.5469667911529541),
#  ('415482009|coronavirus tw5 sindrome respiratorio agudo grave| Organismo',
#   0.5469362735748291),
#  ('415487003|coronavirus twc sindrome respiratorio agudo grave| Organismo',
#   0.5469340085983276),
#  ('415483004|coronavirus tw6 sindrome respiratorio agudo grave| Organismo',
#   0.5469181537628174),
#  ('415412000|coronavirus jmd sindrome respiratorio agudo grave| Organismo',
#   0.5469092130661011),
#  ('399150003|prueba reaccion cadena polimerasa sindrome respiratorio agudo severo| Procedimiento',
#   0.5469078421592712),
#  ('415439008|coronavirus sin845 sindrome respiratorio agudo grave| Organismo',
#   0.5468955039978027),
#  ('415447008|coronavirus sinp1 sindrome respiratorio agudo grave| Organismo',
#   0.5468776226043701),
#  ('415489000|coronavirus twc3 sindrome respiratorio agudo grave| Organismo',
#   0.5468659996986389),
#  ('415387004|coronavirus gz50 sindrome respiratorio agudo grave| Organismo',
#   0.5468652844429016),
#  ('415408006|coronavirus hzs2 d sindrome respiratorio agudo severo| Organismo',
#   0.5468602776527405),
#  ('415362006|coronavirus bj01 sindrome respiratorio agudo grave| Organismo',
#   0.5468282103538513),
#  ('415367000|coronavirus bj302 sindrome respiratorio agudo grave| Organismo',
#   0.5468207597732544),
#  ('415481002|coronavirus tw4 sindrome respiratorio agudo grave| Organismo',
#   0.5467877984046936),
#  ('415442002|coronavirus sin848 sindrome respiratorio agudo grave| Organismo',
#   0.5467818975448608),
#  ('415444001|coronavirus sin850 sindrome respiratorio agudo grave| Organismo',
#   0.5467472076416016)]

# %% [markdown]
# ### Elegir el tipo de clase de objeto, comparando los mas similares: (diagnósticos, procedimientos...)

# %%
if 'Hallazgo' in lconcept[0][0]:
    print('ok')

# %%
word='procedimiento'
mas=[w for concept in lconcept if 'procedimiento' in lconcept]

# %%
mas
# Out:
# []

# %%
term=['ictus']
mas_similar(term, topn=1000)
# Out:
# [('230690007|ictus cerebral| Hallazgo clínico', 0.7806976437568665),
#  ('450741005|escala ictus nih| Estadificaciones y escalas',
#   0.7656364440917969),
#  ('18615009|ictus solar| Hallazgo clínico', 0.7298291325569153),
#  ('135875009|prevencion ictus| Procedimiento', 0.6853494644165039),
#  ('450743008|puntaje escala ictus nih| Entidad observable',
#   0.6719679832458496),
#  ('450742003|evaluacion uso escala ictus nih| Procedimiento',
#   0.6632712483406067),
#  ('707522008|escala impacto ictus version 3 0 puntaje comunicacion| Entidad observable',
#   0.6445953845977783),
#  ('275104002|historia familiar ictus| Situación con contexto explícito',
#   0.6436722278594971),
#  ('705003005|escala impacto ictus version 3 0| Estadificaciones y escalas',
#   0.6429042816162109),
#  ('707520000|escala impacto ictus version 3 0 puntaje emociones| Entidad observable',
#   0.6344026327133179),
#  ('707521001|escala impacto ictus version 3 0 puntaje memoria| Entidad observable',
#   0.6295913457870483),
#  ('707518003|escala impacto ictus version 3 0 puntaje movilidad| Entidad observable',
#   0.625770092010498),
#  ('707514001|puntaje escala impacto ictus version 3 0| Entidad observable',
#   0.6191654801368713),
#  ('707516004|escala impacto ictus version 3 0 puntaje fuerza| Entidad observable',
#   0.6137630343437195),
#  ('707523003|escala impacto ictus version 3 0 puntaje participacion social| Entidad observable',
#   0.6105870604515076),
#  ('426033005|disfagia efecto tardio ictus| Hallazgo clínico',
#   0.6103700995445251),
#  ('707515000|escala impacto ictus version 3 0 puntaje dominio fisico| Entidad observable',
#   0.6101102828979492),
#  ('707522008|escala impacto accidente cerebrovascular version 3 0 puntaje comunicacion| Entidad observable',
#   0.600107729434967),
#  ('707519006|escala impacto ictus version 3 0 puntaje actividades vida diaria| Entidad observable',
#   0.5960298180580139),
#  ('707517008|escala impacto ictus version 3 0 puntaje funcion manual| Entidad observable',
#   0.5917053818702698),
#  ('707520000|escala impacto accidente cerebrovascular version 3 0 puntaje emociones| Entidad observable',
#   0.5894337892532349),
#  ('707521001|escala impacto accidente cerebrovascular version 3 0 puntaje memoria| Entidad observable',
#   0.5888696908950806),
#  ('705027007|evaluacion escala impacto accidente cerebrovascular version 3 0| Procedimiento',
#   0.5874885320663452),
#  ('707518003|escala impacto accidente cerebrovascular version 3 0 puntaje movilidad| Entidad observable',
#   0.5826084613800049),
#  ('705003005|escala impacto accidente cerebrovascular version 3 0| Estadificaciones y escalas',
#   0.5820189714431763),
#  ('707523003|escala impacto accidente cerebrovascular version 3 0 puntaje participacion social| Entidad observable',
#   0.577483057975769),
#  ('450742003|evaluacion uso escala accidente cerebrovascular institutos nacionales salud unidos norteamerica| Procedimiento',
#   0.5745751857757568),
#  ('707514001|puntaje escala impacto accidente cerebrovascular version 3 0| Entidad observable',
#   0.5716536641120911),
#  ('450741005|escala accidente cerebrovascular national institutes of health| Estadificaciones y escalas',
#   0.5712290406227112),
#  ('707516004|escala impacto accidente cerebrovascular version 3 0 puntaje fuerza| Entidad observable',
#   0.5703684687614441),
#  ('707515000|escala impacto accidente cerebrovascular version 3 0 puntaje dominio fisico| Entidad observable',
#   0.5701486468315125),
#  ('450743008|puntaje escala accidente cerebrovascular institutos nacionales salud unidos norteamerica| Entidad observable',
#   0.5699445009231567),
#  ('450742003|evaluacion uso escala accidente cerebrovascular national institutes of health| Procedimiento',
#   0.5697656869888306),
#  ('450741005|escala accidente cerebrovascular institutos nacionales salud unidos norteamerica| Estadificaciones y escalas',
#   0.569365382194519),
#  ('450743008|puntaje escala accidente cerebrovascular national institutes of health| Entidad observable',
#   0.5686911940574646),
#  ('230717002|accidente isquemico transitorio territorio vertebrobasilar| Hallazgo clínico',
#   0.5677627325057983),
#  ('707519006|escala impacto accidente cerebrovascular version 3 0 puntaje actividades vida diaria| Entidad observable',
#   0.5675095915794373),
#  ('413758000|accidente cerebrovascular cardioembolico| Hallazgo clínico',
#   0.5660863518714905),
#  ('99051000119101|antecedente accidente cerebrovascular lacunar| Situación con contexto explícito',
#   0.5653421878814697),
#  ('141831000119101|antecedente accidente cerebrovascular embolico deficiencias| Situación con contexto explícito',
#   0.5652406215667725),
#  ('674361000119104|apraxia secuela accidente cerebrovascular isquemico| Hallazgo clínico',
#   0.5639523267745972),
#  ('33301000119105|secuela accidente cerebrovascular cardioembolico| Hallazgo clínico',
#   0.5628019571304321),
#  ('140701000119108|antecedente accidente cerebrovascular hemorragico hemiparesia| Situación con contexto explícito',
#   0.5576595067977905),
#  ('690201000119109|ataxia secuela accidente cerebrovascular embolico| Hallazgo clínico',
#   0.5569801330566406),
#  ('230698000|accidente cerebrovascular lacunar| Hallazgo clínico',
#   0.5552303791046143),
#  ('33331000119103|secuela accidente cerebrovascular lacunar| Hallazgo clínico',
#   0.554867684841156),
#  ('707517008|escala impacto accidente cerebrovascular version 3 0 puntaje funcion manual| Entidad observable',
#   0.5538755655288696),
#  ('48601000119107|hemiplejia y/o hemiparesia despues accidente cerebrovascular| Hallazgo clínico',
#   0.5525484085083008),
#  ('230702001|hemiparesia ataxica lacunar| Hallazgo clínico',
#   0.5511534810066223),
#  ('266257000|ait| Hallazgo clínico', 0.5465918779373169),
#  ('140711000119106|antecedente accidente cerebrovascular hemorragico hemiplejia| Situación con contexto explícito',
#   0.5414221286773682),
#  ('428668000|apraxia accidente cerebrovascular| Hallazgo clínico',
#   0.5400524139404297),
#  ('195217004|accidente cerebrovascular hemisferio cerebral derecho| Hallazgo clínico',
#   0.5383566617965698),
#  ('91601000119109|secuela accidente cerebrovascular trombotico| Hallazgo clínico',
#   0.5363544225692749),
#  ('195216008|accidente cerebrovascular hemisferio cerebral izquierdo| Hallazgo clínico',
#   0.5362749099731445),
#  ('230716006|accidente isquemico transitorio territorio carotideo| Hallazgo clínico',
#   0.5361863374710083),
#  ('442617003|afasia efecto tardio accidente cerebrovascular| Hallazgo clínico',
#   0.5356057286262512),
#  ('736709006|escala evaluacion postural pacientes accidente cerebrovascular| Estadificaciones y escalas',
#   0.5345211029052734),
#  ('160271002|sin antecedente familiar accidente cerebrovascular y/o ataque isquemico transitorio| Situación con contexto explícito',
#   0.5343729853630066),
#  ('371040005|accidente cerebrovascular trombotico| Hallazgo clínico',
#   0.5327511429786682),
#  ('736712009|puntaje escala evaluacion postural pacientes accidente cerebrovascular| Entidad observable',
#   0.5314812660217285),
#  ('441991000|hemiparesia efecto tardio accidente cerebrovascular| Hallazgo clínico',
#   0.5295227766036987),
#  ('445815002|evaluacion escala habilidades comunicacion e interaccion version 4 0| Procedimiento',
#   0.5291585922241211),
#  ('281113000|escala honos health of the nation outcome scale adicionada version generica| Estadificaciones y escalas',
#   0.5289376378059387),
#  ('281849001|item escala honos health of the nation outcome scale version generica| Estadificaciones y escalas',
#   0.5283172130584717),
#  ('273328008|escala boston afasia| Estadificaciones y escalas',
#   0.528194010257721),
#  ('445981002|evaluacion escala impacto ambiental laboral version 2 0| Procedimiento',
#   0.5271761417388916),
#  ('273463002|evaluacion disartria frenchay| Estadificaciones y escalas',
#   0.5259490609169006),
#  ('440430001|acis evaluacion habilidades comunicacion e interaccion version 4 0| Estadificaciones y escalas',
#   0.5252987146377563),
#  ('736708003|evaluacion escala evaluacion postural pacientes accidente cerebrovascular| Procedimiento',
#   0.5245991349220276),
#  ('141821000119104|antecedente accidente cerebrovascular isquemico deficit residual| Situación con contexto explícito',
#   0.5235707759857178),
#  ('290791000119105|trastorno fluidez lenguaje secuela accidente cerebrovascular| Hallazgo clínico',
#   0.5235400199890137),
#  ('674121000119107|ataxia secuela accidente cerebrovascular hemorragico| Hallazgo clínico',
#   0.5229933261871338),
#  ('446877008|puntaje evaluacion habilidades comunicacion e interaccion version 4 0| Entidad observable',
#   0.5219649076461792),
#  ('440430001|evaluacion habilidades comunicacion e interaccion version 4 0| Estadificaciones y escalas',
#   0.5211039781570435),
#  ('716745004|livedo racemosa y accidente cerebrovascular| Hallazgo clínico',
#   0.5210244655609131),
#  ('137991000119103|trastorno convulsivo secuela accidente cerebrovascular| Hallazgo clínico',
#   0.5203992128372192),
#  ('110997000|ferrocalcinosis cerebrovascular| Hallazgo clínico',
#   0.5195485353469849),
#  ('140911000119109|accidente cerebrovascular isquemico coma| Hallazgo clínico',
#   0.5195091962814331),
#  ('229654003|disfasia broca| Hallazgo clínico', 0.5193026065826416),
#  ('1670004|hemiparesia cerebral| Hallazgo clínico', 0.5186578035354614),
#  ('422504002|accidente cerebrovascular isquemico| Hallazgo clínico',
#   0.5172309875488281),
#  ('441630004|afasia efecto tardio enfermedad cerebrovascular| Hallazgo clínico',
#   0.5165677070617676),
#  ('723083001|efectos tardios accidente cerebrovascular isquemico| Hallazgo clínico',
#   0.5160925388336182),
#  ('281124003|escala honos health of the nation outcome scale item 10 : actividades cotidianas| Estadificaciones y escalas',
#   0.5150891542434692),
#  ('725819009|evaluacion escala impacto ambiente residencial version 4 0| Procedimiento',
#   0.514886736869812),
#  ('140281000119108|hemiparesia efecto tardio enfermedad cerebrovascular| Hallazgo clínico',
#   0.5148815512657166),
#  ('442733008|hemiplejia efecto tardio accidente cerebrovascular| Hallazgo clínico',
#   0.5148170590400696),
#  ('442212003|deficit cognitivo residual efecto tardio accidente cerebrovascular| Hallazgo clínico',
#   0.5145601034164429),
#  ('705032008|entrevista evaluacion circunstancias ocupacionales y escala calificacion version 4 0| Estadificaciones y escalas',
#   0.5144312381744385),
#  ('160363004|historia familiar ataque isquemico transitorio| Situación con contexto explícito',
#   0.5141657590866089),
#  ('20022000|hemiparesia| Hallazgo clínico', 0.5140399932861328),
#  ('127377003|hemiparesia| Situación con contexto explícito',
#   0.5140399932861328),
#  ('439312002|entrevista evaluacion circunstancias ocupacionales y escala forense calificacion salud mental version 4 0| Estadificaciones y escalas',
#   0.5136238932609558),
#  ('230691006|acv accidente cerebrovascular oclusion arteria cerebral| Hallazgo clínico',
#   0.512921154499054),
#  ('108691000119102|espasticidad secuela accidente cerebrovascular| Hallazgo clínico',
#   0.512730598449707),
#  ('718873000|puntaje escala entornos laborales entrevista antecedentes desempeño laboral ii version 2 1| Entidad observable',
#   0.5126820802688599),
#  ('446812005|puntaje entrevista evaluacion circunstancias ocupacionales y escala forense calificacion salud mental version 4 0| Entidad observable',
#   0.5123300552368164),
#  ('429993008|antecedente accidente cerebrovascular sin deficits secuelares| Situación con contexto explícito',
#   0.5107380747795105),
#  ('118971000119107|antecedente accidente cerebrovascular embolico sin deficiencia| Situación con contexto explícito',
#   0.5103026628494263),
#  ('232288005|vertigo isquemico vertebrobasilar| Hallazgo clínico',
#   0.5101014375686646),
#  ('13281000122101|accidente cerebrovascular transitorio| Hallazgo clínico',
#   0.5099989771842957),
#  ('718870002|escala entornos laborales entrevista antecedentes desempeño laboral ii version 2 1| Estadificaciones y escalas',
#   0.5099597573280334),
#  ('31590009|ferrocalcinosis| Estructura corporal', 0.5094015002250671),
#  ('716841003|puntaje evaluacion frenchay disartria| Entidad observable',
#   0.5087880492210388),
#  ('275526006|historia accidente cerebrovascular| Situación con contexto explícito',
#   0.5085210800170898),
#  ('29951000119107|hemiparesia ataxica| Hallazgo clínico', 0.5082395672798157),
#  ('714350005|evaluacion uso escala clinical outcomes in routine evaluation outcome measure| Procedimiento',
#   0.5081971883773804),
#  ('281116008|escala honos health of the nation outcome scale item 2 : lesion autoinfligida no accidental| Estadificaciones y escalas',
#   0.5079944729804993),
#  ('429235008|antecedente infarto cerebral cardioembolico| Situación con contexto explícito',
#   0.5078836679458618),
#  ('23671000119107|secuela infarto cerebral isquemico| Hallazgo clínico',
#   0.5078006982803345),
#  ('445980001|evaluacion entrevista rol trabajador version 10 0| Procedimiento',
#   0.5061737895011902),
#  ('718693006|puntaje prueba conductual memoria rivermead version adultos| Entidad observable',
#   0.506104588508606),
#  ('725818001|escala impacto ambiente residencial version 4 0| Estadificaciones y escalas',
#   0.5056072473526001),
#  ('720849008|educacion accidente cerebrovascular| Procedimiento',
#   0.5052425861358643),
#  ('281119001|escala honos health of the nation outcome scale item 5 : enfermedad fisica/discapacidad| Estadificaciones y escalas',
#   0.5052227973937988),
#  ('447568004|conjunto referencias ordenadas jerarquia navegacion clinical terms version 3| ',
#   0.5047445893287659),
#  ('441960006|deficit habla y lenguaje efecto tardio accidente cerebrovascular| Hallazgo clínico',
#   0.5045748353004456),
#  ('446008000|evaluacion utilizacion entrevista y calificacion circunstancias ocupacionales y escala forense calificacion salud mental version 4 0| Procedimiento',
#   0.5045198202133179),
#  ('281125002|escala honos health of the nation outcome scale item 11 : condiciones vida| Estadificaciones y escalas',
#   0.504440188407898),
#  ('716745004|sindrome livedo reticularis y accidente cerebrovascular| Hallazgo clínico',
#   0.5032994747161865),
#  ('230713003|accidente cerebrovascular acv patologia incierta| Hallazgo clínico',
#   0.503177285194397),
#  ('721955008|puntaje promedio indice score funcion familiar y cambio 15 dimensiones 3 ruptura comunicacion| Entidad observable',
#   0.50290447473526),
#  ('426033005|disfagia efecto tardio accidente cerebrovascular| Hallazgo clínico',
#   0.5028319954872131),
#  ('426033005|disfagia efecto tardio accidente cerebrovascular| Hallazgo clínico',
#   0.5028319954872131),
#  ('275104002|antecedente familiar accidente cerebrovascular| Situación con contexto explícito',
#   0.502753734588623),
#  ('273764007|evaluacion disartria robertson| Estadificaciones y escalas',
#   0.5024421811103821),
#  ('160271002|sin antecedente familiar accidente cerebrovascular/ataque isquemico transitorio| Situación con contexto explícito',
#   0.5021798014640808),
#  ('724426006|accidente cerebrovascular isquemico debido a aterosclerosis gran arteria extracraneal| Hallazgo clínico',
#   0.5019170045852661),
#  ('230716006|ataque isquemico transitorio territorio arteria carotida| Hallazgo clínico',
#   0.5017358064651489),
#  ('141281000119101|antecedente accidente cerebrovascular isquemico sin deficiencia residual| Situación con contexto explícito',
#   0.5017305016517639),
#  ('281117004|escala honos health of the nation outcome scale item 3 : problema alcohol/drogas| Estadificaciones y escalas',
#   0.5017248392105103),
#  ('281117004|escala honos health of the nation outcome scale item 3 : problema alcochol/drogas| Estadificaciones y escalas',
#   0.5017248392105103),
#  ('140921000119102|accidente cerebrovascular isquemico sin coma| Hallazgo clínico',
#   0.5017072558403015),
#  ('447280006|puntaje escala impacto ambiente laboral version 2 0| Entidad observable',
#   0.5016677975654602),
#  ('417540008|invitacion control accidente cerebrovascular/ataque isquemico transitorio| Hallazgo clínico',
#   0.5015549659729004),
#  ('446662002|puntaje entrevista rol trabajador version 10 0| Entidad observable',
#   0.5011456608772278),
#  ('725132001|accidente cerebrovascular isquemico sin deficit residual| Hallazgo clínico',
#   0.5009832978248596),
#  ('281844006|escala honos health of the nation outcome scale subescala a| Estadificaciones y escalas',
#   0.5008410215377808),
#  ('118951000119103|antecedente accidente cerebrovascular trombotico sin deficiencia residual| Situación con contexto explícito',
#   0.5005589723587036),
#  ('442024001|hemiplejia efecto tardio enfermedad cerebrovascular| Hallazgo clínico',
#   0.4999489188194275),
#  ('138875005|snomed ct sido creada mediante combinacion snomed rt y clinical terms version 3 conocidos read codes cuales creados nombre departamento salud gran bretaña y propiedad intelectual corona britanica| ',
#   0.4998752474784851),
#  ('281115007|escala honos health of the nation outcome scale item 1 : conducta agresiva/destructiva| Estadificaciones y escalas',
#   0.4998595714569092),
#  ('138875005|snomed ct sido creada mediante combinacion snomed rt y nomenclatura computarizada conocida clinical terms version 3 creada nombre departamento salud gran bretaña propiedad intelectual corona britanica| ',
#   0.49982452392578125),
#  ('281118009|escala honos health of the nation outcome scale item 4 : problemas cognitivos| Estadificaciones y escalas',
#   0.49963489174842834),
#  ('718883001|puntaje escala competencia laboral entrevista antecedentes desempeño laboral ii version 2 1| Entidad observable',
#   0.49955058097839355),
#  ('26021000119107|vertigo secuela enfermedad cerebrovascular| Hallazgo clínico',
#   0.49902817606925964),
#  ('229654003|afasia broca| Hallazgo clínico', 0.49890050292015076),
#  ('224029002|distrito territorio noroeste| Ambiente o localización geográfica',
#   0.498623251914978),
#  ('900000000000497000|conjunto referencias cruzadas simples a identificadores clinical terms version 3| ',
#   0.49796879291534424),
#  ('229665008|disfasia expresiva| Hallazgo clínico', 0.4976543188095093),
#  ('417540008|invitacion monitoreo accidente cerebrovascular/ataque isquemico transitorio| Hallazgo clínico',
#   0.4973942041397095),
#  ('415630002|monitoreo accidente cerebrovascular/ataque isquemico transitorio| Hallazgo clínico',
#   0.49732697010040283),
#  ('426788002|vertigo efecto tardio accidente cerebrovascular| Hallazgo clínico',
#   0.4970947504043579),
#  ('426788002|vertigo efecto tardio accidente cerebrovascular| Hallazgo clínico',
#   0.4970947504043579),
#  ('284464005|escalas health of the nation outcome hno escalas nacionales evolucion salud reino unido| Estadificaciones y escalas',
#   0.4970729947090149),
#  ('106169008|afasia agnosia dislexia y/o apraxia| Hallazgo clínico',
#   0.4969770908355713),
#  ('133981000119106|disartria efecto tardio enfermedad cerebrovascular| Hallazgo clínico',
#   0.49690482020378113),
#  ('281126001|escala honos health of the nation outcome scale item 12 : ocupacion/actividades| Estadificaciones y escalas',
#   0.4965445101261139),
#  ('718872005|puntaje escala identidad laboral entrevista antecedentes desempeño laboral ii version 2 1| Entidad observable',
#   0.49585404992103577),
#  ('281121006|escala honos health of the nation outcome scale item 7 : animo depresivo| Estadificaciones y escalas',
#   0.4957922101020813),
#  ('391124000|escala disnea medical research council : grado 3| Hallazgo clínico',
#   0.4957394599914551),
#  ('273555000|escala comunicacion lambeth| Estadificaciones y escalas',
#   0.4956660866737366),
#  ('718871003|escala competencia laboral entrevista antecedentes desempeño laboral ii version 2 1| Estadificaciones y escalas',
#   0.4954870343208313),
#  ('273276006|escalas desempeño lenguaje afasia| Estadificaciones y escalas',
#   0.49531108140945435),
#  ('723641005|evaluacion escalas historica clinica y manejo riesgo violencia 20 items version 3| Procedimiento',
#   0.49516046047210693),
#  ('1131000119105|secuela accidente cerebrovascular| Hallazgo clínico',
#   0.4951103627681732),
#  ('229664007|disfasia wernicke| Hallazgo clínico', 0.4950218200683594),
#  ('281120007|escala honos health of the nation outcome scale item 6 : alucinaciones/delirios| Estadificaciones y escalas',
#   0.49496227502822876),
#  ('29941000119105|ataxia secuela enfermedad cerebrovascular| Hallazgo clínico',
#   0.494644433259964),
#  ('720594007|puntaje total indice score funcion familiar y cambio 15 dimensiones 3 ruptura comunicacion| Entidad observable',
#   0.4945729970932007),
#  ('441529001|disfasia efecto tardio enfermedad cerebrovascular| Hallazgo clínico',
#   0.49429917335510254),
#  ('130990006|afasia transcortical| Hallazgo clínico', 0.49429214000701904),
#  ('440140008|antecedente accidente cerebrovascular deficit residual| Situación con contexto explícito',
#   0.49385708570480347),
#  ('450755002|puntaje escala disnea medical research council| Entidad observable',
#   0.4938328266143799),
#  ('141811000119106|antecedente accidente cerebrovascular hemorragico deficit residual| Situación con contexto explícito',
#   0.4937359094619751),
#  ('723642003|escalas historica clinica y manejo riesgo violencia 20 items version 3| Estadificaciones y escalas',
#   0.4936513304710388),
#  ('272143008|completitud| Calificador', 0.493439257144928),
#  ('717325003|evaluacion prueba frenchay disartria| Procedimiento',
#   0.49337929487228394),
#  ('720563007|indice score funcion familiar y cambio 15 dimensiones 3 ruptura comunicacion| Estadificaciones y escalas',
#   0.4931218922138214),
#  ('145741000119101|apraxia efecto tardio enfermedad cerebrovascular| Hallazgo clínico',
#   0.4929073750972748),
#  ('195217004|acv hemisferio cerebral derecho| Hallazgo clínico',
#   0.4927963614463806),
#  ('77728007|rehabilitacion despues episodio hemiplejia accidente cerebrovascular| Procedimiento',
#   0.49245843291282654),
#  ('428668000|apraxia accidente cerebrovasclar| Hallazgo clínico',
#   0.49244850873947144),
#  ('413124000|derivacion accidente cerebrovascular/ataque isquemico transitorio| Hallazgo clínico',
#   0.4921586513519287),
#  ('160363004|antecedente familiar ataque isquemico transitorio| Situación con contexto explícito',
#   0.4921572804450989),
#  ('138875005|snomed ct creo mediante combinacion snomed rt y nomenclatura y clasificacion computarizada conocida read codes version 3 creada nombre departamento salud gran bretaña| ',
#   0.4921421408653259),
#  ('230699008|infarto lacunar motor puro| Hallazgo clínico',
#   0.4921097457408905),
#  ('281845007|escala honos health of the nation outcome scale subescala b| Estadificaciones y escalas',
#   0.4918375313282013),
#  ('281240008|extension accidente cerebrovascular| Hallazgo clínico',
#   0.4911799430847168),
#  ('718867001|escala identidad laboral entrevista antecedentes desempeño laboral ii version 2 1| Estadificaciones y escalas',
#   0.49111151695251465),
#  ('195216008|acv hemisferio cerebral izquierdo| Hallazgo clínico',
#   0.49101394414901733),
#  ('439829006|escala impacto ambiente laboral version 2| Estadificaciones y escalas',
#   0.4909975528717041),
#  ('275526006|antecedente accidente cerebrovascular| Situación con contexto explícito',
#   0.4909913241863251),
#  ('407628009|hallazgo escala deterioro global evaluacion demencia degenerativa primaria| Hallazgo clínico',
#   0.490742027759552),
#  ('266257000|accidente isquemico transitorio| Hallazgo clínico',
#   0.4907204508781433),
#  ('391126003|escala disnea medical research council : grado 5| Hallazgo clínico',
#   0.4904858469963074),
#  ('230694003|infarto accidente cerebrovascular circulacion cerebral anterior| Hallazgo clínico',
#   0.49043941497802734),
#  ('672561000119103|deficit cognitivo debido a accidente cerebrovascular isquemico y posterior a| Hallazgo clínico',
#   0.49018633365631104),
#  ('363140000|hipolipoproteinemia| Hallazgo clínico', 0.4901520311832428),
#  ('690341000119100|deficit cognitivo debido a accidente cerebrovascular embolico y posterior a| Hallazgo clínico',
#   0.4896484315395355),
#  ('428147002|dioxolano| Sustancia', 0.4894079566001892),
#  ('417059002|convocatoria verbal control accidente cerebrovascular/ataque isquemico transitorio| Hallazgo clínico',
#   0.48937636613845825),
#  ('57981008|accidente cerebrovascular curso| Hallazgo clínico',
#   0.48921358585357666),
#  ('148871000119109|debilidad efecto tardio accidente cerebrovascular| Hallazgo clínico',
#   0.4891664683818817),
#  ('445035000|puntaje escala breve prevencion caidas version internacional| Entidad observable',
#   0.4891597032546997),
#  ('23011003|afasia expresiva receptiva| Hallazgo clínico', 0.4890725612640381),
#  ('281122004|escala honos health of the nation outcome scale item 8 : problemas mentales/de conducta| Estadificaciones y escalas',
#   0.48891979455947876),
#  ('138875005|snomed ct creo mediante combinacion snomed rt y nomenclatura y clasificacion computarizada conocida read codes version 3 creada nombre departamento salud gran bretaña propiedad intelectual corona britanica| ',
#   0.48883265256881714),
#  ('142271000119106|deficit cognitivo habilidades comunicacion| Hallazgo clínico',
#   0.48871126770973206),
#  ('433183000|vejiga neurogenica efecto tardio accidente cerebrovascular| Hallazgo clínico',
#   0.4884001910686493),
#  ('45502001|amiloidosis cerebrovascular| Hallazgo clínico',
#   0.4880061447620392),
#  ('229665008|afasia expresiva| Hallazgo clínico', 0.48768720030784607),
#  ('674361000119104|apraxia debida a accidente cerebrovascular isquemico y posterior a| Hallazgo clínico',
#   0.48758041858673096),
#  ('135875009|prevencion accidente cerebrovascular| Procedimiento',
#   0.4874829649925232),
#  ('281846008|escala honos health of the nation outcome scale subescala c| Estadificaciones y escalas',
#   0.4874109923839569),
#  ('440117009|entrevista rol trabajador version 10 0| Estadificaciones y escalas',
#   0.48727476596832275),
#  ('440117009|entrevista rol trabajador wri version 10 0| Estadificaciones y escalas',
#   0.48727476596832275),
#  ('190785000|hipoalfalipoproteinemia| Hallazgo clínico', 0.4870997369289398),
#  ('443573009|evaluacion escala eficacia prevencion caidas tinetti| Procedimiento',
#   0.4869334399700165),
#  ('68051003|dicloropropeno| Sustancia', 0.48677924275398254),
#  ('672521000119108|disfasia debida a accidente cerebrovascular isquemico y posterior a| Hallazgo clínico',
#   0.486233115196228),
#  ('706952004|puntaje modulo impacto laboral cuestionario dash| Entidad observable',
#   0.48622721433639526),
#  ('68107009|paresia cerebral ataxia homolateral| Hallazgo clínico',
#   0.48565474152565),
#  ('407631005|escala gds nivel 3 deterioro cognitivo leve| Hallazgo clínico',
#   0.4854975938796997),
#  ('724425005|accidente cerebrovascular isquemico debido a aterosclerosis gran arteria intracraneal| Hallazgo clínico',
#   0.4852411150932312),
#  ('92341000119107|debilidad extremidades secuela accidente cerebrovascular| Hallazgo clínico',
#   0.4851928949356079),
#  ('716167006|evaluacion escala boehm 3 preescolar| Procedimiento',
#   0.48510676622390747),
#  ('281848009|escala honos health of the nation outcome scale subescala d| Estadificaciones y escalas',
#   0.48507556319236755),
#  ('391120009|escala disnea medical research council : grado 1| Hallazgo clínico',
#   0.484824001789093),
#  ('58392004|pseudoparalisis parrot| Hallazgo clínico', 0.4847669303417206),
#  ('281123009|escala honos health of the nation outcome scale item 9 : problemas relacion| Estadificaciones y escalas',
#   0.4844982624053955),
#  ('273643004|evaluacion cognitivo neuroconductual| Estadificaciones y escalas',
#   0.48435285687446594),
#  ('690351000119103|disfasia debida a accidente cerebrovascular embolico y posterior a| Hallazgo clínico',
#   0.48427924513816833),
#  ('444776006|escala breve prevencion caidas version internacional| Estadificaciones y escalas',
#   0.48400023579597473),
#  ('57981008|sindrome accidente cerebrovascular evolucion| Hallazgo clínico',
#   0.4836087226867676),
#  ('133991000119109|trastorno fluidez secuela enfermedad cerebrovascular| Hallazgo clínico',
#   0.483532190322876),
#  ('445036004|evaluacion version abreviada escala internacional riesgo caidas| Procedimiento',
#   0.48311591148376465),
#  ('34209003|hemiplejia cerebral| Hallazgo clínico', 0.48295921087265015),
#  ('725844001|evaluacion cuestionario actividades vida diaria penn parkinson 15| Procedimiento',
#   0.48281705379486084),
#  ('441526008|infarto cerebro debido a accidente cerebrovascular iatrogenico| Hallazgo clínico',
#   0.48281654715538025),
#  ('160252004|sin antecedentes familiares significativos accidente cerebrovascular o sincope| Situación con contexto explícito',
#   0.482411652803421),
#  ('438367009|puntaje riesgo insuficiencia cardiaca congestiva hipertension 75 años edad o mayor diabetes y accidente cerebrovascular o ataque isquemico transitorio| Estadificaciones y escalas',
#   0.4824073612689972),
#  ('273437007|escala eastern cooperative oncology group ecog evaluacion fisica| Estadificaciones y escalas',
#   0.4822155237197876),
#  ('217646008|accidente privacion no calificada| Evento', 0.48206716775894165),
#  ('724993002|accidente cerebrovascular isquemico debido a oclusion gran arteria extracraneal| Hallazgo clínico',
#   0.48157456517219543),
#  ('439440006|entrevista historia desempeño ocupacional ii version 2 1| Estadificaciones y escalas',
#   0.4814225435256958),
#  ('286742002|accidente cerebrovascular inminente| Hallazgo clínico',
#   0.4813285768032074),
#  ('417506008|control accidente cerebrovascular hemorragico| Procedimiento',
#   0.4812522530555725),
#  ('447161003|puntaje escala valoracion eficacia afrontar dificultades laborales| Entidad observable',
#   0.48104017972946167),
#  ('258693003|libra| Calificador', 0.4809193015098572),
#  ('439219008|evaluacion disfasia| Procedimiento', 0.48056092858314514),
#  ('391123006|escala disnea medical research council : grado 2| Hallazgo clínico',
#   0.48054566979408264),
#  ('716873009|evaluacion inteligibilidad habla disartria| Estadificaciones y escalas',
#   0.47995778918266296),
#  ('118961000119101|antecedente accidente cerebrovascular hemorragico sin deficit residual| Situación con contexto explícito',
#   0.47947096824645996),
#  ('59103002|paralisis cerebral ataxia homolateral| Hallazgo clínico',
#   0.479330837726593),
#  ('736043007|escala cribado consumo sustancias psicoactivas crafft version 2 0| Estadificaciones y escalas',
#   0.4793136715888977),
#  ('718456009|puntaje promedio indice score funcion familiar y cambio 15 dimensiones 2 abrumado dificultades| Entidad observable',
#   0.47864851355552673),
#  ('716212003|evaluacion prueba frenchay cribado individuos afasia| Procedimiento',
#   0.47862252593040466),
#  ('273437007|escala eastern cooperative oncology group evaluacion fisica| Estadificaciones y escalas',
#   0.4785756468772888),
#  ('391125004|escala disnea medical research council : grado 4| Hallazgo clínico',
#   0.47837305068969727),
#  ('230715005|accidente cerebrovascular acv circulacion posterior patologia incierta| Hallazgo clínico',
#   0.4782862067222595),
#  ('229664007|disfasia receptiva| Hallazgo clínico', 0.4781774878501892),
#  ('423053003|desempeño eastern cooperative oncology group grado 3| Hallazgo clínico',
#   0.4778444468975067),
#  ('230714009|accidente cerebrovascular acv circulacion anterior patologia incierta| Hallazgo clínico',
#   0.47779586911201477),
#  ('366609000|prueba accidente cerebrovascular hallazgo| Hallazgo clínico',
#   0.4777645468711853),
#  ('46421000119102|trastorno comportamiento secuela infarto cerebral| Hallazgo clínico',
#   0.4775981307029724),
#  ('473290007|puntaje interpretacion cognitiva subescala alucinaciones auditivas escalas calificacion sintomas psicosis| Entidad observable',
#   0.47746169567108154),
#  ('373606000|accidente cerebrovascular oclusivo| Hallazgo clínico',
#   0.47741836309432983),
#  ('9901000119100|oclusion arteria cerebral accidente cerebrovascular| Hallazgo clínico',
#   0.4773261249065399),
#  ('230691006|accidente cerebrovascular oclusion arteria cerebral| Hallazgo clínico',
#   0.4773261249065399),
#  ('713043005|evaluacion uso perfil resultados medicos : midalo usted mismo measure yourself medical outcome profile| Procedimiento',
#   0.4771728515625),
#  ('736043007|escala cribado consumo sustancias psicoactivas carlos version 2 0| Estadificaciones y escalas',
#   0.4770476222038269),
#  ('309456003|clerigo| Contexto social', 0.4770466685295105),
#  ('724994008|accidente cerebrovascular isquemico debido a estenosis gran arteria extracraneal| Hallazgo clínico',
#   0.47696638107299805),
#  ('190773008|hiperbetalipoproteinemia| Hallazgo clínico', 0.47675424814224243),
#  ('718582003|evaluacion escala evaluacion abstinencia benzodiazepinas clinical institute| Procedimiento',
#   0.4763491153717041),
#  ('77728007|rehabilitacion luego episodio hemiplejia accidente cerebrovascular| Procedimiento',
#   0.47629252076148987),
#  ('421676007|distrito territorio canadiense| Ambiente o localización geográfica',
#   0.4762499928474426),
#  ('702315006|paralisis cerebral distonica| Hallazgo clínico',
#   0.47621816396713257),
#  ('722131000|conjunto referencias lenguaje idioma frances international organization for standardization codigo 639 1 fr| ',
#   0.4762062430381775),
#  ('716615006|puntaje prueba frenchay cribado individuos afasia| Entidad observable',
#   0.476089209318161),
#  ('138875005|snomed clinical terms version : 20070731 r edicion julio 2007| ',
#   0.47602564096450806),
#  ('230781006|paralisis cerebral distonica caracteristicas espasticas| Hallazgo clínico',
#   0.47596657276153564),
#  ('69306002|fitasa| Sustancia', 0.47591590881347656),
#  ('716874003|puntaje prueba inteligibilidad habla disartria| Entidad observable',
#   0.4758627712726593),
#  ('377360003|drospirenona etinilestradiol 3 mg/0 03 mg comprimido| Producto farmacéutico / biológico',
#   0.47582629323005676),
#  ('714354001|evaluacion escala calificacion sesiones grupales| Procedimiento',
#   0.47581422328948975),
#  ('293432006|efecto adverso inhibidor 3 hidroxi 3 metilglutaril coenzima a hmg coa reductasa| Hallazgo clínico',
#   0.4757249355316162),
#  ('719978000|evaluacion escala actividades cotidianas comunicacion segunda edicion| Procedimiento',
#   0.47571152448654175),
#  ('43486001|paralisis cerebral hemiplejica| Hallazgo clínico',
#   0.4756661057472229),
#  ('278512001|paralisis cerebral ataxica| Hallazgo clínico',
#   0.47544190287590027),
#  ('230700009|infarto lacunar sensitivo puro| Hallazgo clínico',
#   0.4754408895969391),
#  ('273784006|escala aptitud comunicacion temprana niños disfuncion auditiva| Estadificaciones y escalas',
#   0.47528231143951416),
#  ('715823002|puntaje esquema valoracion discapacidad organizacion mundial salud version 2 0| Entidad observable',
#   0.4750173091888428),
#  ('229691009|disartria velofaringe| Hallazgo clínico', 0.4749279022216797),
#  ('331596000|crotamiton 10 locion| Producto farmacéutico / biológico',
#   0.4749005436897278),
#  ('716240008|evaluacion esquema valoracion discapacidad organizacion mundial salud version 2 0| Procedimiento',
#   0.4748613238334656),
#  ('672461000119104|hemiplejia lado dominante debida a accidente cerebrovascular isquemico y posterior a| Hallazgo clínico',
#   0.47474992275238037),
#  ('725880001|puntaje participacion global preferencias actividades infantiles| Entidad observable',
#   0.47441351413726807),
#  ('718507006|puntaje perfil comunicacion funcional edimburgo| Entidad observable',
#   0.474403440952301),
#  ('230695002|accidente cerebrovascular parcial circulacion cerebral anterior| Hallazgo clínico',
#   0.47431179881095886),
#  ('333633007|apraxia transcortical| Hallazgo clínico', 0.474296510219574),
#  ('722129009|conjunto referencias lenguaje idioma japones international organization for standardization codigo 639 1 ja| ',
#   0.4742073714733124),
#  ('716212003|evaluacion prueba frenchay pesquisa individuos afasia| Procedimiento',
#   0.4741724729537964),
#  ('716776005|evaluacion prueba inteligibilidad habla disartria| Procedimiento',
#   0.4741324782371521),
#  ('450727001|evaluacion uso escala impacto eventos revisada| Procedimiento',
#   0.47401103377342224),
#  ('371079004|paralisis cerebral paraplejica| Hallazgo clínico',
#   0.47397005558013916),
#  ('716635007|trastorno cognitivo comunicacion| Hallazgo clínico',
#   0.47390642762184143),
#  ('716212003|evaluacion prueba frenchay screening individuos afasia| Procedimiento',
#   0.4738626480102539),
#  ('134771000119108|alteracion sensitiva efecto tardio accidente cerebrovascular| Hallazgo clínico',
#   0.47381675243377686),
#  ('407630006|escala gds nivel 2 deterioro cognitivo leve| Hallazgo clínico',
#   0.47362878918647766),
#  ('192813004|degeneracion cerebral enfermedad cerebrovascular| Hallazgo clínico',
#   0.47344648838043213),
#  ('333053007|carbarilo 0 5 locion alcoholica| Producto farmacéutico / biológico',
#   0.47336870431900024),
#  ('27201004|acrosteolisis| Hallazgo clínico', 0.4733335077762604),
#  ('722929005|accidente cerebrovascular arterial isquemico perinatal| Hallazgo clínico',
#   0.47327739000320435),
#  ('273784006|escala habilidades comunicacionales tempranas| Estadificaciones y escalas',
#   0.47319018840789795),
#  ('422517004|habilidades comunicacion interpersonal inadecuadas| Hallazgo clínico',
#   0.47301334142684937),
#  ('10325006|afasia amnesica| Hallazgo clínico', 0.47298505902290344),
#  ('719086002|evaluacion evaluaciones psicolinguisticas procesamiento lenguaje afasia| Procedimiento',
#   0.4728235900402069),
#  ('170600009|control accidente cerebrovascular| Procedimiento',
#   0.4727438688278198),
#  ('230701008|infarto lacunar sensoriomotor puro| Hallazgo clínico',
#   0.4727167785167694),
#  ('719085003|puntaje evaluaciones psicolinguisticas procesamiento lenguaje afasia| Entidad observable',
#   0.4727020561695099),
#  ('674401000119108|deficit habla y lenguaje debido a accidente cerebrovascular isquemico y posterior a| Hallazgo clínico',
#   0.4725901782512665),
#  ('97531000119106|antecedente accidente cerebrovascular parietal| Situación con contexto explícito',
#   0.4724043905735016),
#  ('473294003|puntaje subescala interpretacion cognitiva escalas calificacion sintomas psicosis| Entidad observable',
#   0.4723513126373291),
#  ('699429007|antecedente accidente cerebrovascular ultimas ocho semanas| Situación con contexto explícito',
#   0.4723505973815918),
#  ('716615006|puntaje prueba frenchay pesquisa individuos afasia| Entidad observable',
#   0.4722476899623871),
#  ('720196002|puntaje total indice score funcion familiar y cambio 15 dimensiones 2 abrumado dificultades| Entidad observable',
#   0.4720233976840973),
#  ('716240008|evaluacion esquema valoracion discapacidad oms version 2 0| Procedimiento',
#   0.471957266330719),
#  ('273896006|subcociente vineland comunicacion| Estadificaciones y escalas',
#   0.4719409942626953),
#  ('714343006|evaluacion escala breve eficacia parental| Procedimiento',
#   0.4718858003616333),
#  ('716212003|evaluacion prueba frenchay tamizado individuos afasia| Procedimiento',
#   0.4717991352081299),
#  ('391189007|intervencion temprana psicosis 1 3 contactos / mes| Procedimiento',
#   0.47167670726776123),
#  ('230690007|accidente cerebrovascular| Hallazgo clínico',
#   0.47165989875793457),
#  ('266257000|ataque isquemico transitorio| Hallazgo clínico',
#   0.4715661108493805),
#  ('672441000119103|hemiplejia lado no dominante debida a accidente cerebrovascular isquemico y posterior a| Hallazgo clínico',
#   0.4715557098388672),
#  ('448879004|conjunto referencias lenguaje idioma castellano international organization for standardization codigo 639 1| ',
#   0.4714847207069397),
#  ('448879004|conjunto referencias lenguaje idioma castellano international organization for standardization codigo 639 1| ',
#   0.4714847207069397),
#  ('718758006|evaluacion escala calificacion sesiones grupales infantiles| Procedimiento',
#   0.47137922048568726),
#  ('10624401000119102|antecedente familiar accidente cerebrovascular debido a aneurisma| Situación con contexto explícito',
#   0.47132158279418945),
#  ('716615006|puntaje prueba frenchay screening individuos afasia| Entidad observable',
#   0.4712478518486023),
#  ('443481007|puntaje escala riesgo caidas tinetti eficacia| Entidad observable',
#   0.47118496894836426),
#  ('690331000119109|deficit habla y lenguaje debido a accidente cerebrovascular embolico y posterior a| Hallazgo clínico',
#   0.47108471393585205),
#  ('91646005|afasia jerga| Hallazgo clínico', 0.47083061933517456),
#  ('716727004|evaluacion bateria trastornos comunicacion demencia arizona| Procedimiento',
#   0.4707987904548645),
#  ('76612001|hipercoagulable| Hallazgo clínico', 0.47066307067871094),
#  ('425389002|desempeño eastern cooperative oncology group grado 0| Hallazgo clínico',
#   0.47064608335494995),
#  ('672571000119109|deficit cognitivo debido a accidente cerebrovascular hemorragico y posterior a| Hallazgo clínico',
#   0.47055214643478394),
#  ('25133001|accidente cerebrovascular completamente desarrollado| Hallazgo clínico',
#   0.47045987844467163),
#  ('716175000|puntaje bateria arizona trastornos comunicacion demencia| Entidad observable',
#   0.4703914225101471),
#  ('423409001|desempeño eastern cooperative oncology group grado 5| Hallazgo clínico',
#   0.4703774154186249),
#  ('433183000|vejiga neruogenica efecto tardio accidente cerebrovascular| Hallazgo clínico',
#   0.4703075885772705),
#  ('734919008|puntaje escala breve eficacia parental| Entidad observable',
#   0.47019004821777344),
#  ('718433000|escala calificacion sesiones grupales| Estadificaciones y escalas',
#   0.470125675201416),
#  ('736043007|escala cribado consumo sustancias psicoactivas carro amigos relajacion lios olvido solo version 2 0| Estadificaciones y escalas',
#   0.4699596166610718),
#  ('716051003|accidente cerebrovascular intervencion quirurgica| Hallazgo clínico',
#   0.46984174847602844),
#  ('42270002|visitante accidente relacionado actividad laboral| Hallazgo clínico',
#   0.469798743724823),
#  ('446219005|evaluacion escala neuroconductual arnadottir actividades vida diaria terapia ocupacional| Procedimiento',
#   0.4697057008743286),
#  ('310137004|servicio accidente cerebrovascular| Calificador',
#   0.4693983197212219),
#  ('422512005|desempeño eastern cooperative oncology group grado 1| Hallazgo clínico',
#   0.4693267345428467),
#  ('439343009|escala riesgo caidas tinetti eficacia| Estadificaciones y escalas',
#   0.4692925810813904),
#  ('421667000|drospirenona 3 mg/etinilestradiol 0 02 mg comprimido| Producto farmacéutico / biológico',
#   0.46928754448890686),
#  ('331652006|disfasia semantica| Hallazgo clínico', 0.469196617603302),
#  ('91481002|intervencion ambiental nombre paciente psiquiatrico agencias| Procedimiento',
#   0.46918100118637085),
#  ('230690007|acv| Hallazgo clínico', 0.46915748715400696),
#  ('719150000|evaluacion indice actividades frenchay| Procedimiento',
#   0.4691319465637207),
#  ('116288000|accidente cerebrovascular paralitico| Hallazgo clínico',
#   0.46900689601898193),
#  ('717318005|evaluacion perfil comunicacion funcional edimburgo| Procedimiento',
#   0.4689835011959076),
#  ('229685007|disartria flacida| Hallazgo clínico', 0.4688366651535034),
#  ('80051000119107|manejo atencion accidente cerebrovascular| Procedimiento',
#   0.46881920099258423),
#  ('330920003|clioquinol pivalato flumetasona 1 /0 02 gotas oticas| Producto farmacéutico / biológico',
#   0.4687698781490326),
#  ('3381000175105|escala the ounce scale| Estadificaciones y escalas',
#   0.46874457597732544),
#  ('333087002|malation 0 5 locion alcoholica| Producto farmacéutico / biológico',
#   0.4687340259552002),
#  ('307801002|prueba memoria conductual rivermead version adulta| Estadificaciones y escalas',
#   0.46858784556388855),
#  ('690201000119109|ataxia debida a accidente cerebrovascular embolico y posterior a| Hallazgo clínico',
#   0.46843093633651733),
#  ('444172003|ataque isquemico cerebral transitorio recurrente| Hallazgo clínico',
#   0.46825551986694336),
#  ('717006009|evaluacion escala expresiva conceptos basicos bracken| Procedimiento',
#   0.4681853950023651),
#  ('26829003|intervencion ambiental nombre paciente psiquiatrico instituciones| Procedimiento',
#   0.46815499663352966),
#  ('716615006|puntaje prueba frenchay tamizado individuos afasia| Entidad observable',
#   0.46808475255966187),
#  ('690271000119104|hemiplejia lado no dominante debida a accidente cerebrovascular embolico y posterior a| Hallazgo clínico',
#   0.46799856424331665),
#  ('473291006|puntaje caracteristicas fisicas subescala alucinaciones auditivas escalas calificacion sintomas psicosis| Entidad observable',
#   0.4678584039211273),
#  ('63157004|afasia parietoccipital| Hallazgo clínico', 0.4676783084869385),
#  ('111297002|accidente cerebrovascular no paralitico| Hallazgo clínico',
#   0.46750152111053467),
#  ('229685007|disartria flaccida| Hallazgo clínico', 0.4674813151359558),
#  ('74506000|luto| Hallazgo clínico', 0.467307984828949),
#  ('725843007|cuestionario actividades vida diaria penn parkinson 15| Estadificaciones y escalas',
#   0.467146635055542),
#  ('91425008|intervencion ambiental nombre paciente psiquiatrico empleadores| Procedimiento',
#   0.4671367406845093),
#  ('442668000|hemiplejia lado no dominante efecto tardio enfermedad cerebrovascular| Hallazgo clínico',
#   0.46709978580474854),
#  ('273900009|subcociente escala vineland socializacion| Estadificaciones y escalas',
#   0.4670495390892029),
#  ('135877001|riesgo accidente cerebrovascular| Estadificaciones y escalas',
#   0.46698933839797974),
#  ('710125008|promocion uso habilidades memoria| Procedimiento',
#   0.4669378399848938),
#  ('138875005|snomed clinical terms version : 20110131 r enero 2011| ',
#   0.46682557463645935),
#  ('138875005|snomed clinical terms version : 20110731 r julio 2011| ',
#   0.46665191650390625),
#  ('674091000119108|vertigo debido a accidente cerebrovascular isquemico y posterior a| Hallazgo clínico',
#   0.46660301089286804),
#  ('722128001|conjunto referencias lenguaje idioma chino international organization for standardization codigo 639 1 zh| ',
#   0.46657490730285645),
#  ('714328009|evaluacion uso cuestionario cognitivo cotidiano| Procedimiento',
#   0.4665708541870117),
#  ('714328009|evaluacion uso cuestionario cognitivo cotidiano everyday cognition| Procedimiento',
#   0.4665708541870117),
#  ('407629001|escala gds sin deterioro cognitivo| Hallazgo clínico',
#   0.46651381254196167),
#  ('448003001|puntaje escala 3 preguntas royal college of physicians| Entidad observable',
#   0.4665011167526245),
#  ('442676003|hemiplejia lado dominante efecto tardio enfermedad cerebrovascular| Hallazgo clínico',
#   0.4664313793182373),
#  ('138875005|snomed clinical terms version : 20140131 r enero 2014| ',
#   0.46635958552360535),
#  ('216279008|accidente vehiculo pasajeros aeropuerto impulsado baterias| Evento',
#   0.46604853868484497),
#  ('719215002|evaluacion bateria afasia western| Procedimiento',
#   0.46591952443122864),
#  ('699232007|puntaje modulo realizacion deportes y actividades artisticas criterios valoracion discapacidades brazo hombro y mano| Entidad observable',
#   0.4659055769443512),
#  ('347144002|monosulfato guanetidina adrenalina 3 /0 5 colirio| Producto farmacéutico / biológico',
#   0.4658960700035095),
#  ('718434006|puntaje promedio indice score funcion familiar y cambio 15 dimensiones 1 fortalezas y adaptabilidad| Entidad observable',
#   0.4658607840538025),
#  ('138875005|snomed clinical terms version : edicion español 20080131 r enero 2008| ',
#   0.4657132029533386),
#  ('275526006|antecedente : accidente cerebrovascular| Situación con contexto explícito',
#   0.4656522274017334),
#  ('55487001|empleador accidente relacionado actividad laboral| Hallazgo clínico',
#   0.46564996242523193),
#  ('710146004|promocion comunicacion familiar efectiva| Procedimiento',
#   0.4655468463897705),
#  ('718903000|evaluacion escala integrada resultados cuidados paliativos 5 version personal periodo recuerdo 3 dias| Procedimiento',
#   0.4654598832130432),
#  ('273462007|prueba cribado afasia frenchay| Estadificaciones y escalas',
#   0.46544912457466125),
#  ('311480009|escalas evaluacion memoria williams| Estadificaciones y escalas',
#   0.46544352173805237),
#  ('80935004|hemiplejia flacida| Hallazgo clínico', 0.46534302830696106),
#  ('722130004|conjunto referencias lenguaje idioma aleman international organization for standardization codigo 639 1| ',
#   0.46510183811187744),
#  ('715195002|evaluacion bateria apraxia cambridge| Procedimiento',
#   0.4650089144706726),
#  ('720562002|indice score funcion familiar y cambio 15 dimensiones 2 abrumado dificultades| Estadificaciones y escalas',
#   0.46487313508987427),
#  ('473354003|puntaje inventario movilidad agorafobia sujeto acompañado| Entidad observable',
#   0.46472227573394775),
#  ('230279005|disfasia progresiva tipo no alzheimer| Hallazgo clínico',
#   0.4646865725517273),
# ...
#   0.44692230224609375),
#  ('86383003|coccidioidina| Sustancia', 0.44692230224609375),
#  ('273603009|puntaje prueba mental version larga| Estadificaciones y escalas',
#   0.4468984603881836),
#  ('377421004|etinilestradiol norgestrel 0 05 mg/0 5 mg comprimido| Producto farmacéutico / biológico',
#   0.4468863010406494),
#  ('306802002|derivacion a servicio accidente cerebrovascular| Procedimiento',
#   0.44686412811279297),
#  ('330762002|clorhidrato proximetacaina fluoresceina sodica 0 5 /0 25 colirio monodosis| Producto farmacéutico / biológico',
#   0.4468570351600647),
#  ('373606000|acv oclusivo| Hallazgo clínico', 0.44679564237594604),
#  ('716212003|evaluacion prueba frenchay deteccion selectiva individuos afasia| Procedimiento',
#   0.44678133726119995),
#  ('14686007|hemianestesia| Hallazgo clínico', 0.4467700719833374),
#  ('724762006|parkinsonismo postraumatico| Hallazgo clínico',
#   0.44676339626312256),
#  ('348445008|producto contiene bromhidrato escopolamina 0 15 mg cada comprimido administracion oral| Producto farmacéutico / biológico',
#   0.44669249653816223),
#  ('725877002|evaluacion escala medicion participacion y medioambiental niños y jovenes| Procedimiento',
#   0.44667553901672363),
#  ('308380009|remolcador| Contexto social', 0.44665876030921936),
#  ('719147003|evaluacion prueba aprendizaje verbal california version infantil| Procedimiento',
#   0.44665583968162537),
#  ('443758006|grado numerico escala 0 a 3| Calificador', 0.4465981125831604),
#  ('734592007|inhibidor 3 hidroxi 3 metilglutaril coenzima a reductasa| Calificador',
#   0.44656893610954285),
#  ('96302009|inhibidor 3 hidroxi 3 metilglutaril coenzima a reductasa| Producto farmacéutico / biológico',
#   0.44656893610954285),
#  ('372912004|inhibidor 3 hidroxi 3 metilglutaril coenzima a reductasa| Sustancia',
#   0.44656893610954285),
#  ('326309006|producto contiene solamente desogestrel 0 15 miligramos y etinilestradiol 0 02 miligramos cada comprimido administracion oral| Producto farmacéutico / biológico',
#   0.4465658366680145),
#  ('273338003|prueba deletreo basada escalas britanicas capacidades| Estadificaciones y escalas',
#   0.4465528130531311),
#  ('273927008|bateria afasia western| Estadificaciones y escalas',
#   0.44650110602378845),
#  ('407629001|edg nivel 1 sin deterioro cognitivo| Hallazgo clínico',
#   0.44649621844291687),
#  ('333254007|gluconato clorhexidina cetrimida 0 015 /0 15 solucion| Producto farmacéutico / biológico',
#   0.4464935064315796),
#  ('413119003|miembro grupo accidente cerebrovascular| Hallazgo clínico',
#   0.44646263122558594),
#  ('725812000|evaluacion prueba ordenamiento tarjetas actividades| Procedimiento',
#   0.44643694162368774),
#  ('710575003|ataque isquemico transitorio debido a embolia| Hallazgo clínico',
#   0.4464069604873657),
#  ('445040008|evaluacion riesgo violencia version 2 hcr 20| Procedimiento',
#   0.44639331102371216),
#  ('445195000|version 2 hcr 20 evaluacion riesgo violencia| Estadificaciones y escalas',
#   0.44639331102371216),
#  ('423053003|desempeño ecog grado 3| Hallazgo clínico', 0.446389377117157),
#  ('216283008|accidente vagon troncos arboles| Evento', 0.4463820159435272),
#  ('674121000119107|ataxia debida a accidente cerebrovascular hemorragico y posterior a| Hallazgo clínico',
#   0.44637972116470337),
#  ('711452002|escala evaluacion comprension y expresion 6 11| Estadificaciones y escalas',
#   0.4463341236114502),
#  ('718975008|escala integrada resultados cuidados paliativos version paciente periodo recuerdo 1 semana| Estadificaciones y escalas',
#   0.4463280737400055),
#  ('377360003|drospirenona 3 mg y etinilestradiol 0 03 mg cada comprimido administracion oral| Producto farmacéutico / biológico',
#   0.446316659450531),
#  ('407887004|etinilestradiol 0 03 mg y drospirenona 3 mg cada comprimido administracion oral| Producto farmacéutico / biológico',
#   0.446316659450531),
#  ('273937003|escala discapacidad integracion social organizacion mundial salud oms| Estadificaciones y escalas',
#   0.4463125467300415),
#  ('721142006|sindrome hereditario endoteliopatia retinopatia nefropatia y accidente cerebrovascular| Hallazgo clínico',
#   0.4463040828704834),
#  ('718725002|evaluacion escala evaluacion comprension y expresion 6 11| Procedimiento',
#   0.44628745317459106),
#  ('82361000119107|comportamiento alterado demencia debida a corea huntington| Hallazgo clínico',
#   0.44625556468963623),
#  ('160340009|antecedente familiar paralisis cerebral| Situación con contexto explícito',
#   0.44625434279441833),
#  ('192871008|sindrome ramsay hunt ataxia| Hallazgo clínico',
#   0.446135014295578),
#  ('331505006|dimeticona 1000 cetrimida 10 /0 3 crema| Producto farmacéutico / biológico',
#   0.44610244035720825),
#  ('273756001|escala lenguaje discapacitados visuales reynell zinkin| Estadificaciones y escalas',
#   0.44605985283851624),
#  ('442181008|monoplejia miembro superior no dominante efecto tardio accidente cerebrovascular| Hallazgo clínico',
#   0.4460591673851013),
#  ('229212007|danzaterapia creativa| Procedimiento', 0.4460379481315613),
#  ('68131000119100|paralisis facial grado 3 house brackmann| Hallazgo clínico',
#   0.4460243880748749),
#  ('377419009|producto contiene solamente etinilestradiol 0 03 mg y norgestrel 0 3 mg cada comprimido administracion oral| Producto farmacéutico / biológico',
#   0.446014404296875),
#  ('237952001|aciduria 3 metaglutaconica actividad normal 3 metilglutaconil coa hidratasa| Hallazgo clínico',
#   0.44593238830566406),
#  ('273933004|escala discapacidad movilidad organizacion mundial salud| Estadificaciones y escalas',
#   0.44592034816741943),
#  ('273933004|escala discapacidad movilidad organizacion mundial salud| Estadificaciones y escalas',
#   0.44592034816741943),
#  ('347214009|prednisolona 0 003 colirio| Producto farmacéutico / biológico',
#   0.445821613073349),
#  ('278287000|hemiparesia izquierda| Hallazgo clínico', 0.44580113887786865),
#  ('427065003|monoplejia miembro superior dominante efecto tardio accidente cerebrovascular| Hallazgo clínico',
#   0.44579100608825684),
#  ('326310001|producto contiene solamente etinilestradiol 0 03 miligramos y desogestrel 0 15 miligramos cada comprimido administracion oral| Producto farmacéutico / biológico',
#   0.44578981399536133),
#  ('722136005|modulo recursos iniciales idioma japones mantenido international health terminology standards development organisation| ',
#   0.445726215839386),
#  ('714360001|puntaje escala evaluacion enfermedad alzheimer| Entidad observable',
#   0.4457085430622101),
#  ('429389007|escala intencion suicida pierce| Estadificaciones y escalas',
#   0.44567936658859253),
#  ('716792000|evaluacion escala niveles funcionamiento cognitivo rancho amigos| Procedimiento',
#   0.4456533193588257),
#  ('242985002|lesion impacto vehiculo motor movimiento intencion desconocida| Hallazgo clínico',
#   0.44557899236679077),
#  ('333035001|carbarilo producto| Producto farmacéutico / biológico',
#   0.4454888105392456),
#  ('713198003|cribado cognitivo oxford| Estadificaciones y escalas',
#   0.44547706842422485),
#  ('330646001|yoduro ecotiopato 0 06 colirio| Producto farmacéutico / biológico',
#   0.4454766511917114),
#  ('716849001|evaluacion prueba lenguaje cotidiano amsterdam nijmegen| Procedimiento',
#   0.4454665184020996),
#  ('446964003|puntaje herramienta deteccion selectiva nivel cognitivo allen version completa| Entidad observable',
#   0.44545215368270874),
#  ('431315003|grabacion audio entrevista sujeto| Procedimiento',
#   0.445417582988739),
#  ('716853004|puntaje prueba dimensiones linguisticas objetivas wechsler| Entidad observable',
#   0.4453710913658142),
#  ('703163006|enfermedad cerebrovascular secundaria| Hallazgo clínico',
#   0.4453292489051819),
#  ('718049007|test recepcion gramatical version 2| Estadificaciones y escalas',
#   0.4453093111515045),
#  ('270389004|representante demandante autorizacion movilidad| Objeto físico',
#   0.44528740644454956),
#  ('230280008|afasia progresiva mal alzheimer| Hallazgo clínico',
#   0.44528305530548096),
#  ('724424009|accidente cerebrovascular isquemico debido a oclusion pequeña arteria| Hallazgo clínico',
#   0.4452758729457855),
#  ('718967002|escala integrada resultados cuidados paliativos version personal periodo recuerdo 1 semana| Estadificaciones y escalas',
#   0.4452732801437378),
#  ('311949005|crayon| Sustancia', 0.44527167081832886),
#  ('391126003|escala disnea mrc : grado 5| Hallazgo clínico',
#   0.4451906085014343),
#  ('445195000|version 2 escala valoracion riesgo comportamientos violentos 20 items| Estadificaciones y escalas',
#   0.4451867938041687),
#  ('717353003|boehm 3 preescolar| Estadificaciones y escalas',
#   0.44517654180526733),
#  ('447198002|producto contiene diclorhidrato pramipexol 0 125 miligramos cada comprimido administracion oral| Producto farmacéutico / biológico',
#   0.44511735439300537),
#  ('347142003|monosulfato guanetidina 0 5 colirio| Producto farmacéutico / biológico',
#   0.4450758695602417),
#  ('377219007|sulfato atropina sulfato hiosciamina bromhidrato escopolamina 0 0194 mg/0 1037 mg/0 0065 mg comprimido| Producto farmacéutico / biológico',
#   0.44507357478141785),
#  ('438513002|degeneracion cerebral enfermedad parkinson| Hallazgo clínico',
#   0.4450569748878479),
#  ('134748003|dexametasona tobramicina 0 1 /0 3 colirio| Producto farmacéutico / biológico',
#   0.4449603855609894),
#  ('249949001|clasificacion medical research council potencia muscular grado 0| Hallazgo clínico',
#   0.4449215829372406),
#  ('347154003|bromhidrato homatropina 0 5 colirio| Producto farmacéutico / biológico',
#   0.44487500190734863),
#  ('35314007|huracan| Evento', 0.44481924176216125),
#  ('391171006|atencion psiquiatrica general adultos mayores : 1 a 3 contactos / mes| Procedimiento',
#   0.4448108673095703),
#  ('708735004|escala somnolencia epworth| Estadificaciones y escalas',
#   0.4447547197341919),
#  ('330762002|clorhidrato proparacaina fluoresceina sodica 0 5 /0 25 colirio monodosis| Producto farmacéutico / biológico',
#   0.44474971294403076),
#  ('16024151000119105|accidente cerebrovascular debido a oclusion arteria cerebelosa izquierda| Hallazgo clínico',
#   0.4447363615036011),
#  ('230690007|stroke| Hallazgo clínico', 0.4446050524711609),
#  ('331292004|digluconato clorhexidina ametocaina 0 05/0 015 aerosol uso oral| Producto farmacéutico / biológico',
#   0.44455283880233765),
#  ('229706001|apraxia ideomotora| Hallazgo clínico', 0.4445264935493469),
#  ('116340000|trastorno aprendizaje cognitivo| Hallazgo clínico',
#   0.4445245862007141),
#  ('371678006|clioquinol hidrocortisona 3 /0 5 crema| Producto farmacéutico / biológico',
#   0.44447994232177734),
#  ('330421007|lomefloxacina 0 3 colirio| Producto farmacéutico / biológico',
#   0.44447436928749084),
#  ('717786001|puntaje escala breve calificacion depresion| Entidad observable',
#   0.4444425702095032),
#  ('72655000|hemiplejia alternada hipogloso| Hallazgo clínico',
#   0.44441795349121094),
#  ('330421007|lomefloxacino 0 3 colirio| Producto farmacéutico / biológico',
#   0.4444136619567871),
#  ('716556002|puntaje perfil comunicacion funcional revisado| Entidad observable',
#   0.4443952441215515),
#  ('273933004|escala discapacidad movilidad oms| Estadificaciones y escalas',
#   0.44434911012649536),
#  ('273933004|escala discapacidad movilidad oms| Estadificaciones y escalas',
#   0.44434911012649536),
#  ('304781001|escalas comportamiento adaptativo vineland| Estadificaciones y escalas',
#   0.4443437457084656),
#  ('376589005|producto contiene diclorhidrato pramipexol 0 5 miligramos cada comprimido administracion oral| Producto farmacéutico / biológico',
#   0.4442906379699707),
#  ('313008000|comunicacion pronostico a familiar| Procedimiento',
#   0.4442877173423767),
#  ('290631000119103|disartria debida a accidente cerebrovascular y posterior a| Hallazgo clínico',
#   0.44425255060195923),
#  ('273461000|indice actividades frenchay| Estadificaciones y escalas',
#   0.4442446827888489),
#  ('251361006|escala discriminacion habla| Entidad observable',
#   0.444240927696228),
#  ('425313007|grado numerico escala 0 a 5| Calificador', 0.444237619638443),
#  ('370315001|producto benoxinato| Producto farmacéutico / biológico',
#   0.44421887397766113),
#  ('464113007|dispositivo entrenamiento comunicacion dibujo y pintura| Elemento de registro',
#   0.44421687722206116),
#  ('362411002|hemisferio cerebelar| Estructura corporal', 0.4442130923271179),
#  ('6566002|hemisferio cerebelar| Estructura corporal', 0.4442130923271179),
#  ('160252004|sin antecedentes familiares accidente cardiovascular o cerebrovascular| Situación con contexto explícito',
#   0.44419872760772705),
#  ('450755002|puntaje escala disnea consejo investigacion medica| Entidad observable',
#   0.44413065910339355),
#  ('138875005|snomed clinical terms edicion español 20100731 r edicion julio 2010| ',
#   0.4441288113594055),
#  ('391188004|intervencion temprana psicosis 1 2 contactos / semana| Procedimiento',
#   0.44412821531295776),
#  ('445796009|evaluacion entrevista antecedentes desempeño laboral| Procedimiento',
#   0.44407129287719727),
#  ('21000122101|escala gijon valoracion socio familiar anciano| Estadificaciones y escalas',
#   0.4440543055534363),
#  ('401323002|escala disnea borg : 0 5 leve apenas perceptible| Hallazgo clínico',
#   0.4440385401248932),
#  ('699248008|puntaje impacto negativo indice cuidadores personas ancianas europa| Entidad observable',
#   0.44403761625289917),
#  ('273687008|socios entrenamiento comunicacion aumentativa| Estadificaciones y escalas',
#   0.44403713941574097),
#  ('443350002|escala movilidad pulgar kapandji| Estadificaciones y escalas',
#   0.44397449493408203),
#  ('273269001|escala evaluacion enfermedad alzheimer| Estadificaciones y escalas',
#   0.4439568817615509),
#  ('249955006|clasificacion medical research council potencia muscular grado 5| Hallazgo clínico',
#   0.44393953680992126),
#  ('409190003|desogestrel etinilestradiol 0 1 mg/0 025 mg comprimido| Producto farmacéutico / biológico',
#   0.4439230263233185),
#  ('330646001|yoduro ecotiofato 0 06 colirio| Producto farmacéutico / biológico',
#   0.443900465965271),
#  ('377326005|producto contiene solamente desogestrel 0 15 mg y etinilestradiol 0 03 mg cada comprimido administracion oral| Producto farmacéutico / biológico',
#   0.44386714696884155),
#  ('424943007|flavonoide| Sustancia', 0.44378477334976196),
#  ('103303007|perdida auditiva remite ataque vertigo| Hallazgo clínico',
#   0.4437583088874817),
#  ('716769000|evaluacion escala lenguaje preescolar| Procedimiento',
#   0.4437582194805145),
#  ('375524008|sulfacetamida sodica 10 locion| Producto farmacéutico / biológico',
#   0.44374513626098633),
#  ('407634002|escala deterioro general nivel 6 deterioro cognitivo grave| Hallazgo clínico',
#   0.44371387362480164),
#  ('446769003|puntaje entrevista antecedentes desempeño laboral| Entidad observable',
#   0.4437074661254883),
#  ('322081002|producto contiene solamente bromhidrato escopolamina 0 3 mg cada comprimido administracion oral| Producto farmacéutico / biológico',
#   0.4436894655227661),
#  ('447199005|producto contiene diclorhidrato pramipexol 0 25 miligramos cada comprimido administracion oral| Producto farmacéutico / biológico',
#   0.443650484085083),
#  ('373806003|grado 3 escala funcional organizacion mundial salud| Hallazgo clínico',
#   0.4436416029930115),
#  ('322081002|bromhidrato escopolamina 0 3 mg cada comprimido administracion oral| Producto farmacéutico / biológico',
#   0.4436185956001282),
#  ('473307002|evaluacion utilizacion evaluacion cognitiva addenbrooke revisada subescala memoria| Procedimiento',
#   0.44360873103141785),
#  ('718167003|puntaje escala vocabulario crichton| Entidad observable',
#   0.44360652565956116),
#  ('377404008|producto contiene solamente norgestrel 0 3 mg fumarato ferroso 75 mg y etinilestradiol 0 03 mg cada comprimido administracion oral| Producto farmacéutico / biológico',
#   0.4435603618621826),
#  ('718617006|puntaje escala evaluacion abstinencia benzodiazepinas instituto clinico| Entidad observable',
#   0.44348740577697754),
#  ('716159003|evaluacion bateria neuropsicologica luria nebraska| Procedimiento',
#   0.44348371028900146),
#  ('725809003|escalas funcion y participacion miller| Estadificaciones y escalas',
#   0.44347381591796875)]

# %%
term=['dcha']
mas_similar(term, topn=10)
# Out:
# [('264551002|microtraumatismo| Calificador', 0.5249876976013184),
#  ('110397009|microtraumatismo| Estructura corporal', 0.5249876976013184),
#  ('719547006|superficie distal tibia derecha| Estructura corporal',
#   0.5092614889144897),
#  ('719548001|superficie distal tibia izquierda| Estructura corporal',
#   0.508665144443512),
#  ('11809901000119104|abrasion rodilla derecha| Hallazgo clínico',
#   0.504396378993988),
#  ('735826003|ruptura traumatica ligamento palmar a altura articulacion metacarpofalangica mano| Hallazgo clínico',
#   0.504317045211792),
#  ('735824000|ruptura traumatica ligamento lateral articulacion metacarpofalangica mano| Hallazgo clínico',
#   0.5040948390960693),
#  ('11809941000119102|abrasion rodilla izquierda| Hallazgo clínico',
#   0.5032720565795898),
#  ('1075451000119103|ruptura cronica ligamento cruzado anterior rodilla izquierda| Hallazgo clínico',
#   0.501764178276062),
#  ('1075411000119104|ruptura cronica ligamento cruzado anterior rodilla derecha| Hallazgo clínico',
#   0.5012276768684387)]

# %%
term=['cefaleas']
mas_similar(term, topn=10)
# Out:
# [('712831003|cefaleas frecuentes| Hallazgo clínico', 0.8160639405250549),
#  ('725058003|sindrome ataques cefaleas neuralgiformes unilaterales breve duracion inyeccion conjuntival y secrecion lagrimal| Hallazgo clínico',
#   0.5999895334243774),
#  ('55533009|olvidos frecuentes| Hallazgo clínico', 0.5435292720794678),
#  ('416714005|escenas retrospectivas episodicas| Hallazgo clínico',
#   0.533408522605896),
#  ('62770008|litoria aurea| Organismo', 0.5255089402198792),
#  ('52754008|menstruacion inusualmente frecuente| Hallazgo clínico',
#   0.515266478061676),
#  ('51895004|jacamerops aurea| Organismo', 0.5096697807312012),
#  ('44376007|histeria| Hallazgo clínico', 0.509282648563385),
#  ('170634005|trastornos sueño frecuentes debidos asma| Hallazgo clínico',
#   0.502802312374115),
#  ('266601003|menstruacion excesiva y frecuente| Hallazgo clínico',
#   0.5004130005836487)]

# %%
term=['transparietal']
mas_similar(term, topn=10)
# Out:
# [('103354007|transparietal|Calificador', 1.0),
#  ('281587000|pentalogia cantrell|Hallazgo clínico', 0.6808680295944214),
#  ('83698002|reparacion completa tetralogia fallot parche transparietal|Procedimiento',
#   0.6761741638183594),
#  ('85844000|infarto transparietal|Estructura corporal', 0.6622048616409302),
#  ('399228007|tetralogia fallot ausencia valvula pulmonar|Hallazgo clínico',
#   0.6258249282836914),
#  ('70422006|infarto no transparietal agudo|Hallazgo clínico',
#   0.6215298771858215),
#  ('204351007|trilogia fallot|Hallazgo clínico', 0.6208992004394531),
#  ('204351007|trilogia fallot|Hallazgo clínico', 0.6208992004394531),
#  ('78235001|interfirio|Calificador', 0.619303822517395),
#  ('233049006|reparacion defecto tabique auriculoventricular asociado tetralogia fallot|Procedimiento',
#   0.6188405752182007)]

# %%
term=['infarto', 'pulmonar']
mas_similar(term, topn=10)
# Out:
# [('64662007|infarto pulmonar| Hallazgo clínico', 1.0),
#  ('1001000119102|embolia pulmonar infarto pulmonar| Hallazgo clínico',
#   0.9005996584892273),
#  ('83727005|infarto pulmonar hemorragico| Hallazgo clínico',
#   0.8857958316802979),
#  ('85844000|infarto transparietal| Estructura corporal', 0.8485758304595947),
#  ('81037000|infarto lagunar| Estructura corporal', 0.837242841720581),
#  ('230692004|infarto precerebral| Hallazgo clínico', 0.8291271924972534),
#  ('31092005|infarto zahn| Estructura corporal', 0.8280655741691589),
#  ('55641003|infarto| Estructura corporal', 0.8280655741691589),
#  ('64662007|infarto pulmon| Hallazgo clínico', 0.8187499642372131),
#  ('71911007|infarto cicatrizado| Estructura corporal', 0.8079499006271362)]

# %% [markdown]
# ### Código Fuente original de gensim.most_similar(): (Simulacro funcionamiento y explicación)
# Se adapta este mismo código, para que se pueda aplicar a nuestro espacio vectorial **Snomed2Vec**

# %% [markdown]
# ** Metodos necesarios para obtener el Most_Similar() - Original Gensim:**

# %%
def init_sims(self, replace=False):
        """ Precompute L2-normalized vectors.
        If `replace` is set, forget the original vectors and only keep the normalized ones = saves lots of memory!
        Note that you **cannot continue training** after doing a replace. The model becomes
        effectively read-only = you can call `most_similar`, `similarity` etc., but not `train`.
        """
        if getattr(self, 'syn0norm', None) is None or replace:
            logger.info("precomputing L2-norms of word weight vectors")
            if replace:
                for i in xrange(w2v_InfAltaSK.syn0.shape[0]):
                    w2v_InfAltaSK.syn0[i, :] /= sqrt((w2v_InfAltaSK.syn0[i, :] ** 2).sum(-1))
                w2v_InfAltaSK.syn0norm = w2v_InfAltaSK.syn0
            else:
                w2v_InfAltaSK.syn0norm = (w2v_InfAltaSK.syn0 / sqrt((w2v_InfAltaSK.syn0 ** 2).sum(-1))[..., newaxis]).astype(REAL)

# %%
# Version Original Word2Vec-----------------------------------------------------------------:

def most_similar(self, positive=[], negative=[], topn=10, restrict_vocab=None, indexer=None):

        self.init_sims()

        if isinstance(positive, string_types) and not negative:
            # allow calls like most_similar('dog'), as a shorthand for most_similar(['dog'])
            positive = [positive]

        # add weights for each word, if not already present; default to 1.0 for positive and -1.0 for negative words
        positive = [
            (word, 1.0) if isinstance(word, string_types + (ndarray,)) else word
            for word in positive
        ]
        negative = [
            (word, -1.0) if isinstance(word, string_types + (ndarray,)) else word
            for word in negative
        ]

        # compute the weighted average of all words
        all_words, mean = set(), []
        for word, weight in positive + negative:
            if isinstance(word, ndarray):
                mean.append(weight * word)
            elif word in self.vocab:
                mean.append(weight * self.syn0norm[self.vocab[word].index])
                all_words.add(self.vocab[word].index)
            else:
                raise KeyError("word '%s' not in vocabulary" % word)
        if not mean:
            raise ValueError("cannot compute similarity with no input")
        mean = matutils.unitvec(array(mean).mean(axis=0)).astype(REAL)

        if indexer is not None:
            return indexer.most_similar(mean, topn)

        limited = self.syn0norm if restrict_vocab is None else self.syn0norm[:restrict_vocab]
        dists = dot(limited, mean)
        if not topn:
            return dists
        best = matutils.argsort(dists, topn=topn + len(all_words), reverse=True)
        # ignore (don't return) words from the input
        result = [(self.index2word[sim], float(dists[sim])) for sim in best if sim not in all_words]
        return result[:topn]

# %%
w2v_InfAltaSK.init_sims()
# Out:
# 2018-09-23 19:44:51,851 : INFO : precomputing L2-norms of word weight vectors

# %%
w2v_InfAltaSK.syn0norm.shape
# Out:
# (98103, 300)

# %%
word='infarto'
positive=[word]
positive = [(word, 1.0) if isinstance(word, string_types + (ndarray,)) else word for word in positive]
print(positive)
# Out:
# [('infarto', 1.0)]

# %%
word='infarto'
syn0norm[w2v_InfAltaSK.vocab[word].index]

# %%
all_words, mean = set(), []
for word, weight in positive:
    print(word)
    print(weight)
    if isinstance(word, ndarray):
        mean.append(weight * word)
    elif word in w2v_InfAltaSK.vocab:
        mean.append(weight * w2v_InfAltaSK.syn0norm[w2v_InfAltaSK.vocab[word].index])
        all_words.add(w2v_InfAltaSK.vocab[word].index)
    else:
        raise KeyError("word '%s' not in vocabulary" % word)
    if not mean:
        raise ValueError("cannot compute similarity with no input")
print(type(mean)  )      
mean = matutils.unitvec(array(mean).mean(axis=0)).astype(REAL)
print(type(mean))
# Out:
# infarto
# 1.0
# <class 'list'>
# <class 'numpy.ndarray'>

# %%
limited = w2v_InfAltaSK.syn0norm

dists = dot(limited, mean)
print(dists)
print(len(dists))
best = matutils.argsort(dists, topn=10 + len(all_words), reverse=True)
print(best)
# Out:
# [ 0.0770419   0.08676368  0.07107695 ...,  0.35047367  0.4828262   0.4055863 ]
# 98103
# [ 4578  5789  4135 26512 18391 11111  4414 24905 49978  9681 44698]

# %%
print(all_words)
# Out:
# {4578}

# %%
result = [(w2v_InfAltaSK.index2word[sim], float(dists[sim])) for sim in best if sim not in all_words]
result[:10]
# Out:
# [('lacunar', 0.8207111954689026),
#  ('territorio', 0.7604696750640869),
#  ('agudo/subagudo', 0.7399933934211731),
#  ('acmi', 0.7191818952560425),
#  ('extenso', 0.7096375823020935),
#  ('acm', 0.706554651260376),
#  ('vertebro-basilar', 0.7032238245010376),
#  ('isuqemico', 0.7029422521591187),
#  ('cerebeloso', 0.6982408165931702),
#  ('agudo-subagudo', 0.6956357955932617)]

# %%
term=['infarto']

# %%
w2v_SnomedSK.most_similar(term,topn=10)
# Out:
# 2018-09-24 12:52:33,392 : INFO : precomputing L2-norms of word weight vectors
# [('miocardio', 0.8871554732322693),
#  ('cerebrovascular', 0.81633061170578),
#  ('cardiaco', 0.7894208431243896),
#  ('embolia', 0.7829642295837402),
#  ('cardíaco', 0.7815970182418823),
#  ('ictus', 0.7750582695007324),
#  ('cardíaca', 0.7426031827926636),
#  ('cardiaca', 0.7415591478347778),
#  ('aneurisma', 0.740800142288208),
#  ('infartos', 0.7397944331169128)]

# %%
w2v_SnomedSK.most_similar(['coche'],topn=10)
# Out:
# [('automóvil', 0.7691925168037415),
#  ('vehículo', 0.7672134637832642),
#  ('coches', 0.7424559593200684),
#  ('furgoneta', 0.738179624080658),
#  ('moto', 0.707735538482666),
#  ('aparcado', 0.686632513999939),
#  ('carro', 0.6852102279663086),
#  ('autobús', 0.6705993413925171),
#  ('todoterreno', 0.6632262468338013),
#  ('camión', 0.66265869140625)]

# %% [markdown]
# ### Función Gensim.Similarity()

# %%
def similarity(self, w1, w2):
        """
        Compute cosine similarity between two words.
        Example::
          >>> trained_model.similarity('woman', 'man')
          0.73723527
          >>> trained_model.similarity('woman', 'woman')
          1.0
        """
        return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))

# %% [markdown]
# ## 5. Obtener Querys Vectors: (Tools)

# %%
def getConcept(term):
    # Term debe estar denro de un array ['term1','term2']
    return SnomedWork[SnomedWork['corpusTerm'].isin(term)]

# %%
term=['infarto']
getConcept(term)

# %%
def getIdConcept(id):
    return SnomedWork.loc[SnomedWork['idConcept']==id, ['jerarquia','corpusTerm']]

# %%
id='104001'
getIdConcept(id)
# Out:
#        jerarquia                                    corpusTerm
# 3  Procedimiento                    [escision, lesion, rotula]
# 4  Procedimiento  [escision, local, lesion, o, tejido, rotula]
# 5  Procedimiento                    [escision, lesion, rotula]
# 6  Procedimiento                   [reseccion, lesion, rotula]
# 7  Procedimiento                   [reseccion, lesion, rotula]

# %%
def vectorSnomed(lstgrams,size):
    output=[]
    buffer=np.zeros((size,), dtype=np.float32)
    for item in lstgrams:
        try:
            buffer = buffer + w2v_InfAltaSK.word_vec(item)
        except:
            buffer = buffer + np.zeros((size,), dtype=np.float32)
            #break
    #output.extend( buffer)
    return buffer

# %%
# Funcion similitud Distancia del Coseno, Parametros Vectores
def vSimilar(wv1,wv2):
    return np.nan_to_num((round(float(np.dot(wv1, wv2)/(np.linalg.norm(wv1) * np.linalg.norm(wv2))),4)))

# %%
# Calcula los n-gramas, segun una lista de tokens, valor n
def ngrams(listTokens, n):
    output = []  
    for i in range(len(listTokens)-n+1):
        output.append(listTokens[i:i+n])
    return output

# %%
# Crea todos los n-gramas de una frase según (n)
#Salida: lista de n-gramas desde 1 hasta n
def todosGramas(listTokens,n):
    output=[]
    buffer=[]
    for i in range(n):
        i+=1
        output.append(ngrams(listTokens, i))
    for i in range(n):
        buffer+= output[i]
    return buffer

# %%
# Entrada: Lista de gramas ['1-grama','2-grama',['3-grama','4-grama]]
from nltk.util import skipgrams

def skipgramas(frase,n,k):
    return(skipgrams(sent, n, k))

# %% [markdown]
# ### 4.1 Crear Vector para cada token de la frase.
# Generación de los vectores de los tokens de cada frase.<br>
# * Funcion **creaVector(frase, size)**, genera un vector por cada token de la frase.
#     * Entrada: lista de tokens de la **frase** y **size**, tamaño del vector generado según modelo W2V (300 o 100)
#     * Salida: lista con los vectores de cada token, de la frase
#
# * Funcion: **vectorTotal(listGramas, size)**
#     * Entrada: **listGramas**, lista de n-gramas generados, **size**, tamaño del vector, según modelo W2V.
#     * Salida: Vectores asociados a cada frase, si es 1-grama -> Salida Vector(token).<br>
#       Si la frase tiene **n** gramas -> Salida $$(V[p]=v[tk_{1}]+v[tk_{2}]+...+v[tk_{n}])$$

# %% [markdown]
# ### 4.2. Crear los vectores para todos los ngramas generados:

# %%
# Entrada: lista de Frase, con ngramas en sublistas
# Ejemplo: todosGramas(textP13,3) 
# Entrada: ['fiebre','gripe','tos']
# Salida: [['fiebre'],['gripe'],['tos'],['fiebre', 'gripe'], ['gripe', 'tos'],['fiebre', 'gripe', 'tos']]

def vectorTotal(lstgrams,size):
    output=[]
    for item in lstgrams:
        buffer=np.zeros((size,), dtype=np.float32)
        for w in item:
            try:
                buffer = buffer + w2v_InfAltaSK.word_vec(w)
            except:
                # Si el token no está en el vocabulario del Modelo, se descarta todos los ngramas
                buffer = buffer + np.zeros((size,), dtype=np.float32)
                #break
        output.append((item, buffer))
    return output

# %% [markdown]
# ### 5 . Enfoques para la estructura final de Snomed2vec:
# * Generar estructura Matriz con una linea por cada ID (Id único), con los vectores de sus descripciones y sinónimos en misma fila.
# * Generar una linea por cada id y su descripcion. (Id's repetidos).

# %%
# Generar estructura Matriz con una linea por cada ID, con los vectores de sus descripciones y sinónimos 
# en misma fila.
# ----------------------------------------------------
# Enfoque 1:

snomed2vec = []

for i in range(len(dfSnomedSyn)):
    codId = dfSnomedSyn['conceptId'].loc[i]
    txtCorpus = dfSnomedSyn['corpus_token'].loc[i]
    txtSyn = dfSnomedSyn['corpus_Syn'].loc[i]
    snomed2vec.append([codId,vectorTotal(txtSyn, 300)])
    
print(len(snomed2vec))

# %%
def vectorSnomed(lstgrams,size):
    output=[]
    buffer=np.zeros((size,), dtype=np.float32)
    for item in lstgrams:
        try:
            buffer = buffer + w2v_InfAltaSK.word_vec(item)
        except:
            buffer = buffer + np.zeros((size,), dtype=np.float32)
            #break
    #output.extend( buffer)
    return buffer

# %% [markdown]
# ## 6. Función de Similitud. Snomed2Vec.Most_Similar():
# Función de Similitud, cuando se le pasa los vectores generados. Utilizando la Distancia del Coseno.

# %%
# Funcion similitud Distancia del Coseno, Parametros Vectores
def vSimilar(wv1,wv2):
    return np.nan_to_num((round(float(np.dot(wv1, wv2)/(np.linalg.norm(wv1) * np.linalg.norm(wv2))),4)))

# %%
def levenshtein(first, second):
    """Return the Levenshtein distance between two strings.
    Based on:
        http://rosettacode.org/wiki/Levenshtein_distance#Python
        implementing at: https://github.com/coloratto/TextRank/blob/master/textrank/__init__.py
    """
    if len(first) > len(second):
        first, second = second, first
    distances = range(len(first) + 1)
    for index2, char2 in enumerate(second):
        new_distances = [index2 + 1]
        for index1, char1 in enumerate(first):
            if char1 == char2:
                new_distances.append(distances[index1])
            else:
                new_distances.append(1 + min((distances[index1],
                                             distances[index1 + 1],
                                             new_distances[-1])))
        distances = new_distances
    return distances[-1]

# %%
def masCercana(w):
    cerca=[]
    try:
        cerca=w2v_InfAltaSK.most_similar(w)
    except:
        cerca=[]
    return cerca

# %%
def cercanos(sent,n):
    simConcept=[]
    for w in sent:
        buffer = masCercana(w)
        if len(masCercana(w))>1:
            for i in range(n):
                simConcept.append(buffer[i][0])
    return simConcept

# %% [markdown]
# ## 7. Creación de la Clase Snomed2Vec.

# %%
# Creacion de la clase snomed2vec Preparación de la nueva clase:
from gensim.models.keyedvectors import KeyedVectors

class snomed2vec(self, typeModel=0):
    
    if typeModel==0:                                     #Modelo Informes de Alta + Descripciones Snomed-CT
        fich = '/Models/w2v-SK-s300-w5-m2-Total-Key.txt'
    elif typeModel==1:                                   #Modelo Wikipedia
        fich = '/Models/SBW-vectors-300-min5.txt'
    elif typeModel==2:                                   #Modelo Descripciones Snomed-CT
        fich = '/Models/w2vSnomed-SK-s300-w3.txt'
    else:                                                #Modelo Informes de ALta de Urgencias.
        fich = '/Models/w2v-SK-s300-w5-min2.txt'
    f = p+fich
    w2vModel = KeyedVectors.load_word2vec_format(f, binary=False) 
    
    self.index2word = []

# %% [markdown]
# ## 7.1 Creación Métodos para Snomed2Vec:

# %% [markdown]
# ### 6.2. Implementacion  funcionamiento de most_similar() Version 2.0: (Otros Ejemplos de Implementacion)

# %%
from six import iteritems, itervalues, string_types
from gensim import utils, matutils
from gensim import models
import numpy as np

# %%
def get_ok_index(model, restrict_vocab):
    if hasattr(model, 'restrict_vocab') and model.restrict_vocab == restrict_vocab:
        return model.ok_index
    else:
        # sort vocab by neg cts, placing most frequent first.
        ok_vocab = dict(sorted(iteritems(model.vocab), key=lambda item: -item[1].count)[:restrict_vocab])
        ok_index = set(v.index for v in itervalues(ok_vocab))
        model.restrict_vocab = restrict_vocab
        model.ok_index = ok_index
        return ok_index

# %%
def get_sims(model, positive, negative, topn=False, restrict_vocab=30000):
    aa = make_analogy_array(model, positive=positive, negative=negative)
    return model.most_similar([aa], topn=False, restrict_vocab=restrict_vocab)

# %%
def complete_analogy(model, a, b, c, restrict_vocab=30000, verbose=False):
    ignore = set(model.vocab[v].index for v in [a, b, c])
    # sims will be a vector of shape (restrict_vocab,)
    # sims = model.most_similar(positive=[b, c], negative=[a], topn=False, restrict_vocab=restrict_vocab)
    positive, negative = ([b, c], [a])
    # aa = make_analogy_array(model,positive=positive,negative=negative)
    # sims = model.most_similar([aa], topn=False, restrict_vocab=restrict_vocab)
    sims = get_sims(model, positive, negative, topn=False, restrict_vocab=30000)
    ok_index = get_ok_index(model, restrict_vocab)
    # returns the INDICES of the elements sorted from best scoring to lowest.
    indices = matutils.argsort(sims, reverse=True)
    for index in indices:
        if index in ok_index and index not in ignore:
            predicted = model.index2word[index]
            break
    if verbose:
        print('------------------------------------')
        print('{0}:{1}::{2}:??   ??={3}'.format(a, b, c, predicted))
    return predicted

# %%
def nearest_neighbors(model, a, restrict_vocab=30000, topn=10, verbose=False):
    sims = model.most_similar(positive=[a], topn=False, restrict_vocab=restrict_vocab)
    ok_index = get_ok_index(model, restrict_vocab)
    # returns the INDICES of the elements sorted from best scoring to lowest.
    indices = matutils.argsort(sims, reverse=True)
    predicted = []
    ctr = 0
    for index in indices:
        if index in ok_index:
            ctr += 1
            predicted.append(model.index2word[index])
            if ctr == topn:
                break
    if verbose:
        print
        print
        '"{0}" ({1} nearest neighbors): {2}'.format(a, topn, ' '.join(predicted))
    return predicted

# %%
nearest_neighbors(w2v_InfAltaSK,'izda')
# Out:
# ['izda',
#  'dcha',
#  'derecha',
#  'dercha',
#  'drecha',
#  'izquierda',
#  'zida',
#  'izuqierda',
#  'izqueirda',
#  'iza']

# %%
def make_analogy_array(model, positive, negative):
    positive = [(word, 1.0) for word in positive]
    negative = [(word, -1.0) for word in negative]
    # mean = []
    mean = None
    for word, weight in positive + negative:
        if word in model.vocab:
            # mean.append(weight * model.syn0norm[model.vocab[word].index])
            if mean is not None:
                mean += weight * model.syn0norm[model.vocab[word].index]
            else:
                mean = weight * model.syn0norm[model.vocab[word].index]
        else:
            raise KeyError("word '%s' not in vocabulary" % word)
    # return matutils.unitvec(np.array(mean).mean(axis=0)).astype(np.float32)
    return matutils.unitvec(np.array(mean)).astype(np.float32)

# %% [markdown]
# make_analogy_array(w2v_InfAltaSK,['doctor','hombre'],['mujer'])

# %%
def word_vec(model, word):
    if isinstance(word, np.ndarray):
        return word
    elif word in model.vocab:
        all_words.add(model.vocab[word].index)
        return self.syn0norm[model.vocab[word].index]
    else:
        raise KeyError("word '%s' not in vocabulary" % word)

# %%
w2v_InfAltaSK.vocab['mujer'].index
# Out:
# 4534

# %%
complete_analogy(w2v_InfAltaSK, 'doctor', 'hombre', 'mujer', verbose=True)

# %% [markdown]
# ### Ejemplos para aplicarlo a un conjuntos de datos y evaluar Analogías

# %%
if __name__ == '__main__':

    import os.path

    # See
    # https://code.google.com/archive/p/word2vec/

    # Google test set for analogy maker
    # Download from http://word2vec.googlecode.com/svn/trunk/questions-words.txt
    # Edit to location on your machine.
    question_words_file = 'questions-words.txt'
    model_dir = '/Users/gawron/ext/src/word2vec/'
    # best predict vectors http://clic.cimec.unitn.it/composes/semantic-vectors.html
    # not in C format? _hdr version fixes C-form,at problem
    model_file, binary = 'EN-wform.w.5.cbow.neg10.400.subsmpl.filtered.txt', False
    # model_file,binary = 'vectors.bin',True
    model_file = os.path.join(model_dir, model_file)
    print
    'Loading binary={0} file {1} '.format(binary, model_file)
    model = models.Word2Vec.load_word2vec_format(model_file, binary=binary)
    print
    'Loaded'
    # model.similarity('woman', 'girl')
    # model.doesnt_match("breakfast cereal dinner lunch".split())

    # To do spearmean's correlation
    # import scipy.stats.stats
    # scipy.stats.stats.spearmanr(range(10), [3,2,0,1,6,5,9,8,4,7])

# %%
    complete_analogy(model, 'man', 'king', 'woman', verbose=True)
    complete_analogy(model, 'chicago', 'illinois', 'houston', verbose=True)
    complete_analogy(model, 'father', 'son', 'mother', verbose=True)
    complete_analogy(model, 'brother', 'sister', 'father', verbose=True)

    comp_predicted = nearest_neighbors(model, 'computer', topn=25, restrict_vocab=5000, verbose=True)
    alg_predicted = nearest_neighbors(model, 'algebra', topn=25, restrict_vocab=5000, verbose=True)
    church_predicted = nearest_neighbors(model, 'church', topn=25, restrict_vocab=5000, verbose=True)
    sleep_predicted = nearest_neighbors(model, 'sleep', topn=25, restrict_vocab=5000, verbose=True)

    # Run analogy maker on the Google test set
    XX = model.accuracy(question_words_file, restrict_vocab=30000, most_similar=get_sims)
    # print 'Total Analogies: Correct {0}  Incorrect {1}'.format(len(XX[-1]['correct']),len(XX[-1]['incorrect']))
    # Total Correct 3171  Incorrect 9097
    print
    print
    '{0:^50}'.format('Analogy scores')
    print
    '=' * 50
    print
    print
    '{0:>30}    Correct      Incorrect'.format('')
    for score_dict in XX:
        print
        '{0:<30} {1:^12}  {2:^12}'.format(score_dict['section'] + ':', len(score_dict['correct']),
                                          len(score_dict['incorrect']))

# %%
complete_analogy(model, 'man', 'king', 'woman', verbose=True)
InfAltModel
